# %%
https://etherscan.io/address/0xA188EEC8F81263234dA3622A406892F3D630f98c#code

https://etherscan.io/address/0xA188EEC8F81263234dA3622A406892F3D630f98c#code

# https://developers.sky.money/modules/litepsm

# is there anyway we can get to be this?


# we can't get good spot prices for USDS because there is a 4Billion deep 
# https://etherscan.io/address/0x37305B1cD40574E4C5Ce33f8e8306Be057fD7341
# place that can swap DAI, USDC, USDS, sDAI, sUSDs

# %% [markdown]
# ## LitePSM
#
# LitePSM is a gas-efficient implementation of the Peg Stability Module (PSM), designed to facilitate seamless swaps between DAI, USDS, and external stablecoins such as USDC, with no slippage. Unlike the original PSM, which was gas-intensive due to direct interactions with the MakerDAO Vat, LitePSM enables swaps using a pool of pre-minted DAI or USDS, reducing each transaction to two simple ERC-20 token transfers.
#
# Key features of LitePSM include permissionless functions to maintain pool stability, the ability for authorized parties to execute no-fee swaps, and the option to segregate gem balances for yield generation. This version is backward compatible and designed to optimize gas costs while supporting the security and operational requirements of the Sky ecosystem.
#
# Please refer to the LitePSM User Guide for additional details about the module.
#
# https://developers.sky.money/modules/litepsm

# %%
safe_price_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 safe_price_df
#
# NameError: name 'safe_price_df' is not defined

# %% [markdown]
# What am I missing here
#
# DAI, USDS and sUSDS are special cases.
#
# I think we can always get 1:1

# %% [markdown]
# Authorized Users
# Please reach out to the Integrations team to discuss your use case and inquire about becoming an authorized user.
#
# Stats
# Please refer to makerburn.com for current LitePSM-USDC stats after launch.

# %%
# Authorized Users
# Please reach out to the Integrations team to discuss your use case and inquire about becoming an authorized user.

# Stats
# Please refer to makerburn.com for current LitePSM-USDC stats after launch.

# #

# it has 4billion in liqudity
#

# %%
# 400M in DAI
# https://etherscan.io/address/0xf6e72db5454dd049d0788e411b06cfaf16853042

# 4.1B in USDC
# 0x37305B1cD40574E4C5Ce33f8e8306Be057fD7341 # interestingly this is not a contract

# the 0xA188EEC8F81263234dA3622A406892F3D630f98c.pocket() -> points to the EOA with 4.1B in ETH


# Here is how i think it works,
