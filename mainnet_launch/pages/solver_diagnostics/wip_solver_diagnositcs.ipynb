# %%
from solver_diagnostics import *
from mainnet_launch.constants import *
import plotly.express as px

autopool = AUTO_DOLA
actual_rebalance_events_df, dex_swap_steps_df, proposed_rebalances_df = fetch_and_render_solver_diagnostics_data(
    autopool
)
px.scatter(
    actual_rebalance_events_df,
    x="datetime",
    y="latency",
    title="Latency (minutes) Between Solver Generation and Execution",
)
# Out:
# 2025-06-11 15:36:09.942 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-11 15:36:09.943 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-11 15:36:09.943 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-11 15:36:10.438 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-11 15:36:10.438 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-11 15:36:10.441 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-11 15:36:10.441 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...

# %%
px.scatter()
# Out:
#      quantity_out    quantity_in  safe_value_out  safe_value_in  \
# 0      260.711443     261.299545      260.711443     260.470158
# 1      250.000000     250.588078      250.000000     249.874656
# 2      250.000000     250.669514      250.000000     249.985003
# 3    20000.000000   20048.773378    20000.000000   19975.992145
# 4    40000.000000   40045.397846    40000.000000   39933.329519
# 5   507586.651647  448213.886034   507586.651647  507510.513649
# 6   253793.325823  224104.483853   253793.325823  253755.256825
# 7    50000.000000   50053.933314    50000.000000   49960.269585
# 8    50000.000000   50116.633595    50000.000000   50024.974176
# 9   254700.377680  224889.880882   254700.377680  254662.172623
# 10   48259.254973   48367.039726    48259.254973   48225.164616
# 11   36194.441229   36272.298892    36194.441229   36164.932510
# 12   35783.819220   35854.603903    35783.819220   35741.595218
# 13  125000.000000  125265.191231   125000.000000  124906.528819
# ...
