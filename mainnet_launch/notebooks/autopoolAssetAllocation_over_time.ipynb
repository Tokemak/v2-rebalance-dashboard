# %%
from multicall import Call

from mainnet_launch.data_fetching.get_state_by_block import get_raw_state_by_blocks, build_blocks_to_use
import plotly.graph_objects as go
import plotly.express as px
import pandas as pd
import streamlit as st
from multicall import Call
from web3 import Web3


from mainnet_launch.constants import (
    AutopoolConstants,
    WETH,
    ROOT_PRICE_ORACLE,
    ChainData,
    ALL_AUTOPOOLS,
    BASE_ETH,
    eth_client,
    ETH_CHAIN,
    AUTO_ETH,
)

from mainnet_launch.data_fetching.get_state_by_block import (
    get_raw_state_by_blocks,
    safe_normalize_with_bool_success,
    get_state_by_one_block,
    identity_with_bool_success,
)

from mainnet_launch.data_fetching.get_events import fetch_events

from mainnet_launch.abis import (
    AUTOPOOL_ETH_STRATEGY_ABI,
    ERC_20_ABI,
    BALANCER_AURA_DESTINATION_VAULT_ABI,
    ROOT_PRICE_ORACLE_ABI,
)
from mainnet_launch.destinations import get_destination_details, DestinationDetails
from mainnet_launch.data_fetching.add_info_to_dataframes import (
    add_timestamp_to_df_with_block_column,
    add_transaction_gas_info_to_df_with_tx_hash,
)

from mainnet_launch.database.should_update_database import should_update_table
from mainnet_launch.pages.asset_discounts.fetch_and_render_asset_discounts import _fetch_lst_calc_addresses_df

import plotly.io as pio

pio.templates.default = None


from mainnet_launch.pages.autopool_exposure.asset_allocation_over_time import (
    _fetch_asset_allocation_over_time_from_external_source,
)

autopool = AUTO_ETH

assets_df = _fetch_asset_allocation_over_time_from_external_source(
    autopool, autopool.chain.block_autopool_first_deployed
)
assets_df
# Out:
# 2025-01-23 15:18:00.902 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2025-01-23 15:18:00.985 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-23 15:18:01.147
# ...
#   command:
#
#     streamlit run /home/parker/Documents/Tokemak/v2-rebalance-dashboard/.venv/lib/python3.10/site-packages/ipykernel_launcher.py [ARGUMENTS]
# 2025-01-23 15:18:01.148 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-23 15:18:01.148 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-23 15:18:01.149 No runtime found, using MemoryCacheStorageManager
# 2025-01-23 15:18:01.649 Thread 'Thread-4': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...

# %%
lst_df = _fetch_lst_calc_addresses_df(autopool.chain)
asset_to_symbol = dict(zip(lst_df['lst'], lst_df['symbol']))
asset_to_symbol[WETH(autopool.chain).lower()] = 'WETH'
assets_df  = assets_df.rename(columns=asset_to_symbol)
assets_df
# Out:
# 2025-01-23 15:18:31.322 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-23 15:18:31.322 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-23 15:18:31.323 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-23 15:18:31.324 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-23 15:18:31.325 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
#                                   WETH        pxETH        stETH         ETHx  \
# timestamp
# 2024-09-15 02:04:47+00:00     0.166129          NaN          NaN          NaN
# 2024-09-15 08:06:23+00:00     0.176129          NaN          NaN          NaN
# 2024-09-15 14:07:35+00:00     0.176129          NaN          NaN          NaN
# ...

# %%
from mainnet_launch.pages.asset_discounts.fetch_and_render_asset_discounts   import ASSET_BACKING_AND_PRICES, get_all_rows_in_table_by_chain, _extract_backing_price_and_percent_discount_dfs
long_asset_oracle_and_backing_df = get_all_rows_in_table_by_chain(ASSET_BACKING_AND_PRICES, ETH_CHAIN)
long_asset_oracle_and_backing_df
# Out:
#          block  symbol   backing  oracle_price  percent_discount chain
# 0     20752910   cbETH  1.081472      1.079332          0.197946   eth
# 1     20754710   cbETH  1.081472      1.079332          0.197946   eth
# 2     20756510   cbETH  1.081472      1.079332          0.197946   eth
# 3     20758310   cbETH  1.081546      1.079332          0.204705   eth
# 4     20760110   cbETH  1.081546      1.079487          0.190317   eth
# ...        ...     ...       ...           ...               ...   ...
# 6199  21674510  wstETH  1.191357      1.188757          0.218228   eth
# 6200  21676310  wstETH  1.191357      1.188757          0.218228   eth
# 6201  21678110  wstETH  1.191357      1.188889          0.207123   eth
# 6202  21679910  wstETH  1.191357      1.188889          0.207123   eth
# 6203  21681710  wstETH  1.191452      1.188984          0.207123   eth
#
# [6204 rows x 6 columns]

# %%
wide_backing_df, wide_oracle_price_df, wide_percent_discount_df = _extract_backing_price_and_percent_discount_dfs(
    long_asset_oracle_and_backing_df
)

wide_backing_df['WETH'] = 1
wide_backing_df['stETH'] = 1

wide_oracle_price_df['WETH'] = 1
wide_oracle_price_df['stETH'] = wide_oracle_price_df['wstETH'] / wide_backing_df['wstETH']

wide_percent_discount_df['WETH'] = 0
wide_percent_discount_df['stETH'] = wide_percent_discount_df['wstETH']

assets_oracle_value = assets_df * wide_oracle_price_df[assets_df.columns]
assets_backing_value = assets_df * wide_backing_df[assets_df.columns]
asset_percent_discount = assets_df * wide_percent_discount_df[assets_df.columns] / 100 # remove * 100 to get ETH

# %%
px.bar(assets_oracle_value, title='Asset Oralce Price Value')

# %%
px.bar(assets_backing_value, title='Asset Underlying Value')

# %%
px.bar(assets_backing_value - assets_oracle_value , title='Expected gain if all assets Return to peg (ignores how we own less of assets as they increase) ')
# 50% of price return comes from rETH, break up price return into sources

# %%
px.bar(asset_percent_discount, title='Expected gain if all assets Return to peg (ignores how we own less of assets as they increase) ')
