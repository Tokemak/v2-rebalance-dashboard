# %%
import pandas as pd
from mainnet_launch.constants import (
    CACHE_TIME,
    eth_client,
    ALL_AUTOPOOLS,
    BAL_ETH,
    AUTO_ETH,
    AUTO_LRT,
    AutopoolConstants,
)
from mainnet_launch.destinations import get_destination_details
from mainnet_launch.lens_contract import get_pools_and_destinations_call
from mainnet_launch.destination_diagnostics.fetch_destination_summary_stats import _build_summary_stats_call

import warnings

warnings.filterwarnings("ignore", message=".*This warning can be ignored when running in bare mode*")

destination_details = get_destination_details()
# Out:
# 2024-10-28 15:19:17.976 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2024-10-28 15:19:17.980 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2024-10-28 15:19:17.982 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2024-10-28 15:19:18.060 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2024-10-28 15:19:18.062 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-28 15:19:18.119
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /home/parker/Documents/Tokemak/v2-rebalance-dashboard/.venv/lib/python3.10/site-packages/ipykernel_launcher.py [ARGUMENTS]
# 2024-10-28 15:19:18.119 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-28 15:19:18.120 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-28 15:19:18.121 No runtime found, using MemoryCacheStorageManager
# 2024-10-28 15:19:18.121 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-28 15:19:18.122 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-28 15:19:18.122 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-28 15:19:18.123 No runtime found, using MemoryCacheStorageManager
# 2024-10-28 15:19:18.123 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-28 15:19:18.124 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-28 15:19:18.124 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-28 15:19:18.125 No runtime found, using MemoryCacheStorageManager
# 2024-10-28 15:19:18.465 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-28 15:19:18.466 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-28 15:19:18.621 Thread 'Thread-26': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-28 15:19:18.622 Thread 'Thread-26': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-28 15:19:18.623 Thread 'Thread-27': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-28 15:19:18.634 Thread 'Thread-27': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-28 15:19:23.201 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-28 15:19:23.202 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-28 15:19:24.818 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-28 15:19:24.818 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
suspect_pool = destination_details[0]
suspect_pool
# Out:
# Destination Details:
#  vaultAddress	: 0x2F7e096a400ded5D02762120b39A3aA4ABA072a4
#  exchangeName	: balancer
#  dexPool	: 0x7761b6E0Daa04E70637D81f1Da7d186C205C2aDE
#  lpTokenAddress	: 0x7761b6E0Daa04E70637D81f1Da7d186C205C2aDE
#  lpTokenSymbol	: rsETH / ETHx
#  lpTokenName	: Balancer rsETH / ETHx
#  autopool	: {'name': 'Balancer/Tokemak balETH', 'autopool_eth_addr': '0x6dC3ce9C57b20131347FDc9089D740DAf6eB34c5', 'autopool_eth_strategy_addr': '0xabe104560D0B390309bcF20b73Dca335457AA32e', 'solver_rebalance_plans_bucket': 'v2-gen3-eth-mainnet-solve-v2gen3ethmainnetsolverba-wx1snhldrupb'}
#  vault_name	: rsETH / ETHx (balancer)

# %%
from multicall import Call

from mainnet_launch.constants import CACHE_TIME, ALL_AUTOPOOLS, eth_client, LENS_CONTRACT
from mainnet_launch.data_fetching.get_state_by_block import (
    get_raw_state_by_blocks,
    get_state_by_one_block,
    identity_with_bool_success,
    safe_normalize_with_bool_success,
    build_blocks_to_use,
)


def build_get_virtual_price_call(name: str, curve_pool) -> Call:
    return Call(
        curve_pool,
        ["get_virtual_price()(uint256)"],
        [(name, safe_normalize_with_bool_success)],
    )


blocks = build_blocks_to_use(use_mainnet=False)
df = get_raw_state_by_blocks([build_get_virtual_price_call("virtual_price", suspect_pool.lpTokenAddress)], blocks)
df
# Out:
# 2024-10-28 15:19:24.860 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-28 15:19:24.860 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-28 15:19:24.861 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-28 15:19:24.970 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-28 15:19:24.971 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
#                           virtual_price
# timestamp
# 2024-07-08 14:38:47+00:00          None
# 2024-07-08 18:19:47+00:00          None
# 2024-07-08 22:01:47+00:00          None
# 2024-07-09 01:41:59+00:00          None
# 2024-07-09 05:21:59+00:00          None
# ...                                 ...
# 2024-10-28 04:36:47+00:00          None
# 2024-10-28 08:17:35+00:00          None
# 2024-10-28 11:57:47+00:00          None
# 2024-10-28 15:38:11+00:00          None
# 2024-10-28 19:18:23+00:00          None
#
# [735 rows x 1 columns]

# %%
import plotly.express as px
import plotly.io as pio
import numpy as np

pio.templates.default = None
daily_df = df.resample("1D").last()
DEX_FEE_ALPHA = 0.1
daily_df["daily_apr_from_vp_change"] = (
    (daily_df["virtual_price"].diff(1) / daily_df["virtual_price"].shift(1)) * 365 * 100
)
daily_df = daily_df.dropna()

priorValue = 2.0  # a reasonable seed value


def get_smoothed_fee_apr(priorValue, currentValue):
    return (priorValue * (1 - DEX_FEE_ALPHA)) + (currentValue * DEX_FEE_ALPHA)


ewma_smoothed_fee_apr = []
for fee_apr_value in daily_df["daily_apr_from_vp_change"].values:
    new_prior = get_smoothed_fee_apr(priorValue, fee_apr_value)
    priorValue = new_prior
    ewma_smoothed_fee_apr.append(priorValue)


daily_df["ewma_smoothed_fee_apr"] = ewma_smoothed_fee_apr
px.line(daily_df[["daily_apr_from_vp_change", "ewma_smoothed_fee_apr"]])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 9
#       6 daily_df = df.resample("1D").last()
#       7 DEX_FEE_ALPHA = 0.1
#       8 daily_df["daily_apr_from_vp_change"] = (
# ----> 9     (daily_df["virtual_price"].diff(1) / daily_df["virtual_price"].shift(1)) * 365 * 100
#      10 )
#      11 daily_df = daily_df.dropna()
#      13 priorValue = 2.0  # a reasonable seed value
#
# File ~/Documents/Tokemak/v2-rebalance-dashboard/.venv/lib/python3.10/site-packages/pandas/core/series.py:3120, in Series.diff(self, periods)
#    3035 @doc(
#    3036     klass="Series",
#    3037     extra_params="",
#    (...)
#    3083 )
#    3084 def diff(self, periods: int = 1) -> Series:
#    3085     """
#    3086     First discrete difference of element.
#    3087
#    (...)
#    3118     {examples}
#    3119     """
# -> 3120     result = algorithms.diff(self._values, periods)
#    3121     return self._constructor(result, index=self.index, copy=False).__finalize__(
#    3122         self, method="diff"
#    3123     )
#
# File ~/Documents/Tokemak/v2-rebalance-dashboard/.venv/lib/python3.10/site-packages/pandas/core/algorithms.py:1435, in diff(arr, n, axis)
#    1432     _lag_indexer[axis] = slice(None, -n) if n > 0 else slice(-n, None)
#    1433     lag_indexer = tuple(_lag_indexer)
# -> 1435     out_arr[res_indexer] = op(arr[res_indexer], arr[lag_indexer])
#    1437 if is_timedelta:
#    1438     out_arr = out_arr.view("timedelta64[ns]")
#
# TypeError: unsupported operand type(s) for -: 'NoneType' and 'NoneType'

# %%
import plotly.express as px

# %%
abi = """[{"name":"Transfer","inputs":[{"name":"sender","type":"address","indexed":true},{"name":"receiver","type":"address","indexed":true},{"name":"value","type":"uint256","indexed":false}],"anonymous":false,"type":"event"},{"name":"Approval","inputs":[{"name":"owner","type":"address","indexed":true},{"name":"spender","type":"address","indexed":true},{"name":"value","type":"uint256","indexed":false}],"anonymous":false,"type":"event"},{"name":"TokenExchange","inputs":[{"name":"buyer","type":"address","indexed":true},{"name":"sold_id","type":"int128","indexed":false},{"name":"tokens_sold","type":"uint256","indexed":false},{"name":"bought_id","type":"int128","indexed":false},{"name":"tokens_bought","type":"uint256","indexed":false}],"anonymous":false,"type":"event"},{"name":"AddLiquidity","inputs":[{"name":"provider","type":"address","indexed":true},{"name":"token_amounts","type":"uint256[2]","indexed":false},{"name":"fees","type":"uint256[2]","indexed":false},{"name":"invariant","type":"uint256","indexed":false},{"name":"token_supply","type":"uint256","indexed":false}],"anonymous":false,"type":"event"},{"name":"RemoveLiquidity","inputs":[{"name":"provider","type":"address","indexed":true},{"name":"token_amounts","type":"uint256[2]","indexed":false},{"name":"fees","type":"uint256[2]","indexed":false},{"name":"token_supply","type":"uint256","indexed":false}],"anonymous":false,"type":"event"},{"name":"RemoveLiquidityOne","inputs":[{"name":"provider","type":"address","indexed":true},{"name":"token_amount","type":"uint256","indexed":false},{"name":"coin_amount","type":"uint256","indexed":false},{"name":"token_supply","type":"uint256","indexed":false}],"anonymous":false,"type":"event"},{"name":"RemoveLiquidityImbalance","inputs":[{"name":"provider","type":"address","indexed":true},{"name":"token_amounts","type":"uint256[2]","indexed":false},{"name":"fees","type":"uint256[2]","indexed":false},{"name":"invariant","type":"uint256","indexed":false},{"name":"token_supply","type":"uint256","indexed":false}],"anonymous":false,"type":"event"},{"name":"RampA","inputs":[{"name":"old_A","type":"uint256","indexed":false},{"name":"new_A","type":"uint256","indexed":false},{"name":"initial_time","type":"uint256","indexed":false},{"name":"future_time","type":"uint256","indexed":false}],"anonymous":false,"type":"event"},{"name":"StopRampA","inputs":[{"name":"A","type":"uint256","indexed":false},{"name":"t","type":"uint256","indexed":false}],"anonymous":false,"type":"event"},{"name":"CommitNewFee","inputs":[{"name":"new_fee","type":"uint256","indexed":false}],"anonymous":false,"type":"event"},{"name":"ApplyNewFee","inputs":[{"name":"fee","type":"uint256","indexed":false}],"anonymous":false,"type":"event"},{"stateMutability":"nonpayable","type":"constructor","inputs":[],"outputs":[]},{"stateMutability":"nonpayable","type":"function","name":"initialize","inputs":[{"name":"_name","type":"string"},{"name":"_symbol","type":"string"},{"name":"_coins","type":"address[4]"},{"name":"_rate_multipliers","type":"uint256[4]"},{"name":"_A","type":"uint256"},{"name":"_fee","type":"uint256"}],"outputs":[]},{"stateMutability":"nonpayable","type":"function","name":"transfer","inputs":[{"name":"_to","type":"address"},{"name":"_value","type":"uint256"}],"outputs":[{"name":"","type":"bool"}]},{"stateMutability":"nonpayable","type":"function","name":"transferFrom","inputs":[{"name":"_from","type":"address"},{"name":"_to","type":"address"},{"name":"_value","type":"uint256"}],"outputs":[{"name":"","type":"bool"}]},{"stateMutability":"nonpayable","type":"function","name":"approve","inputs":[{"name":"_spender","type":"address"},{"name":"_value","type":"uint256"}],"outputs":[{"name":"","type":"bool"}]},{"stateMutability":"nonpayable","type":"function","name":"permit","inputs":[{"name":"_owner","type":"address"},{"name":"_spender","type":"address"},{"name":"_value","type":"uint256"},{"name":"_deadline","type":"uint256"},{"name":"_v","type":"uint8"},{"name":"_r","type":"bytes32"},{"name":"_s","type":"bytes32"}],"outputs":[{"name":"","type":"bool"}]},{"stateMutability":"view","type":"function","name":"last_price","inputs":[],"outputs":[{"name":"","type":"uint256"}]},{"stateMutability":"view","type":"function","name":"ema_price","inputs":[],"outputs":[{"name":"","type":"uint256"}]},{"stateMutability":"view","type":"function","name":"stored_rates","inputs":[],"outputs":[{"name":"","type":"uint256[2]"}]},{"stateMutability":"view","type":"function","name":"balances","inputs":[{"name":"i","type":"uint256"}],"outputs":[{"name":"","type":"uint256"}]},{"stateMutability":"view","type":"function","name":"admin_fee","inputs":[],"outputs":[{"name":"","type":"uint256"}]},{"stateMutability":"view","type":"function","name":"A","inputs":[],"outputs":[{"name":"","type":"uint256"}]},{"stateMutability":"view","type":"function","name":"A_precise","inputs":[],"outputs":[{"name":"","type":"uint256"}]},{"stateMutability":"view","type":"function","name":"get_p","inputs":[],"outputs":[{"name":"","type":"uint256"}]},{"stateMutability":"view","type":"function","name":"price_oracle","inputs":[],"outputs":[{"name":"","type":"uint256"}]},{"stateMutability":"view","type":"function","name":"get_virtual_price","inputs":[],"outputs":[{"name":"","type":"uint256"}]},{"stateMutability":"view","type":"function","name":"calc_token_amount","inputs":[{"name":"_amounts","type":"uint256[2]"},{"name":"_is_deposit","type":"bool"}],"outputs":[{"name":"","type":"uint256"}]},{"stateMutability":"payable","type":"function","name":"add_liquidity","inputs":[{"name":"_amounts","type":"uint256[2]"},{"name":"_min_mint_amount","type":"uint256"}],"outputs":[{"name":"","type":"uint256"}]},{"stateMutability":"payable","type":"function","name":"add_liquidity","inputs":[{"name":"_amounts","type":"uint256[2]"},{"name":"_min_mint_amount","type":"uint256"},{"name":"_receiver","type":"address"}],"outputs":[{"name":"","type":"uint256"}]},{"stateMutability":"view","type":"function","name":"get_dy","inputs":[{"name":"i","type":"int128"},{"name":"j","type":"int128"},{"name":"dx","type":"uint256"}],"outputs":[{"name":"","type":"uint256"}]},{"stateMutability":"payable","type":"function","name":"exchange","inputs":[{"name":"i","type":"int128"},{"name":"j","type":"int128"},{"name":"_dx","type":"uint256"},{"name":"_min_dy","type":"uint256"}],"outputs":[{"name":"","type":"uint256"}]},{"stateMutability":"payable","type":"function","name":"exchange","inputs":[{"name":"i","type":"int128"},{"name":"j","type":"int128"},{"name":"_dx","type":"uint256"},{"name":"_min_dy","type":"uint256"},{"name":"_receiver","type":"address"}],"outputs":[{"name":"","type":"uint256"}]},{"stateMutability":"nonpayable","type":"function","name":"remove_liquidity","inputs":[{"name":"_burn_amount","type":"uint256"},{"name":"_min_amounts","type":"uint256[2]"}],"outputs":[{"name":"","type":"uint256[2]"}]},{"stateMutability":"nonpayable","type":"function","name":"remove_liquidity","inputs":[{"name":"_burn_amount","type":"uint256"},{"name":"_min_amounts","type":"uint256[2]"},{"name":"_receiver","type":"address"}],"outputs":[{"name":"","type":"uint256[2]"}]},{"stateMutability":"nonpayable","type":"function","name":"remove_liquidity_imbalance","inputs":[{"name":"_amounts","type":"uint256[2]"},{"name":"_max_burn_amount","type":"uint256"}],"outputs":[{"name":"","type":"uint256"}]},{"stateMutability":"nonpayable","type":"function","name":"remove_liquidity_imbalance","inputs":[{"name":"_amounts","type":"uint256[2]"},{"name":"_max_burn_amount","type":"uint256"},{"name":"_receiver","type":"address"}],"outputs":[{"name":"","type":"uint256"}]},{"stateMutability":"view","type":"function","name":"calc_withdraw_one_coin","inputs":[{"name":"_burn_amount","type":"uint256"},{"name":"i","type":"int128"}],"outputs":[{"name":"","type":"uint256"}]},{"stateMutability":"nonpayable","type":"function","name":"remove_liquidity_one_coin","inputs":[{"name":"_burn_amount","type":"uint256"},{"name":"i","type":"int128"},{"name":"_min_received","type":"uint256"}],"outputs":[{"name":"","type":"uint256"}]},{"stateMutability":"nonpayable","type":"function","name":"remove_liquidity_one_coin","inputs":[{"name":"_burn_amount","type":"uint256"},{"name":"i","type":"int128"},{"name":"_min_received","type":"uint256"},{"name":"_receiver","type":"address"}],"outputs":[{"name":"","type":"uint256"}]},{"stateMutability":"nonpayable","type":"function","name":"ramp_A","inputs":[{"name":"_future_A","type":"uint256"},{"name":"_future_time","type":"uint256"}],"outputs":[]},{"stateMutability":"nonpayable","type":"function","name":"stop_ramp_A","inputs":[],"outputs":[]},{"stateMutability":"nonpayable","type":"function","name":"withdraw_admin_fees","inputs":[],"outputs":[]},{"stateMutability":"nonpayable","type":"function","name":"commit_new_fee","inputs":[{"name":"_new_fee","type":"uint256"}],"outputs":[]},{"stateMutability":"nonpayable","type":"function","name":"apply_new_fee","inputs":[],"outputs":[]},{"stateMutability":"nonpayable","type":"function","name":"set_ma_exp_time","inputs":[{"name":"_ma_exp_time","type":"uint256"}],"outputs":[]},{"stateMutability":"nonpayable","type":"function","name":"set_oracle","inputs":[{"name":"_method_id","type":"bytes4"},{"name":"_oracle","type":"address"}],"outputs":[]},{"stateMutability":"view","type":"function","name":"version","inputs":[],"outputs":[{"name":"","type":"string"}]},{"stateMutability":"view","type":"function","name":"coins","inputs":[{"name":"arg0","type":"uint256"}],"outputs":[{"name":"","type":"address"}]},{"stateMutability":"view","type":"function","name":"admin_balances","inputs":[{"name":"arg0","type":"uint256"}],"outputs":[{"name":"","type":"uint256"}]},{"stateMutability":"view","type":"function","name":"fee","inputs":[],"outputs":[{"name":"","type":"uint256"}]},{"stateMutability":"view","type":"function","name":"future_fee","inputs":[],"outputs":[{"name":"","type":"uint256"}]},{"stateMutability":"view","type":"function","name":"admin_action_deadline","inputs":[],"outputs":[{"name":"","type":"uint256"}]},{"stateMutability":"view","type":"function","name":"initial_A","inputs":[],"outputs":[{"name":"","type":"uint256"}]},{"stateMutability":"view","type":"function","name":"future_A","inputs":[],"outputs":[{"name":"","type":"uint256"}]},{"stateMutability":"view","type":"function","name":"initial_A_time","inputs":[],"outputs":[{"name":"","type":"uint256"}]},{"stateMutability":"view","type":"function","name":"future_A_time","inputs":[],"outputs":[{"name":"","type":"uint256"}]},{"stateMutability":"view","type":"function","name":"oracle_method","inputs":[],"outputs":[{"name":"","type":"uint256"}]},{"stateMutability":"view","type":"function","name":"name","inputs":[],"outputs":[{"name":"","type":"string"}]},{"stateMutability":"view","type":"function","name":"symbol","inputs":[],"outputs":[{"name":"","type":"string"}]},{"stateMutability":"view","type":"function","name":"balanceOf","inputs":[{"name":"arg0","type":"address"}],"outputs":[{"name":"","type":"uint256"}]},{"stateMutability":"view","type":"function","name":"allowance","inputs":[{"name":"arg0","type":"address"},{"name":"arg1","type":"address"}],"outputs":[{"name":"","type":"uint256"}]},{"stateMutability":"view","type":"function","name":"totalSupply","inputs":[],"outputs":[{"name":"","type":"uint256"}]},{"stateMutability":"view","type":"function","name":"decimals","inputs":[],"outputs":[{"name":"","type":"uint256"}]},{"stateMutability":"view","type":"function","name":"DOMAIN_SEPARATOR","inputs":[],"outputs":[{"name":"","type":"bytes32"}]},{"stateMutability":"view","type":"function","name":"nonces","inputs":[{"name":"arg0","type":"address"}],"outputs":[{"name":"","type":"uint256"}]},{"stateMutability":"view","type":"function","name":"ma_exp_time","inputs":[],"outputs":[{"name":"","type":"uint256"}]},{"stateMutability":"view","type":"function","name":"ma_last_time","inputs":[],"outputs":[{"name":"","type":"uint256"}]}]"""

# %%
# Out:
# <class 'web3._utils.datatypes.Transfer'>
# <class 'web3._utils.datatypes.Approval'>
# <class 'web3._utils.datatypes.TokenExchange'>
# <class 'web3._utils.datatypes.AddLiquidity'>
# <class 'web3._utils.datatypes.RemoveLiquidity'>
# <class 'web3._utils.datatypes.RemoveLiquidityOne'>
# <class 'web3._utils.datatypes.RemoveLiquidityImbalance'>
# <class 'web3._utils.datatypes.RampA'>
# <class 'web3._utils.datatypes.StopRampA'>
# <class 'web3._utils.datatypes.CommitNewFee'>
# <class 'web3._utils.datatypes.ApplyNewFee'>

# %%
strader_config = "0xF64bAe65f6f2a5277571143A24FaaFDFC0C2a737"

# %%
from mainnet_launch.data_fetching.get_events import get_each_event_in_contract, fetch_events

from mainnet_launch.data_fetching.get_events import get_each_event_in_contract, fetch_events
from mainnet_launch.data_fetching.get_state_by_block import add_timestamp_to_df_with_block_column


pool_contract = eth_client.eth.contract("0x59Ab5a5b5d617E478a2479B0cAD80DA7e2831
# 2023-09-21 07:51:35+00:00                 49         90
# 2023-09-22 04:35:35+00:00                  8        167
# ...                                      ...        ...
# 2024-10-28 01:31:35+00:00                 42        190
# 2024-10-28 08:23:47+00:00                  5         60
# 2024-10-28 10:37:59+00:00                 14        106
# 2024-10-28 16:31:59+00:00                  3         28
# 2024-10-28 17:18:59+00:00                 30        183
#
#                                                                         hash
# timestamp
# 2023-09-14 19:35:23+00:00  0xdfa689bebbcf14f4f67237ac81651b5fbf3c721c1b17...
# 2023-09-21 04:51:23+00:00  0x43944f70a72dcdf67e3ea07b48ffeff5b44c29e4f224...
# 2023-09-21 06:37:23+00:00  0x69cf8ec08d98edee287198597d1026198e6b5f31460f...
# 2023-09-21 07:51:35+00:00  0x4c25a6f05963ab819d04c868ef789cc21b9fa9ca2a7f...
# 2023-09-22 04:35:35+00:00  0x411b7ba3b72f5f47ed9aa8891d6958df69317466345b...
# ...                                                                      ...
# 2024-10-28 01:31:35+00:00  0xf33b824f713f7518443420f4d132202f7a11ca313b37...
# 2024-10-28 08:23:47+00:00  0xd5b0b523bc97d6a3a4ce73cdadbcf67b6d2b7ba0fdf6...
# 2024-10-28 10:37:59+00:00  0xc1c06bfc1eb5e96443db46343d6741bd15da08f790c3...
# 2024-10-28 16:31:59+00:00  0x8a1f4210ce302f4923f2c982d209a254292f02553a3d...
# 2024-10-28 17:18:59+00:00  0xb0fd308ccfb900647feebc77eee22bd428ba45b08f4d...
#
# [2788 rows x 10 columns]

# %%
# IStaderOracle.ExchangeRate memory exchangeRateInfo = token.staderConfig().getStaderOracle().getExchangeRate();
# return exchangeRateInfo.totalETHXSupply == 0
#     ? 1e18
#     : exchangeRateInfo.totalETHBalance * 1e18 / exchangeRateInfo.totalETHXSupply;

# %%
destination_details
# Out:
# [Destination Details:
#   vaultAddress	: 0x2F7e096a400ded5D02762120b39A3aA4ABA072a4
#   exchangeName	: balancer
#   dexPool	: 0x7761b6E0Daa04E70637D81f1Da7d186C205C2aDE
#   lpTokenAddress	: 0x7761b6E0Daa04E70637D81f1Da7d186C205C2aDE
#   lpTokenSymbol	: rsETH / ETHx
#   lpTokenName	: Balancer rsETH / ETHx
#   autopool	: {'name': 'Balancer/Tokemak balETH', 'autopool_eth_addr': '0x6dC3ce9C57b20131347FDc9089D740DAf6eB34c5', 'autopool_eth_strategy_addr': '0xabe104560D0B390309bcF20b73Dca335457AA32e', 'solver_rebalance_plans_bucket': 'v2-gen3-eth-mainnet-solve-v2gen3ethmainnetsolverba-wx1snhldrupb'}
#   vault_name	: rsETH / ETHx (balancer),
#  Destination Details:
#   vaultAddress	: 0x2F7e096a400ded5D02762120b39A3aA4ABA072a4
#   exchangeName	: balancer
#   dexPool	: 0x7761b6E0Daa04E70637D81f1Da7d186C205C2aDE
#   lpTokenAddress	: 0x7761b6E0Daa04E70637D81f1Da7d186C205C2aDE
#   lpTokenSymbol	: rsETH / ETHx
#   lpTokenName	: Balancer rsETH / ETHx
#   autopool	: {'name': 'Tokemak autoLRT', 'autopool_eth_addr': '0xE800e3760FC20aA98c5df6A9816147f190455AF3', 'autopool_eth_strategy_addr': '0x72a726c10220280049687E58B7b05fb03d579109', 'solver_rebalance_plans_bucket': 'v2-gen3-eth-mainnet-solve-v2gen3ethmainnetsolverau-cb9s4hq4f8sv'}
#   vault_name	: rsETH / ETHx (balancer),
#  Destination Details:
#   vaultAddress	: 0x867991C7737Ccbb152aE5a7E6EDB05cA0670717E
#   exchangeName	: balancer
#   dexPool	: 0x1E19CF2D73a72Ef1332C882F20534B6519Be0276
#   lpTokenAddress	: 0x1E19CF2D73a72Ef1332C882F20534B6519Be0276
#   lpTokenSymbol	: B-rETH-STABLE
#   lpTokenName	: Balancer rETH Stable Pool
#   autopool	: {'name': 'Tokemak autoETH', 'autopool_eth_addr': '0x0A2b94F6871c1D7A32Fe58E1ab5e6deA2f114E56', 'autopool_eth_strategy_addr': '0xf5f6addB08c5e6091e5FdEc7326B21bEEd942235', 'solver_rebalance_plans_bucket': 'v2-gen3-eth-mainnet-solve-v2gen3ethmainnetsolverau-7ju0ra8aoznh'}
#   vault_name	: B-rETH-STABLE (balancer),
#  Destination Details:
#   vaultAddress	: 0x867991C7737Ccbb152aE5a7E6EDB05cA0670717E
#   exchangeName	: balancer
#   dexPool	: 0x1E19CF2D73a72Ef1332C882F20534B6519Be0276
#   lpTokenAddress	: 0x1E19CF2D73a72Ef1332C882F20534B6519Be0276
#   lpTokenSymbol	: B-rETH-STABLE
#   lpTokenName	: Balancer rETH Stable Pool
#   autopool	: {'name': 'Balancer/Tokemak balETH', 'autopool_eth_addr': '0x6dC3ce9C57b20131347FDc9089D740DAf6eB34c5', 'autopool_eth_strategy_addr': '0xabe104560D0B390309bcF20b73Dca335457AA32e', 'solver_rebalance_plans_bucket': 'v2-gen3-eth-mainnet-solve-v2gen3ethmainnetsolverba-wx1snhldrupb'}
#   vault_name	: B-rETH-STABLE (balancer),
#  Destination Details:
#   vaultAddress	: 0xd96E943098B2AE81155e98D7DC8BeaB34C539f01
#   exchangeName	: curve
#   dexPool	: 0x6951bDC4734b9f7F3E1B74afeBC670c736A0EDB6
#   lpTokenAddress	: 0x6951bDC4734b9f7F3E1B74afeBC670c736A0EDB6
#   lpTokenSymbol	: pxsteth
#   lpTokenName	: pxETH/stETH
#   autopool	: {'name': 'Tokemak autoETH', 'autopool_eth_addr': '0x0A2b94F6871c1D7A32Fe58E1ab5e6deA2f114E56', 'autopool_eth_strategy_addr': '0xf5f6addB08c5e6091e5FdEc7326B21bEEd942235', 'solver_rebalance_plans_bucket': 'v2-gen3-eth-mainnet-solve-v2gen3ethmainnetsolverau-7ju0ra8aoznh'}
#   vault_name	: pxsteth (curve),
#  Destination Details:
#   vaultAddress	: 0xbA1462f43c6f60ebD1C62735c94E428aD073E01A
#   exchangeName	: curve
#   dexPool	: 0xC8Eb2Cf2f792F77AF0Cd9e203305a585E588179D
#   lpTokenAddress	: 0xC8Eb2Cf2f792F77AF0Cd9e203305a585E588179D
#   lpTokenSymbol	: pxethweth
#   lpTokenName	: pxETH/wETH
#   autopool	: {'name': 'Tokemak autoETH', 'autopool_eth_addr': '0x0A2b94F6871c1D7A32Fe58E1ab5e6deA2f114E56', 'autopool_eth_strategy_addr': '0xf5f6addB08c5e6091e5FdEc7326B21bEEd942235', 'solver_rebalance_plans_bucket': 'v2-gen3-eth-mainnet-solve-v2gen3ethmainnetsolverau-7ju0ra8aoznh'}
#   vault_name	: pxethweth (curve),
#  Destination Details:
#   vaultAddress	: 0x49895f72fd9d0BF6BBb485C70CE38556de62b070
#   exchangeName	: curve
#   dexPool	: 0xe080027Bd47353b5D1639772b4a75E9Ed3658A0d
#   lpTokenAddress	: 0xe080027Bd47353b5D1639772b4a75E9Ed3658A0d
#   lpTokenSymbol	: osETH-rETH
#   lpTokenName	: osETH/rETH
#   autopool	: {'name': 'Tokemak autoETH', 'autopool_eth_addr': '0x0A2b94F6871c1D7A32Fe58E1ab5e6deA2f114E56', 'autopool_eth_strategy_addr': '0xf5f6addB08c5e6091e5FdEc7326B21bEEd942235', 'solver_rebalance_plans_bucket': 'v2-gen3-eth-mainnet-solve-v2gen3ethmainnetsolverau-7ju0ra8aoznh'}
#   vault_name	: osETH-rETH (curve),
#  Destination Details:
#   vaultAddress	: 0x2f2CC1bf461413014741dD68481dB4a3686DAC3D
#   exchangeName	: balancer
#   dexPool	: 0x596192bB6e41802428Ac943D2f1476C1Af25CC0E
#   lpTokenAddress	: 0x596192bB6e41802428Ac943D2f1476C1Af25CC0E
#   lpTokenSymbol	: ezETH-WETH-BPT
#   lpTokenName	: Balancer ezETH-WETH Stable Pool
#   autopool	: {'name': 'Balancer/Tokemak balETH', 'autopool_eth_addr': '0x6dC3ce9C57b20131347FDc9089D740DAf6eB34c5', 'autopool_eth_strategy_addr': '0xabe104560D0B390309bcF20b73Dca335457AA32e', 'solver_rebalance_plans_bucket': 'v2-gen3-eth-mainnet-solve-v2gen3ethmainnetsolverba-wx1snhldrupb'}
#   vault_name	: ezETH-WETH-BPT (balancer),
#  Destination Details:
#   vaultAddress	: 0x2f2CC1bf461413014741dD68481dB4a3686DAC3D
#   exchangeName	: balancer
#   dexPool	: 0x596192bB6e41802428Ac943D2f1476C1Af25CC0E
#   lpTokenAddress	: 0x596192bB6e41802428Ac943D2f1476C1Af25CC0E
#   lpTokenSymbol	: ezETH-WETH-BPT
#   lpTokenName	: Balancer ezETH-WETH Stable Pool
#   autopool	: {'name': 'Tokemak autoLRT', 'autopool_eth_addr': '0xE800e3760FC20aA98c5df6A9816147f190455AF3', 'autopool_eth_strategy_addr': '0x72a726c10220280049687E58B7b05fb03d579109', 'solver_rebalance_plans_bucket': 'v2-gen3-eth-mainnet-solve-v2gen3ethmainnetsolverau-cb9s4hq4f8sv'}
#   vault_name	: ezETH-WETH-BPT (balancer),
#  Destination Details:
#   vaultAddress	: 0x2B08137BeABd2454AD3631DEB754F97C5c93eB78
#   exchangeName	: curve
#   dexPool	: 0x9EfE1A1Cbd6Ca51Ee8319AFc4573d253C3B732af
#   lpTokenAddress	: 0x9EfE1A1Cbd6Ca51Ee8319AFc4573d253C3B732af
#   lpTokenSymbol	: wETHrETH
#   lpTokenName	: wETH/rETH
#   autopool	: {'name': 'Tokemak autoETH', 'autopool_eth_addr': '0x0A2b94F6871c1D7A32Fe58E1ab5e6deA2f114E56', 'autopool_eth_strategy_addr': '0xf5f6addB08c5e6091e5FdEc7326B21bEEd942235', 'solver_rebalance_plans_bucket': 'v2-gen3-eth-mainnet-solve-v2gen3ethmainnetsolverau-7ju0ra8aoznh'}
#   vault_name	: wETHrETH (curve),
#  Destination Details:
#   vaultAddress	: 0x0A2b94F6871c1D7A32Fe58E1ab5e6deA2f114E56
#   exchangeName	: tokemak
#   dexPool	: None
#   lpTokenAddress	: None
#   lpTokenSymbol	: None
#   lpTokenName	: None
#   autopool	: {'name': 'Tokemak autoETH', 'autopool_eth_addr': '0x0A2b94F6871c1D7A32Fe58E1ab5e6deA2f114E56', 'autopool_eth_strategy_addr': '0xf5f6addB08c5e6091e5FdEc7326B21bEEd942235', 'solver_rebalance_plans_bucket': 'v2-gen3-eth-mainnet-solve-v2gen3ethmainnetsolverau-7ju0ra8aoznh'}
#   vault_name	: autoETH (tokemak),
#  Destination Details:
#   vaultAddress	: 0xE93f9C1f6436c7dCb3FE094E13E58742E16ae848
#   exchangeName	: curve
#   dexPool	: 0x59Ab5a5b5d617E478a2479B0cAD80DA7e2831492
#   lpTokenAddress	: 0x59Ab5a5b5d617E478a2479B0cAD80DA7e2831492
#   lpTokenSymbol	: ethx-f
#   lpTokenName	: Curve.fi Factory Pool: ETHx-ETH
#   autopool	: {'name': 'Tokemak autoETH', 'autopool_eth_addr': '0x0A2b94F6871c1D7A32Fe58E1ab5e6deA2f114E56', 'autopool_eth_strategy_addr': '0xf5f6addB08c5e6091e5FdEc7326B21bEEd942235', 'solver_rebalance_plans_bucket': 'v2-gen3-eth-mainnet-solve-v2gen3ethmainnetsolverau-7ju0ra8aoznh'}
#   vault_name	: ethx-f (curve),
#  Destination Details:
#   vaultAddress	: 0xB6d68122428Dc1141467cB96791618615Ab9F746
#   exchangeName	: balancer
#   dexPool	: 0x7761b6E0Daa04E70637D81f1Da7d186C205C2aDE
#   lpTokenAddress	: 0x7761b6E0Daa04E70637D81f1Da7d186C205C2aDE
#   lpTokenSymbol	: rsETH / ETHx
#   lpTokenName	: Balancer rsETH / ETHx
#   autopool	: {'name': 'Balancer/Tokemak balETH', 'autopool_eth_addr': '0x6dC3ce9C57b20131347FDc9089D740DAf6eB34c5', 'autopool_eth_strategy_addr': '0xabe104560D0B390309bcF20b73Dca335457AA32e', 'solver_rebalance_plans_bucket': 'v2-gen3-eth-mainnet-solve-v2gen3ethmainnetsolverba-wx1snhldrupb'}
#   vault_name	: rsETH / ETHx (balancer),
#  Destination Details:
#   vaultAddress	: 0xB6d68122428Dc1141467cB96791618615Ab9F746
#   exchangeName	: balancer
#   dexPool	: 0x7761b6E0Daa04E70637D81f1Da7d186C205C2aDE
#   lpTokenAddress	: 0x7761b6E0Daa04E70637D81f1Da7d186C205C2aDE
#   lpTokenSymbol	: rsETH / ETHx
#   lpTokenName	: Balancer rsETH / ETHx
#   autopool	: {'name': 'Tokemak autoLRT', 'autopool_eth_addr': '0xE800e3760FC20aA98c5df6A9816147f190455AF3', 'autopool_eth_strategy_addr': '0x72a726c10220280049687E58B7b05fb03d579109', 'solver_rebalance_plans_bucket': 'v2-gen3-eth-mainnet-solve-v2gen3ethmainnetsolverau-cb9s4hq4f8sv'}
#   vault_name	: rsETH / ETHx (balancer),
#  Destination Details:
#   vaultAddress	: 0x777FAf85c8E5FC6f4332E56B989C5C94201A273C
#   exchangeName	: curve
#   dexPool	: 0xDB74dfDD3BB46bE8Ce6C33dC9D82777BCFc3dEd5
#   lpTokenAddress	: 0xDB74dfDD3BB46bE8Ce6C33dC9D82777BCFc3dEd5
#   lpTokenSymbol	: weeth-ng
#   lpTokenName	: weETH/WETH-ng
#   autopool	: {'name': 'Tokemak autoLRT', 'autopool_eth_addr': '0xE800e3760FC20aA98c5df6A9816147f190455AF3', 'autopool_eth_strategy_addr': '0x72a726c10220280049687E58B7b05fb03d579109', 'solver_rebalance_plans_bucket': 'v2-gen3-eth-mainnet-solve-v2gen3ethmainnetsolverau-cb9s4hq4f8sv'}
#   vault_name	:
H/wETH
#   autopool	: {'name': 'Tokemak autoETH', 'autopool_eth_addr': '0x0A2b94F6871c1D7A32Fe58E1ab5e6deA2f114E56', 'autopool_eth_strategy_addr': '0xf5f6addB08c5e6091e5FdEc7326B21bEEd942235', 'solver_rebalance_plans_bucket': 'v2-gen3-eth-mainnet-solve-v2gen3ethmainnetsolverau-7ju0ra8aoznh'}
#   vault_name	: pxethweth (curve),
#  Destination Details:
#   vaultAddress	: 0x60339056EC88996e41757E05a798310E46972cca
#   exchangeName	: balancer
#   dexPool	: 0x7761b6E0Daa04E70637D81f1Da7d186C205C2aDE
#   lpTokenAddress	: 0x7761b6E0Daa04E70637D81f1Da7d186C205C2aDE
#   lpTokenSymbol	: rsETH / ETHx
#   lpTokenName	: Balancer rsETH / ETHx
#   autopool	: {'name': 'Balancer/Tokemak balETH', 'autopool_eth_addr': '0x6dC3ce9C57b20131347FDc9089D740DAf6eB34c5', 'autopool_eth_strategy_addr': '0xabe104560D0B390309bcF20b73Dca335457AA32e', 'solver_rebalance_plans_bucket': 'v2-gen3-eth-mainnet-solve-v2gen3ethmainnetsolverba-wx1snhldrupb'}
#   vault_name	: rsETH / ETHx (balancer),
#  Destination Details:
#   vaultAddress	: 0x60339056EC88996e41757E05a798310E46972cca
#   exchangeName	: balancer
#   dexPool	: 0x7761b6E0Daa04E70637D81f1Da7d186C205C2aDE
#   lpTokenAddress	: 0x7761b6E0Daa04E70637D81f1Da7d186C205C2aDE
#   lpTokenSymbol	: rsETH / ETHx
#   lpTokenName	: Balancer rsETH / ETHx
#   autopool	: {'name': 'Tokemak autoLRT', 'autopool_eth_addr': '0xE800e3760FC20aA98c5df6A9816147f190455AF3', 'autopool_eth_strategy_addr': '0x72a726c10220280049687E58B7b05fb03d579109', 'solver_rebalance_plans_bucket': 'v2-gen3-eth-mainnet-solve-v2gen3ethmainnetsolverau-cb9s4hq4f8sv'}
#   vault_name	: rsETH / ETHx (balancer),
#  Destination Details:
#   vaultAddress	: 0x4F4bE87cFe874db2e248A787669a0D6E77f1F149
#   exchangeName	: balancer
#   dexPool	: 0xF7A826D47c8E02835D94fb0Aa40F0cC9505cb134
#   lpTokenAddress	: 0xF7A826D47c8E02835D94fb0Aa40F0cC9505cb134
#   lpTokenSymbol	: ECLP-wstETH-cbETH
#   lpTokenName	: Gyroscope ECLP wstETH/cbETH
#   autopool	: {'name': 'Tokemak autoETH', 'autopool_eth_addr': '0x0A2b94F6871c1D7A32Fe58E1ab5e6deA2f114E56', 'autopool_eth_strategy_addr': '0xf5f6addB08c5e6091e5FdEc7326B21bEEd942235', 'solver_rebalance_plans_bucket': 'v2-gen3-eth-mainnet-solve-v2gen3ethmainnetsolverau-7ju0ra8aoznh'}
#   vault_name	: ECLP-wstETH-cbETH (balancer),
#  Destination Details:
#   vaultAddress	: 0x4F4bE87cFe874db2e248A787669a0D6E77f1F149
#   exchangeName	: balancer
#   dexPool	: 0xF7A826D47c8E02835D94fb0Aa40F0cC9505cb134
#   lpTokenAddress	: 0xF7A826D47c8E02835D94fb0Aa40F0cC9505cb134
#   lpTokenSymbol	: ECLP-wstETH-cbETH
#   lpTokenName	: Gyroscope ECLP wstETH/cbETH
#   autopool	: {'name': 'Balancer/Tokemak balETH', 'autopool_eth_addr': '0x6dC3ce9C57b20131347FDc9089D740DAf6eB34c5', 'autopool_eth_strategy_addr': '0xabe104560D0B390309bcF20b73Dca335457AA32e', 'solver_rebalance_plans_bucket': 'v2-gen3-eth-mainnet-solve-v2gen3ethmainnetsolverba-wx1snhldrupb'}
#   vault_name	: ECLP-wstETH-cbETH (balancer),
#  Destination Details:
#   vaultAddress	: 0x90300b02b162F902B9629963830BcCCdeEd71113
#   exchangeName	: balancer
#   dexPool	: 0x848a5564158d84b8A8fb68ab5D004Fae11619A54
#   lpTokenAddress	: 0x848a5564158d84b8A8fb68ab5D004Fae11619A54
#   lpTokenSymbol	: weETH/ezETH/rswETH
#   lpTokenName	: Balancer weETH/ezETH/rswETH
#   autopool	: {'name': 'Balancer/Tokemak balETH', 'autopool_eth_addr': '0x6dC3ce9C57b20131347FDc9089D740DAf6eB34c5', 'autopool_eth_strategy_addr': '0xabe104560D0B390309bcF20b73Dca335457AA32e', 'solver_rebalance_plans_bucket': 'v2-gen3-eth-mainnet-solve-v2gen3ethmainnetsolverba-wx1snhldrupb'}
#   vault_name	: weETH/ezETH/rswETH (balancer),
#  Destination Details:
#   vaultAddress	: 0x90300b02b162F902B9629963830BcCCdeEd71113
#   exchangeName	: balancer
#   dexPool	: 0x848a5564158d84b8A8fb68ab5D004Fae11619A54
#   lpTokenAddress	: 0x848a5564158d84b8A8fb68ab5D004Fae11619A54
#   lpTokenSymbol	: weETH/ezETH/rswETH
#   lpTokenName	: Balancer weETH/ezETH/rswETH
#   autopool	: {'name': 'Tokemak autoLRT', 'autopool_eth_addr': '0xE800e3760FC20aA98c5df6A9816147f190455AF3', 'autopool_eth_strategy_addr': '0x72a726c10220280049687E58B7b05fb03d579109', 'solver_rebalance_plans_bucket': 'v2-gen3-eth-mainnet-solve-v2gen3ethmainnetsolverau-cb9s4hq4f8sv'}
#   vault_name	: weETH/ezETH/rswETH (balancer),
#  Destination Details:
#   vaultAddress	: 0x5593882d517886D190F47967168D2d68D8960F48
#   exchangeName	: balancer
#   dexPool	: 0x88794C65550DeB6b4087B7552eCf295113794410
#   lpTokenAddress	: 0x88794C65550DeB6b4087B7552eCf295113794410
#   lpTokenSymbol	: pxETH/wETH
#   lpTokenName	: Balancer pxETH/wETH StablePool
#   autopool	: {'name': 'Tokemak autoETH', 'autopool_eth_addr': '0x0A2b94F6871c1D7A32Fe58E1ab5e6deA2f114E56', 'autopool_eth_strategy_addr': '0xf5f6addB08c5e6091e5FdEc7326B21bEEd942235', 'solver_rebalance_plans_bucket': 'v2-gen3-eth-mainnet-solve-v2gen3ethmainnetsolverau-7ju0ra8aoznh'}
#   vault_name	: pxETH/wETH (balancer),
#  Destination Details:
#   vaultAddress	: 0x5593882d517886D190F47967168D2d68D8960F48
#   exchangeName	: balancer
#   dexPool	: 0x88794C65550DeB6b4087B7552eCf295113794410
#   lpTokenAddress	: 0x88794C65550DeB6b4087B7552eCf295113794410
#   lpTokenSymbol	: pxETH/wETH
#   lpTokenName	: Balancer pxETH/wETH StablePool
#   autopool	: {'name': 'Balancer/Tokemak balETH', 'autopool_eth_addr': '0x6dC3ce9C57b20131347FDc9089D740DAf6eB34c5', 'autopool_eth_strategy_addr': '0xabe104560D0B390309bcF20b73Dca335457AA32e', 'solver_rebalance_plans_bucket': 'v2-gen3-eth-mainnet-solve-v2gen3ethmainnetsolverba-wx1snhldrupb'}
#   vault_name	: pxETH/wETH (balancer),
#  Destination Details:
#   vaultAddress	: 0x896eCc16Ab4AFfF6cE0765A5B924BaECd7Fa455a
#   exchangeName	: curve
#   dexPool	: 0xe080027Bd47353b5D1639772b4a75E9Ed3658A0d
#   lpTokenAddress	: 0xe080027Bd47353b5D1639772b4a75E9Ed3658A0d
#   lpTokenSymbol	: osETH-rETH
#   lpTokenName	: osETH/rETH
#   autopool	: {'name': 'Tokemak autoETH', 'autopool_eth_addr': '0x0A2b94F6871c1D7A32Fe58E1ab5e6deA2f114E56', 'autopool_eth_strategy_addr': '0xf5f6addB08c5e6091e5FdEc7326B21bEEd942235', 'solver_rebalance_plans_bucket': 'v2-gen3-eth-mainnet-solve-v2gen3ethmainnetsolverau-7ju0ra8aoznh'}
#   vault_name	: osETH-rETH (curve),
#  Destination Details:
#   vaultAddress	: 0x6DcB6797b1C0442587c2ad79745ef7BB487Fc2E2
#   exchangeName	: balancer
#   dexPool	: 0xf01b0684C98CD7aDA480BFDF6e43876422fa1Fc1
#   lpTokenAddress	: 0xf01b0684C98CD7aDA480BFDF6e43876422fa1Fc1
#   lpTokenSymbol	: ECLP-wstETH-wETH
#   lpTokenName	: Gyroscope ECLP wstETH/wETH
#   autopool	: {'name': 'Tokemak autoETH', 'autopool_eth_addr': '0x0A2b94F6871c1D7A32Fe58E1ab5e6deA2f114E56', 'autopool_eth_strategy_addr': '0xf5f6addB08c5e6091e5FdEc7326B21bEEd942235', 'solver_rebalance_plans_bucket': 'v2-gen3-eth-mainnet-solve-v2gen3ethmainnetsolverau-7ju0ra8aoznh'}
#   vault_name	: ECLP-wstETH-wETH (balancer),
#  Destination Details:
#   vaultAddress	: 0x6DcB6797b1C0442587c2ad79745ef7BB487Fc2E2
#   exchangeName	: balancer
#   dexPool	: 0xf01b0684C98CD7aDA480BFDF6e43876422fa1Fc1
#   lpTokenAddress	: 0xf01b0684C98CD7aDA480BFDF6e43876422fa1Fc1
#   lpTokenSymbol	: ECLP-wstETH-wETH
#   lpTokenName	: Gyroscope ECLP wstETH/wETH
#   autopool	: {'name': 'Balancer/Tokemak balETH', 'autopool_eth_addr': '0x6dC3ce9C57b20131347FDc9089D740DAf6eB34c5', 'autopool_eth_strategy_addr': '0xabe104560D0B390309bcF20b73Dca335457AA32e', 'solver_rebalance_plans_bucket': 'v2-gen3-eth-mainnet-solve-v2gen3ethmainnetsolverba-wx1snhldrupb'}
#   vault_name	: ECLP-wstETH-wETH (balancer),
#  Destination Details:
#   vaultAddress	: 0x84844d8A8a13337b31CF01DC384c74C862FCd903
#   exchangeName	: balancer
#   dexPool	: 0x93d199263632a4EF4Bb438F1feB99e57b4b5f0BD
#   lpTokenAddress	: 0x93d199263632a4EF4Bb438F1feB99e57b4b5f0BD
#   lpTokenSymbol	: wstETH-WETH-BPT
#   lpTokenName	: Balancer wstETH-WETH Stable Pool
#   autopool	: {'name': 'Tokemak autoETH', 'autopool_eth_addr': '0x0A2b94F6871c1D7A32Fe58E1ab5e6deA2f114E56', 'autopool_eth_strategy_addr': '0xf5f6addB08c5e6091e5FdEc7326B21bEEd942235', 'solver_rebalance_plans_bucket': 'v2-gen3-eth-mainnet-solve-v2gen3ethmainnetsolverau-7ju0ra8aoznh'}
#   vault_name	: wstETH-WETH-BPT (balancer),
#  Destination Details:
#   vaultAddress	: 0x84844d8A8a13337b31CF01DC384c74C862FCd903
#   exchangeName	: balancer
#   dexPool	: 0x93d199263632a4EF4Bb438F1feB99e57b4b5f0BD
#   lpTokenAddress	: 0x93d199263632a4EF4Bb438F1feB99e57b4b5f0BD
#   lpTokenSymbol	: wstETH-WETH-BPT
#   lpTokenName	: Balancer wstETH-WETH Stable Pool
#   autopool	: {'name': 'Balancer/Tokemak balETH', 'autopool_eth_addr': '0x6dC3ce9C57b20131347FDc9089D740DAf6eB34c5', 'autopool_eth_strategy_addr': '0xabe104560D0B390309bcF20b73Dca335457AA32e', 'solver_rebalance_plans_bucket': 'v2-gen3-eth-mainnet-solve-v2gen3ethmainnetsolverba-wx1snhldrupb'}
#   vault_name	: wstETH-WETH-BPT (balancer),
#  Destination Details:
#   vaultAddress	: 0x6a8C6ff78082a2ae494EB9291DdC7254117298Ff
#   exchangeName	: curve
#   dexPool	: 0x9EfE1A1Cbd6Ca51Ee8319AFc4573d253C3B732af
#   lpTokenAddress	: 0x9EfE1A1Cbd6Ca51Ee8319AFc4573d253C3B732af
#   lpTokenSymbol	: wETHrETH
#   lpTokenName	: wETH/rETH
#   autopool	: {'name': 'Tokemak autoETH', 'autopool_eth_addr': '0x0A2b94F6871c1D7A32Fe58E1ab5e6deA2f114E56', 'autopool_eth_strategy_addr': '0xf5f6addB08c5e6091e5FdEc7326B21bEEd942235', 'solver_rebalance_plans_bucket': 'v2-gen3-eth-mainnet-solve-v2gen3ethmainnetsolverau-7ju0ra8aoznh'}
#   vault_name	: wETHrETH (curve),
#  Destination Details:
#   vaultAddress	: 0x013D82483C968cdbB4a8384754f5a5028b85dB6d
#   exchangeName	: balancer
#   dexPool	: 0xDACf5Fa19b1f720111609043ac67A9818262850c
#   lpTokenAddress	: 0xDACf5Fa19b1f720111609043ac67A9818262850c
#   lpTokenSymbol	: osETH/wETH-BPT
#   lpTokenName	: Balancer osETH/wETH StablePool
#   autopool	: {'name': 'Balancer/Tokemak balETH', 'autopool_eth_addr': '0x6dC3ce9C57b20131347FDc9089D740DAf6eB34c5', 'autopool_eth_strategy_addr': '0xabe104560D0B390309bcF20b73Dca335457AA32e', 'solver_rebalance_plans_bucket': 'v2-gen3-eth-mainnet-solve-v2gen3ethmainnetsolverba-wx1snhldrupb'}
#   vault_name	: osETH/wETH-BPT (balancer),
#  Destination Details:
#   vaultAddress	: 0x013D82483C968cdbB4a8384754f5a5028b85dB6d
#   exchangeName	: balancer
#   dexPool	: 0xDACf5Fa19b1f720111609043ac67A9818262850c
#   lpTokenAddress	: 0xDACf5Fa19b1f720111609043ac67A9818262850c
#   lpTokenSymbol	: osETH/wETH-BPT
#   lpTokenName	: Balancer osETH/wETH StablePool
#   autopool	: {'name': 'Tokemak autoETH', 'autopool_eth_addr': '0x0A2b94F6871c1D7A32Fe58E1ab5e6deA2f114E56', 'autopool_eth_strategy_addr': '0xf5f6addB08c5e6091e5FdEc7326B21bEEd942235', 'solver_rebalance_plans_bucket': 'v2-gen3-eth-mainnet-solve-v2gen3ethmainnetsolverau-7ju0ra8aoznh'}
#   vault_name	: osETH/wETH-BPT (balancer),
#  Destination Details:
#   vaultAddress	: 0xaD70ed6A904d38acD0BbE2D922279149cFEDb190
#   exchangeName	: curve
#   dexPool	: 0x9c3B46C0Ceb5B9e304FCd6D88Fc50f7DD24B31Bc
#   lpTokenAddress	: 0x9c3B46C0Ceb5B9e304FCd6D88Fc50f7DD24B31Bc
#   lpTokenSymbol	: frxeth-ng-f
#   lpTokenName	: Curve.fi Factory Plain Pool: frxETH/WETH
#   autopool	: {'name': 'Tokemak autoETH', 'autopool_eth_addr': '0x0A2b94F6871c1D7A32Fe58E1ab5e6deA2f114E56', 'autopool_eth_strategy_addr': '0xf5f6addB08c5e6091e5FdEc7326B21bEEd942235', 'solver_rebalance_plans_bucket': 'v2-gen3-eth-mainnet-solve-v2gen3ethmainnetsolverau-7ju0ra8aoznh'}
#   vault_name	: frxeth-ng-f (curve),
#  Destination Details:
#   vaultAddress	: 0xE800e3760FC20aA98c5df6A9816147f190455AF3
#   exchangeName	: tokemak
#   dexPool	: None
#   lpTokenAddress	: None
#   lpTokenSymbol	: None
#   lpTokenName	: None
#   autopool	: {'name': 'Tokemak autoLRT', 'autopool_eth_addr': '0xE800e3760FC20aA98c5df6A9816147f190455AF3', 'autopool_eth_strategy_addr': '0x72a726c10220280049687E58B7b05fb03d579109', 'solver_rebalance_plans_bucket': 'v2-gen3-eth-mainnet-solve-v2gen3ethmainnetsolverau-cb9s4hq4f8sv'}
#   vault_name	: autoLRT (tokemak),
#  Destination Details:
#   vaultAddress	: 0x5Ff56531f92f1e3f2bE616760F05e35caE630D91
#   exchangeName	: curve
#   dexPool	: 0x9EfE1A1Cbd6Ca51Ee8319AFc4573d253C3B732af
#   lpTokenAddress	: 0x9EfE1A1Cbd6Ca51Ee8319AFc4573d253C3B732af
#   lpTokenSymbol	: wETHrETH
#   lpTokenName	: wETH/rETH
#   autopool	: {'name': 'Tokemak autoETH', 'autopool_eth_addr': '0x0A2b94F6871c1D7A32Fe58E1ab5e6deA2f114E56', 'autopool_eth_strategy_addr': '0xf5f6addB08c5e6091e5FdEc7326B21bEEd942235', 'solver_rebalance_plans_bucket': 'v2-gen3-eth-mainnet-solve-v2gen3ethmainnetsolverau-7ju0ra8aoznh'}
#   vault_name	: wETHrETH (curve),
#  Destination Details:
#   vaultAddress	: 0x17216C32B9134343258B05807405db02BE030acd
#   exchangeName	: curve
#   dexPool	: 0xDB74dfDD3BB46bE8Ce6C33dC9D82777BCFc3dEd5
#   lpTokenAddress	: 0xDB74dfDD3BB46bE8Ce6C33dC9D82777BCFc3dEd5
#   lpTokenSymbol	: weeth-ng
#   lpTokenName	: weETH/WETH-ng
#   autopool	: {'name': 'Tokemak autoLRT', 'autopool_eth_addr': '0xE800e3760FC20aA98c5df6A9816147f190455AF3', 'autopool_eth_strategy_addr': '0x72a726c10220280049687E58B7b05fb03d579109', 'solver_rebalance_plans_bucket': 'v2-gen3-eth-mainnet-solve-v2gen3ethmainnetsolverau-cb9s4hq4f8sv'}
#   vault_name	: weeth-ng (curve),
#  Destination Details:
#   vaultAddress	: 0xFDa49984eb4eA4075b8b451032849347C633E94b
#   exchangeName	: balancer
#   dexPool	: 0xDACf5Fa19b1f720111609043ac67A9818262850c
#   lpTokenAddress	: 0xDACf5Fa19b1f720111609043ac67A9818262850c
#   lpTokenSymbol	: osETH/wETH-BPT
#   lpTokenName	: Balancer osETH/wETH StablePool
#   autopool	: {'name': 'Tokemak autoETH', 'autopool_eth_addr': '0x0A2b94F6871c1D7A32Fe58E1ab5e6deA2f114E56', 'autopool_eth_strategy_addr': '0xf5f6addB08c5e6091e5FdEc7326B21bEEd942235', 'solver_rebalance_plans_bucket': 'v2-gen3-eth-mainnet-solve-v2gen3ethmainnetsolverau-7ju0ra8aoznh'}
#   vault_name	: osETH/wETH-BPT (balancer),
#  Destination Details:
#   vaultAddress	: 0xFDa49984eb4eA4075b8b451032849347C633E94b
#   exchangeName	: balancer
#   dexPool	: 0xDACf5Fa19b1f720111609043ac67A9818262850c
#   lpTokenAddress	: 0xDACf5Fa19b1f720111609043ac67A9818262850c
#   lpTokenSymbol	: osETH/wETH-BPT
#   lpTokenName	: Balancer osETH/wETH StablePool
#   autopool	: {'name': 'Balancer/Tokemak balETH', 'autopool_eth_addr': '0x6dC3ce9C57b20131347FDc9089D740DAf6eB34c5', 'autopool_eth_strategy_addr': '0xabe104560D0B390309bcF20b73Dca335457AA32e', 'solver_rebalance_plans_bucket': 'v2-gen3-eth-mainnet-solve-v2gen3ethmainnetsolverba-wx1snhldrupb'}
#   vault_name	: osETH/wETH-BPT (balancer),
#  Destination Details:
#   vaultAddress	: 0x92294A62D6D9F0FbE30Ba3B543edb1806561baD7
#   exchangeName	: balancer
#   dexPool	: 0xF7A826D47c8E02835D94fb0Aa40F0cC9505cb134
#   lpTokenAddress	: 0xF7A826D47c8E02835D94fb0Aa40F0cC9505cb134
#   lpTokenSymbol	: ECLP-wstETH-cbETH
#   lpTokenName	: Gyroscope ECLP wstETH/cbETH
#   autopool	: {'name': 'Tokemak autoETH', 'autopool_eth_addr': '0x0A2b94F6871c1D7A32Fe58E1ab5e6deA2f114E56', 'autopool_eth_strategy_addr': '0xf5f6addB08c5e6091e5FdEc7326B21bEEd942235', 'solver_rebalance_plans_bucket': 'v2-gen3-eth-mainnet-solve-v2gen3ethmainnetsolverau-7ju0ra8aoznh'}
#   vault_name	: ECLP-wstETH-cbETH (balancer),
#  Destination Details:
#   vaultAddress	: 0x92294A62D6D9F0FbE30Ba3B543edb1806561baD7
#   exchangeName	: balancer
#   dexPool	: 0xF7A826D47c8E02835D94fb0Aa40F0cC9505cb134
#   lpTokenAddress	: 0xF7A826D47c8E02835D94fb0Aa40F0cC9505cb134
#   lpTokenSymbol	: ECLP-wstETH-cbETH
#   lpTokenName	: Gyroscope ECLP wstETH/cbETH
#   autopool	: {'name': 'Balancer/Tokemak balETH', 'autopool_eth_addr': '0x6dC3ce9C57b20131347FDc9089D740DAf6eB34c5', 'autopool_eth_strategy_addr': '0xabe104560D0B390309bcF20b73Dca335457AA32e', 'solver_rebalance_plans_bucket': 'v2-gen3-eth-mainnet-solve-v2gen3ethmainnetsolverba-wx1snhldrupb'}
#   vault_name	: ECLP-wstETH-cbETH (balancer),
#  Destination Details:
#   vaultAddress	: 0x003aD6a060a1082B7A6F85d24dDF9E9E196B8426
#   exchangeName	: balancer
#   dexPool	: 0xf01b0684C98CD7aDA480BFDF6e43876422fa1Fc1
#   lpTokenAddress	: 0xf01b0684C98CD7aDA480BFDF6e43876422fa1Fc1
#   lpTokenSymbol	: ECLP-wstETH-wETH
#   lpTokenName	: Gyroscope ECLP wstETH/wETH
#   autopool	: {'name': 'Tokemak autoETH', 'autopool_eth_addr': '0x0A2b94F6871c1D7A32Fe58E1ab5e6deA2f114E56', 'autopool_eth_strategy_addr': '0xf5f6addB08c5e6091e5FdEc7326B21bEEd942235', 'solver_rebalance_plans_bucket': 'v2-gen3-eth-mainnet-solve-v2gen3ethmainnetsolverau-7ju0ra8aoznh'}
#   vault_name	: ECLP-wstETH-wETH (balancer),
#  Destination Details:
#   vaultAddress	: 0x003aD6a060a1082B7A6F85d24dDF9E9E196B8426
#   exchangeName	: balancer
#   dexPool	: 0xf01b0684C98CD7aDA480BFDF6e43876422fa1Fc1
#   lpTokenAddress	: 0xf01b0684C98CD7aDA480BFDF6e43876422fa1Fc1
#   lpTokenSymbol	: ECLP-wstETH-wETH
#   lpTokenName	: Gyroscope ECLP wstETH/wETH
#   autopool	: {'name': 'Balancer/Tokemak balETH', 'autopool_eth_addr': '0x6dC3ce9C57b20131347FDc9089D740DAf6eB34c5', 'autopool_eth_strategy_addr': '0xabe104560D0B390309bcF20b73Dca335457AA32e', 'solver_rebalance_plans_bucket': 'v2-gen3-eth-mainnet-solve-v2gen3ethmainnetsolverba-wx1snhldrupb'}
#   vault_name	: ECLP-wstETH-wETH (balancer),
#  Destination Details:
#   vaultAddress	: 0xf9779aEF9f77e78C857CB4A068c65CcBee25BAAc
#   exchangeName	: balancer
#   dexPool	: 0x58AAdFB1Afac0ad7fca1148f3cdE6aEDF5236B6D
#   lpTokenAddress	: 0x58AAdFB1Afac0ad7fca1148f3cdE6aEDF5236B6D
#   lpTokenSymbol	: rsETH / WETH
#   lpTokenName	: Balancer rsETH-WETH Stable Pool
#   autopool	: {'name': 'Balancer/Tokemak balETH', 'autopool_eth_addr': '0x6dC3ce9C57b20131347FDc9089D740DAf6eB34c5', 'autopool_eth_strategy_addr': '0xabe104560D0B390309bcF20b73Dca335457AA32e', 'solver_rebalance_plans_bucket': 'v2-gen3-eth-mainnet-solve-v2gen3ethmainnetsolverba-wx1snhldrupb'}
#   vault_name	: rsETH / WETH (balancer),
#  Destination Details:
#   vaultAddress	: 0xf9779aEF9f77e78C857CB4A068c65CcBee25BAAc
#   exchangeName	: balancer
#   dexPool	: 0x58AAdFB1Afac0ad7fca1148f3cdE6aEDF5236B6D
#   lpTokenAddress	: 0x58AAdFB1Afac0ad7fca1148f3cdE6aEDF5236B6D
#   lpTokenSymbol	: rsETH / WETH
#   lpTokenName	: Balancer rsETH-WETH Stable Pool
#   autopool	: {'name': 'Tokemak autoLRT', 'autopool_eth_addr': '0xE800e3760FC20aA98c5df6A9816147f190455AF3', 'autopool_eth_strategy_addr': '0x72a726c10220280049687E58B7b05fb03d579109', 'solver_rebalance_plans_bucket': 'v2-gen3-eth-mainnet-solve-v2gen3ethmainnetsolverau-cb9s4hq4f8sv'}
#   vault_name	: rsETH / WETH (balancer),
#  Destination Details:
#   vaultAddress	: 0x148Ca723BefeA7b021C399413b8b7426A4701500
#   exchangeName	: balancer
#   dexPool	: 0x05ff47AFADa98a98982113758878F9A8B9FddA0a
#   lpTokenAddress	: 0x05ff47AFADa98a98982113758878F9A8B9FddA0a
#   lpTokenSymbol	: weETH/rETH
#   lpTokenName	: Balancer weETH/rETH StablePool
#   autopool	: {'name': 'Tokemak autoLRT', 'autopool_eth_addr': '0xE800e3760FC20aA98c5df6A9816147f190455AF3', 'autopool_eth_strategy_addr': '0x72a726c10220280049687E58B7b05fb03d579109', 'solver_rebalance_plans_bucket': 'v2-gen3-eth-mainnet-solve-v2gen3ethmainnetsolverau-cb9s4hq4f8sv'}
#   vault_name	: weETH/rETH (balancer),
#  Destination Details:
#   vaultAddress	: 0x3B2C87Ed95483059b950155a68E906d543193d5C
#   exchangeName	: balancer
#   dexPool	: 0x05ff47AFADa98a98982113758878F9A8B9FddA0a
#   lpTokenAddress	: 0x05ff47AFADa98a98982113758878F9A8B9FddA0a
#   lpTokenSymbol	: weETH/rETH
#   lpTokenName	: Balancer weETH/rETH StablePool
#   autopool	: {'name': 'Balancer/Tokemak balETH', 'autopool_eth_addr': '0x6dC3ce9C57b20131347FDc9089D740DAf6eB34c5', 'autopool_eth_strategy_addr': '0xabe104560D0B390309bcF20b73Dca335457AA32e', 'solver_rebalance_plans_bucket': 'v2-gen3-eth-mainnet-solve-v2gen3ethmainnetsolverba-wx1snhldrupb'}
#   vault_name	: weETH/rETH (balancer),
#  Destination Details:
#   vaultAddress	: 0x3B2C87Ed95483059b950155a68E906d543193d5C
#   exchangeName	: balancer
#   dexPool	: 0x05ff47AFADa98a98982113758878F9A8B9FddA0a
#   lpTokenAddress	: 0x05ff47AFADa98a98982113758878F9A8B9FddA0a
#   lpTokenSymbol	: weETH/rETH
#   lpTokenName	: Balancer weETH/rETH StablePool
#   autopool	: {'name': 'Tokemak autoLRT', 'autopool_eth_addr': '0xE800e3760FC20aA98c5df6A9816147f190455AF3', 'autopool_eth_strategy_addr': '0x72a726c10220280049687E58B7b05fb03d579109', 'solver_rebalance_plans_bucket': 'v2-gen3-eth-mainnet-solve-v2gen3ethmainnetsolverau-cb9s4hq4f8sv'}
#   vault_name	: weETH/rETH (balancer),
#  Destination Details:
#   vaultAddress	: 0x689dc7B5CE8e23061a8223E97701E9345764B8B7
#   exchangeName	: balancer
#   dexPool	: 0x596192bB6e41802428Ac943D2f1476C1Af25CC0E
#   lpTokenAddress	: 0x596192bB6e41802428Ac943D2f1476C1Af25CC0E
#   lpTokenSymbol	: ezETH-WETH-BPT
#   lpTokenName	: Balancer ezETH-WETH Stable Pool
#   autopool	: {'name': 'Balancer/Tokemak balETH', 'autopool_eth_addr': '0x6dC3ce9C57b20131347FDc9089D740DAf6eB34c5', 'autopool_eth_strategy_addr': '0xabe104560D0B390309bcF20b73Dca335457AA32e', 'solver_rebalance_plans_bucket': 'v2-gen3-eth-mainnet-solve-v2gen3ethmainnetsolverba-wx1snhldrupb'}
#   vault_name	: ezETH-WETH-BPT (balancer),
#  Destination Details:
#   vaultAddress	: 0x689dc7B5CE8e23061a8223E97701E9345764B8B7
#   exchangeName	: balancer
#   dexPool	: 0x596192bB6e41802428Ac943D2f1476C1Af25CC0E
#   lpTokenAddress	: 0x596192bB6e41802428Ac943D2f1476C1Af25CC0E
#   lpTokenSymbol	: ezETH-WETH-BPT
#   lpTokenName	: Balancer ezETH-WETH Stable Pool
#   autopool	: {'name': 'Tokemak autoLRT', 'autopool_eth_addr': '0xE800e3760FC20aA98c5df6A9816147f190455AF3', 'autopool_eth_strategy_addr': '0x72a726c10220280049687E58B7b05fb03d579109', 'solver_rebalance_plans_bucket': 'v2-gen3-eth-mainnet-solve-v2gen3ethmainnetsolverau-cb9s4hq4f8sv'}
#   vault_name	: ezETH-WETH-BPT (balancer),
#  Destination Details:
#   vaultAddress	: 0x4E12227b350E8f8fEEc41A58D36cE2fB2e2d4575
#   exchangeName	: balancer
#   dexPool	: 0x58AAdFB1Afac0ad7fca1148f3cdE6aEDF5236B6D
#   lpTokenAddress	: 0x58AAdFB1Afac0ad7fca1148f3cdE6aEDF5236B6D
#   lpTokenSymbol	: rsETH / WETH
#   lpTokenName	: Balancer rsETH-WETH Stable Pool
#   autopool	: {'name': 'Balancer/Tokemak balETH', 'autopool_eth_addr': '0x6dC3ce9C57b20131347FDc9089D740DAf6eB34c5', 'autopool_eth_strategy_addr': '0xabe104560D0B390309bcF20b73Dca335457AA32e', 'solver_rebalance_plans_bucket': 'v2-gen3-eth-mainnet-solve-v2gen3ethmainnetsolverba-wx1snhldrupb'}
#   vault_name	: rsETH / WETH (balancer),
#  Destination Details:
#   vaultAddress	: 0xC001f23397dB71B17602Ce7D90a983Edc38DB0d1
#   exchangeName	: curve
#   dexPool	: 0x59Ab5a5b5d617E478a2479B0cAD80DA7e2831492
#   lpTokenAddress	: 0x59Ab5a5b5d617E478a2479B0cAD80DA7e2831492
#   lpTokenSymbol	: ethx-f
#   lpTokenName	: Curve.fi Factory Pool: ETHx-ETH
#   autopool	: {'name': 'Tokemak autoETH', 'autopool_eth_addr': '0x0A2b94F6871c1D7A32Fe58E1ab5e6deA2f114E56', 'autopool_eth_strategy_addr': '0xf5f6addB08c5e6091e5FdEc7326B21bEEd942235', 'solver_rebalance_plans_bucket': 'v2-gen3-eth-mainnet-solve-v2gen3ethmainnetsolverau-7ju0ra8aoznh'}
#   vault_name	: ethx-f (curve),
#  Destination Details:
#   vaultAddress	: 0x4E12227b350E8f8fEEc41A58D36cE2fB2e2d4575
#   exchangeName	: balancer
#   dexPool	: 0x58AAdFB1Afac0ad7fca1148f3cdE6aEDF5236B6D
#   lpTokenAddress	: 0x58AAdFB1Afac0ad7fca1148f3cdE6aEDF5236B6D
#   lpTokenSymbol	: rsETH / WETH
#   lpTokenName	: Balancer rsETH-WETH Stable Pool
#   autopool	: {'name': 'Tokemak autoLRT', 'autopool_eth_addr': '0xE800e3760FC20aA98c5df6A9816147f190455AF3', 'autopool_eth_strategy_addr': '0x72a726c10220280049687E58B7b05fb03d579109', 'solver_rebalance_plans_bucket': 'v2-gen3-eth-mainnet-solve-v2gen3ethmainnetsolverau-cb9s4hq4f8sv'}
#   vault_name	: rsETH / WETH (balancer),
#  Destination Details:
#   vaultAddress	: 0xB84c580c005A5F633C8CF6eecAf5b0a8314EC5c4
#   exchangeName	: curve
#   dexPool	: 0x6951bDC4734b9f7F3E1B74afeBC670c736A0EDB6
#   lpTokenAddress	: 0x6951bDC4734b9f7F3E1B74afeBC670c736A0EDB6
#   lpTokenSymbol	: pxsteth
#   lpTokenName	: pxETH/stETH
#   autopool	: {'name': 'Tokemak autoETH', 'autopool_eth_addr': '0x0A2b94F6871c1D7A32Fe58E1ab5e6deA2f114E56', 'autopool_eth_strategy_addr': '0xf5f6addB08c5e6091e5FdEc7326B21bEEd942235', 'solver_rebalance_plans_bucket': 'v2-gen3-eth-mainnet-solve-v2gen3ethmainnetsolverau-7ju0ra8aoznh'}
#   vault_name	: pxsteth (curve),
#  Destination Details:
#   vaultAddress	: 0x3F55eedDe51504E6Ed0ec30E8289b4Da11EdB7F9
#   exchangeName	: curve
#   dexPool	: 0xe080027Bd47353b5D1639772b4a75E9Ed3658A0d
#   lpTokenAddress	: 0xe080027Bd47353b5D1639772b4a75E9Ed3658A0d
#   lpTokenSymbol	: osETH-rETH
#   lpTokenName	: osETH/rETH
#   autopool	: {'name': 'Tokemak autoETH', 'autopool_eth_addr': '0x0A2b94F6871c1D7A32Fe58E1ab5e6deA2f114E56', 'autopool_eth_strategy_addr': '0xf5f6addB08c5e6091e5FdEc7326B21bEEd942235', 'solver_rebalance_plans_bucket': 'v2-gen3-eth-mainnet-solve-v2gen3ethmainnetsolverau-7ju0ra8aoznh'}
#   vault_name	: osETH-rETH (curve),
#  Destination Details:
#   vaultAddress	: 0x2899143298FECa3a36DAfDDcddAF167f1D673254
#   exchangeName	: balancer
#   dexPool	: 0xB91159aa527D4769CB9FAf3e4ADB760c7E8C8Ea7
#   lpTokenAddress	: 0xB91159aa527D4769CB9FAf3e4ADB760c7E8C8Ea7
#   lpTokenSymbol	: ETHx/wstETH
#   lpTokenName	: Balancer ETHx/wstETH
#   autopool	: {'name': 'Tokemak autoETH', 'autopool_eth_addr': '0x0A2b94F6871c1D7A32Fe58E1ab5e6deA2f114E56', 'autopool_eth_strategy_addr': '0xf5f6addB08c5e6091e5FdEc7326B21bEEd942235', 'solver_rebalance_plans_bucket': 'v2-gen3-eth-mainnet-solve-v2gen3ethmainnetsolverau-7ju0ra8aoznh'}
#   vault_name	: ETHx/wstETH (balancer),
#  Destination Details:
#   vaultAddress	: 0x2899143298FECa3a36DAfDDcddAF167f1D673254
#   exchangeName	: balancer
#   dexPool	: 0xB91159aa527D4769CB9FAf3e4ADB760c7E8C8Ea7
#   lpTokenAddress	: 0xB91159aa527D4769CB9FAf3e4ADB760c7E8C8Ea7
#   lpTokenSymbol	: ETHx/wstETH
#   lpTokenName	: Balancer ETHx/wstETH
#   autopool	: {'name': 'Balancer/Tokemak balETH', 'autopool_eth_addr': '0x6dC3ce9C57b20131347FDc9089D740DAf6eB34c5', 'autopool_eth_strategy_addr': '0xabe104560D0B390309bcF20b73Dca335457AA32e', 'solver_rebalance_plans_bucket': 'v2-gen3-eth-mainnet-solve-v2gen3ethmainnetsolverba-wx1snhldrupb'}
#   vault_name	: ETHx/wstETH (balancer),
#  Destination Details:
#   vaultAddress	: 0x148Ca723BefeA7b021C399413b8b7426A4701500
#   exchangeName	: balancer
#   dexPool	: 0x05ff47AFADa98a98982113758878F9A8B9FddA0a
#   lpTokenAddress	: 0x05ff47AFADa98a98982113758878F9A8B9FddA0a
#   lpTokenSymbol	: weETH/rETH
#   lpTokenName	: Balancer weETH/rETH StablePool
#   autopool	: {'name': 'Balancer/Tokemak balETH', 'autopool_eth_addr': '0x6dC3ce9C57b20131347FDc9089D740DAf6eB34c5', 'autopool_eth_strategy_addr': '0xabe104560D0B390309bcF20b73Dca335457AA32e', 'solver_rebalance_plans_bucket': 'v2-gen3-eth-mainnet-solve-v2gen3ethmainnetsolverba-wx1snhldrupb'}
#   vault_name	: weETH/rETH (balancer)]

# %%
from mainnet_launch.data_fetching.get_state_by_block import (
    get_raw_state_by_blocks,
    get_state_by_one_block,
    identity_with_bool_success,
    safe_normalize_with_bool_success,
    build_blocks_to_use,
)


def _handle_strader_exchange_rate(success, data):
    if success:
        reportingBlockNumber, totalETHBalance, totalETHXSupply = data
        return totalETHBalance / totalETHXSupply


STRADER_ETHX_ORACLE = "0xF64bAe65f6f2a5277571143A24FaaFDFC0C2a737"


def build_ethx_starder_echange_rate_call(name: str) -> Call:
    return Call(
        STRADER_ETHX_ORACLE,
        ["exchangeRate()((uint256,uint256,uint256))"],
        [(name, _handle_strader_exchange_rate)],
    )


calls = [
    build_get_virtual_price_call("vp", "0x59Ab5a5b5d617E478a2479B0cAD80DA7e2831492"),
    build_ethx_starder_echange_rate_call("ETHx"),
]
block_with_change = 21060971
get_state_by_one_block(calls, block_with_change - 1), get_state_by_one_block(calls, block_with_change)
# Out:
# ({'vp': 1028604851801098903, 'ETHx': 1.0436965132372493},
#  {'vp': 1028648539896558311, 'ETHx': 1.0437679045195043})

# %%
block_with_change in TokenExchange["block"], block_with_change - 1 in TokenExchange["block"]
# Out:
# (False, False)

# %%
for k, df in events.items():
    print(k, block_with_change in df["block"], block_with_change - 1 in df["block"])
# Out:
# Transfer False False
# Approval False False
# TokenExchange False False
# AddLiquidity False False
# RemoveLiquidity False False
# RemoveLiquidityOne False False
# RemoveLiquidityImbalance False False
# RampA False False
# StopRampA False False
# CommitNewFee False False
# ApplyNewFee False False

# %%
[d.vaultAddress for d in destination_details if "wstETH-WETH-BPT" in d.vault_name]
# Out:
# ['0x25cb41919d6B88e0D48108A4F5fe8FBb3744aFE1',
#  '0x25cb41919d6B88e0D48108A4F5fe8FBb3744aFE1',
#  '0x5A4B544B9734930DDC587c9a2f093dC5058A4f4D',
#  '0x5A4B544B9734930DDC587c9a2f093dC5058A4f4D',
#  '0x84844d8A8a13337b31CF01DC384c74C862FCd903',
#  '0x84844d8A8a13337b31CF01DC384c74C862FCd903']

# %%
events.keys()
# Out:
# dict_keys(['Transfer', 'Approval', 'TokenExchange', 'AddLiquidity', 'RemoveLiquidity', 'RemoveLiquidityOne', 'RemoveLiquidityImbalance', 'RampA', 'StopRampA', 'CommitNewFee', 'ApplyNewFee'])

# %%
The

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
100 * (15_000 / 12_000_000)
# Out:
# 0.125

# %%
from mainnet_launch.constants import CACHE_TIME, ALL_AUTOPOOLS, eth_client, LENS_CONTRACT
from mainnet_launch.data_fetching.get_state_by_block import (
    get_raw_state_by_blocks,
    get_state_by_one_block,
    identity_with_bool_success,
    safe_normalize_with_bool_success,
    build_blocks_to_use,
)


def _clean_summary_stats_info(success, summary_stats):
    if success is True:
        summary = {
            "destination": summary_stats[0],
            "baseApr": summary_stats[1] / 1e18,
            "feeApr": summary_stats[2] / 1e18,
            "incentiveApr": summary_stats[3] / 1e18,
            "safeTotalSupply": summary_stats[4] / 1e18,
            "priceReturn": summary_stats[5] / 1e18,
            "maxDiscount": summary_stats[6] / 1e18,
            "maxPremium": summary_stats[7] / 1e18,
            "ownedShares": summary_stats[8] / 1e18,
            "compositeReturn": summary_stats[9] / 1e18,
            "pricePerShare": summary_stats[10] / 1e18,
        }
        return summary
    else:
        return None


def build_proxyGetDestinationSummaryStats_call(
    name: str, autopool_strategy_address: str, destination_address: str, direction: str, amount: int
) -> Call:
    if direction == "in":
        direction_enum = 0
    elif direction == "out":
        direction_enum = 1
    else:
        raise ValueError(f"direction can only be `in` or `out` is {direction=}")

    return Call(
        LENS_CONTRACT,
        [
            f"proxyGetDestinationSummaryStats(address,address,uint8,uint256)((address,uint256,uint256,uint256,uint256,int256,int256,int256,uint256,int256,uint256))",
            autopool_strategy_address,
            destination_address,
            direction_enum,
            amount,
        ],
        [(name, _clean_summary_stats_info)],
    )


def build_all_proxyGetDestinationSummaryStats_calls(autopool: AutopoolConstants) -> list[Call]:
    destination_details = get_destination_details()
    all_of_this_autopools_destinations = [dest for dest in destination_details if dest.autopool == autopool]
    # include a check that the unqiue vaultAddress == len(all_of_this_autopools_destinations)

    calls = [
        build_proxyGetDestinationSummaryStats_call(
            name=dest.vaultAddress,
            autopool_strategy_address=dest.autopool.autopool_eth_strategy_addr,
            destination_address=dest.vaultAddress,
            direction="out",
            amount=0,
        )
        for dest in all_of_this_autopools_destinations
    ]  # for each autopool the destination vault address is unique

    return calls


def fetch_destination_summary_stats(blocks: list[int], autopool: AutopoolConstants):
    calls = build_all_proxyGetDestinationSummaryStats_calls(autopool)

    calls.append(get_pools_and_destinations_call())
    summary_stats_df = get_raw_state_by_blocks(calls, blocks)

    return summary_stats_df


# I think this works but the warnings are a problem, need to fix unsure how
blocks = build_blocks_to_use()
df = fetch_destination_summary_stats(blocks, AUTO_LRT)
df
# Out:
# 2024-10-11 19:38:44.221 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:44
\
# timestamp
# 2024-09-15 02:04:47  {'destination': '0xe800e3760fc20aa98c5df6a9816...
# 2024-09-15 05:44:35  {'destination': '0xe800e3760fc20aa98c5df6a9816...
# 2024-09-15 09:24:47  {'destination': '0xe800e3760fc20aa98c5df6a9816...
# 2024-09-15 13:04:11  {'destination': '0xe800e3760fc20aa98c5df6a9816...
# 2024-09-15 16:44:23  {'destination': '0xe800e3760fc20aa98c5df6a9816...
# ...                                                                ...
# 2024-10-11 08:40:59  {'destination': '0xe800e3760fc20aa98c5df6a9816...
# 2024-10-11 12:21:35  {'destination': '0xe800e3760fc20aa98c5df6a9816...
# 2024-10-11 16:02:35  {'destination': '0xe800e3760fc20aa98c5df6a9816...
# 2024-10-11 19:42:47  {'destination': '0xe800e3760fc20aa98c5df6a9816...
# 2024-10-11 23:23:35  {'destination': '0xe800e3760fc20aa98c5df6a9816...
#
#                             0xb6d68122428dc1141467cb96791618615ab9f746  \
# timestamp
# 2024-09-15 02:04:47  {'destination': '0xb6d68122428dc1141467cb96791...
# 2024-09-15 05:44:35  {'destination': '0xb6d68122428dc1141467cb96791...
# 2024-09-15 09:24:47  {'destination': '0xb6d68122428dc1141467cb96791...
# 2024-09-15 13:04:11  {'destination': '0xb6d68122428dc1141467cb96791...
# 2024-09-15 16:44:23  {'destination': '0xb6d68122428dc1141467cb96791...
# ...                                                                ...
# 2024-10-11 08:40:59  {'destination': '0xb6d68122428dc1141467cb96791...
# 2024-10-11 12:21:35  {'destination': '0xb6d68122428dc1141467cb96791...
# 2024-10-11 16:02:35  {'destination': '0xb6d68122428dc1141467cb96791...
# 2024-10-11 19:42:47  {'destination': '0xb6d68122428dc1141467cb96791...
# 2024-10-11 23:23:35  {'destination': '0xb6d68122428dc1141467cb96791...
#
#                                                getPoolsAndDestinations
# timestamp
# 2024-09-15 02:04:47  {'autopools': [{'poolAddress': '0x0a2b94f6871c...
# 2024-09-15 05:44:35  {'autopools': [{'poolAddress': '0x0a2b94f6871c...
# 2024-09-15 09:24:47  {'autopools': [{'poolAddress': '0x0a2b94f6871c...
# 2024-09-15 13:04:11  {'autopools': [{'poolAddress': '0x0a2b94f6871c...
# 2024-09-15 16:44:23  {'autopools': [{'poolAddress': '0x0a2b94f6871c...
# ...                                                                ...
# 2024-10-11 08:40:59  {'autopools': [{'poolAddress': '0x0a2b94f6871c...
# 2024-10-11 12:21:35  {'autopools': [{'poolAddress': '0x0a2b94f6871c...
# 2024-10-11 16:02:35  {'autopools': [{'poolAddress': '0x0a2b94f6871c...
# 2024-10-11 19:42:47  {'autopools': [{'poolAddress': '0x0a2b94f6871c...
# 2024-10-11 23:23:35  {'autopools': [{'poolAddress': '0x0a2b94f6871c...
#
# [177 rows x 18 columns]

# %%
all_of_this_autopools_destinations = [dest for dest in destination_details if dest.autopool == AUTO_LRT]
duplciated_pool = [
    a
    for a in all_of_this_autopools_destinations
    if a.vault_name == "Tokemak-Wrapped Ether-Balancer rsETH-WETH Stable Pool"
]
duplciated_pool
# Out:
# [Destination Details:
#   Vaultaddress        	: 0x4e12227b350e8f8feec41a58d36ce2fb2e2d4575
#   Exchangename        	: balancer
#   Dexpool             	: 0x58aadfb1afac0ad7fca1148f3cde6aedf5236b6d
#   Lptokenaddress      	: 0x58aadfb1afac0ad7fca1148f3cde6aedf5236b6d
#   Lptokensymbol       	: rsETH / WETH
#   Lptokenname         	: Balancer rsETH-WETH Stable Pool
#   Autopool            	: {'name': 'autoLRT', 'autopool_eth_addr': '0xE800e3760FC20aA98c5df6A9816147f190455AF3', 'autopool_eth_strategy_addr': '0x72a726c10220280049687E58B7b05fb03d579109', 'solver_rebalance_plans_bucket': 'v2-gen3-eth-mainnet-solve-v2gen3ethmainnetsolverau-cb9s4hq4f8sv'}
#   Vault_Name          	: Tokemak-Wrapped Ether-Balancer rsETH-WETH Stable Pool,
#  Destination Details:
#   Vaultaddress        	: 0x676b34c2c2294ef070c1e9e0fcd4091dd06393fe
#   Exchangename        	: balancer
#   Dexpool             	: 0x58aadfb1afac0ad7fca1148f3cde6aedf5236b6d
#   Lptokenaddress      	: 0x58aadfb1afac0ad7fca1148f3cde6aedf5236b6d
#   Lptokensymbol       	: rsETH / WETH
#   Lptokenname         	: Balancer rsETH-WETH Stable Pool
#   Autopool            	: {'name': 'autoLRT', 'autopool_eth_addr': '0xE800e3760FC20aA98c5df6A9816147f190455AF3', 'autopool_eth_strategy_addr': '0x72a726c10220280049687E58B7b05fb03d579109', 'solver_rebalance_plans_bucket': 'v2-gen3-eth-mainnet-solve-v2gen3ethmainnetsolverau-cb9s4hq4f8sv'}
#   Vault_Name          	: Tokemak-Wrapped Ether-Balancer rsETH-WETH Stable Pool]

# %%
import warnings
from IPython.display import clear_output

destination_vault_address_cols = [d for d in df.columns if d != "getPoolsAndDestinations"]


def _replace_destination_summary_stats_of_destinations_not_linked_to_any_autopool_with_none(row: pd.Series) -> dict:
    # if a destination_vault is currently is the destinations returned by lens_contract.getPoolsAndDestinations() at that block
    # keep the data
    # otherwise set it to None

    # this is so that we only look at data for active destinations.
    # the isShutdown() method on DestinationVault is not used here.
    # 0x4e12227b350e8f8feec41a58d36ce2fb2e2d4575 0x676b34c2c2294ef070c1e9e0fcd4091dd06393fe are eact not shudown
    # but only one is actively allocated to. the other was deprecated
    # this logic is complicated. double check that it makes sense with cody

    # excess caching warnings here
    row_dict = row.to_dict()

    current_destination_vault_addresses = set()
    for list_of_destinations in row_dict["getPoolsAndDestinations"]["destinations"]:
        for destination in list_of_destinations:
            current_destination_vault_addresses.add(destination["vaultAddress"])

    clean_destination_summary_stats = dict()
    for destination_vault_address in destination_vault_address_cols:
        if destination_vault_address in current_destination_vault_addresses:
            vault_name = attempt_destination_address_to_vault_name(destination_vault_address)
            if vault_name in clean_destination_summary_stats:
                raise ValueError("should attempt to have more than one destination summary stat per destination")
            clean_destination_summary_stats[vault_name] = row_dict[destination_vault_address]

    return clean_destination_summary_stats


with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    clean_df = pd.DataFrame.from_records(
        df.apply(_replace_destination_summary_stats_of_destinations_not_linked_to_any_autopool_with_none, axis=1)
    )
    clear_output(wait=True)
    clean_df
# Out:
# 2024-10-11 19:38:48.425 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.425 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.426 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.426 No runtime found, using MemoryCacheStorageManager
# 2024-10-11 19:38:48.427 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.427 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.427 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.428 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.429 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.432 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.433 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.433 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.434 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.434 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.435 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.436 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.436 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.437 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.437 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.440 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.441 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.441 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.442 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.442 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.443 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.443 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.443 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.444 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.445 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.448 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.450 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.451 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.451 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.452 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.453 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.453 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.453 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.454 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.455 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.457 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.458 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.458 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.459 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.459 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.460 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.460 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.460 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.461 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.461 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.465 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.466 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.466 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.467 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.468 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.469 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.469 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.470 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.471 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.471 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.474 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.474 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.475 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.475 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.475 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.476 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.476 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.477 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.477 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.478 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.479 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.479 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.480 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.480 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.481 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.482 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.482 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.483 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.483 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.484 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.485 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.486 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.487 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.487 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.488 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.489 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.489 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.489 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.489 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.490 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.491 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.491 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.492 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.492 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.492 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.493 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.493 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.493 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.493 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.494 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.494 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.494 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.495 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.495 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.495 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.496 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.496 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.496 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.496 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.496 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.497 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.497 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.498 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.498 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.499 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.500 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.500 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.501 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.502 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.502 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.504 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.504 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.505 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.506 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.506 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.507 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.508 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.508 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.509 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.509 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.510 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.510 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.511 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.511 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.511 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.512 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.512 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.513 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.513 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.514 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.516 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.517 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.518 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.518 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.519 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.520 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.520 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.520 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.520 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.521 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.521 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.522 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.522 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.522 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.522 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.524 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.525 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.525 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.526 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.527 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.532 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.533 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.533 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.534 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.534 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.536 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.536 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.537 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.538 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.538 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.541 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.541 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.542 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.542 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.542 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.543 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.543 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.544 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.544 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.545 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.548 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.548 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.548 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.549 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.549 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.550 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.550 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.550 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.551 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.551 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.554 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.555 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.555 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.556 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.556 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.557 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.558 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.558 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.559 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.559 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.562 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.563 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.563 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.563 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.564 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.565 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.565 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.565 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.567 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.568 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.575 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.576 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.578 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.578 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.579 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.580 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.580 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.581 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.582 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.582 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.584 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.585 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.586 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.587 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.588 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.590 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.594 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.594 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.595 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.596 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.598 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.598 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.599 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.600 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.600 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.602 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.602 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.603 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.604 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.604 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.605 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.605 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.606 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.606 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.606 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.608 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.608 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.609 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.609 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.609 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.610 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.611 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.611 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.612 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.612 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.614 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.615 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.615 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.616 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.616 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.617 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.618 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.618 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.618 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.619 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.619 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.620 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.620 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.621 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.621 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.622 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.622 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.622 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.623 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.624 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.626 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.626 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.627 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.627 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.628 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.630 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.632 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.632 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.633 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.634 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.636 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.636 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.637 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.637 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.637 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.638 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.638 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.639 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.639 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.639 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.640 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.640 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.641 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.641 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.641 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.642 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.643 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.643 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.644 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.644 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.645 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.645 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.645 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.645 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.646 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.647 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.647 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.648 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.648 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.648 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.649 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.650 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.650 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.651 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.651 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.652 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.652 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.652 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.653 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.653 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.654 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.654 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.654 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.654 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.654 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.655 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.655 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.656 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.656 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.656 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.657 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.658 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.658 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.659 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.659 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.660 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.660 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.660 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.660 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.661 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.662 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.663 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.663 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.664 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.664 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.665 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.666 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.667 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.668 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.668 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.669 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.670 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.670 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.670 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.670 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.671 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.672 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.672 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.672 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.673 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.673 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.674 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.674 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.674 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.674 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.675 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.676 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.677 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.677 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.677 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.678 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.678 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.678 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.679 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.679 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.680 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:48.680 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...
# 2024-10-11 19:38:51.161 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.161 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.161 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.161 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.162 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.162 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.162 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.163 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.163 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.163 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.164 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.164 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.164 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.164 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.165 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.165 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.165 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.165 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.166 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.166 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.167 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.167 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.167 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.168 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.169 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.170 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.170 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.170 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.171 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.172 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.172 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.173 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.173 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.173 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.174 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.175 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.175 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.176 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.176 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.177 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.177 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.178 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.178 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.178 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.178 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.179 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.179 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.179 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.180 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.180 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.180 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.180 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.181 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.181 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.182 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.183 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.183 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.183 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.184 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.185 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.186 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.187 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.187 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.187 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.188 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.189 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.189 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.189 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.189 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.190 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.190 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.191 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.191 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.191 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.192 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.192 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.192 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.192 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.193 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.193 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.194 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.194 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.194 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.194 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.195 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.195 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.195 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.196 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.196 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.196 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.197 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.197 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.197 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.197 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.198 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.198 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.198 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.199 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.199 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.199 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.200 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.200 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.201 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.201 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.202 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.203 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.203 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.204 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.204 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.205 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.205 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.205 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.206 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.206 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.206 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.207 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.207 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.207 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.208 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.208 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.208 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.209 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.209 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.209 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.210 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-11 19:38:51.211 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
clean_df
# Out:
#      Tokemak-Wrapped Ether-Balancer weETH/ezETH/rswETH  \
# 0    {'destination': '0x1416bfe53520a71553230c3fdee...
# 1    {'destination': '0x1416bfe53520a71553230c3fdee...
# 2    {'destination': '0x1416bfe53520a71553230c3fdee...
# 3    {'destination': '0x1416bfe53520a71553230c3fdee...
# 4    {'destination': '0x90300b02b162f902b9629963830...
# ..                                                 ...
# 172  {'destination': '0xc9b5d82652a1c8214b0971a0049...
# 173  {'destination': '0xc9b5d82652a1c8214b0971a0049...
# 174  {'destination': '0xc9b5d82652a1c8214b0971a0049...
# 175  {'destination': '0xc9b5d82652a1c8214b0971a0049...
# 176  {'destination': '0xc9b5d82652a1c8214b0971a0049...
#
#     Tokemak-Wrapped Ether-Balancer ezETH-WETH Stable Pool  \
# 0    {'destination': '0x689dc7b5ce8e23061a8223e9770...
# 1    {'destination': '0x689dc7b5ce8e23061a8223e9770...
# 2    {'destination': '0x689dc7b5ce8e23061a8223e9770...
# 3    {'destination': '0x689dc7b5ce8e23061a8223e9770...
# 4    {'destination': '0xc4c973edc82cb6b972c555672b4...
# ..                                                 ...
# 172  {'destination': '0x2f2cc1bf461413014741dd68481...
# 173  {'destination': '0x2f2cc1bf461413014741dd68481...
# 174  {'destination': '0x2f2cc1bf461413014741dd68481...
# 175  {'destination': '0x2f2cc1bf461413014741dd68481...
# 176  {'destination': '0x2f2cc1bf461413014741dd68481...
#
#                    Tokemak-Wrapped Ether-weETH/WETH-ng  \
# 0    {'destination': '0x17216c32b9134343258b0580740...
# 1    {'destination': '0x17216c32b9134343258b0580740...
# 2    {'destination': '0x17216c32b9134343258b0580740...
# 3    {'destination': '0x17216c32b9134343258b0580740...
# 4    {'destination': '0x777faf85c8e5fc6f4332e56b989...
# ..                                                 ...
# 172  {'destination': '0x5c6aeb9ef0d5bba4e6691f38100...
# 173  {'destination': '0x5c6aeb9ef0d5bba4e6691f38100...
# 174  {'destination': '0x5c6aeb9ef0d5bba4e6691f38100...
# 175  {'destination': '0x5c6aeb9ef0d5bba4e6691f38100...
# 176  {'destination': '0x5c6aeb9ef0d5bba4e6691f38100...
#
#     Tokemak-Wrapped Ether-Balancer weETH/rETH StablePool  \
# 0    {'destination': '0x3b2c87ed95483059b950155a68e...
# 1    {'destination': '0x3b2c87ed95483059b950155a68e...
# 2    {'destination': '0x3b2c87ed95483059b950155a68e...
# 3    {'destination': '0x3b2c87ed95483059b950155a68e...
# 4    {'destination': '0x148ca723befea7b021c399413b8...
# ..                                                 ...
# 172  {'destination': '0x40219bbda953ca811d2d0168dc8...
# 173  {'destination': '0x40219bbda953ca811d2d0168dc8...
# 174  {'destination': '0x40219bbda953ca811d2d0168dc8...
# 175  {'destination': '0x40219bbda953ca811d2d0168dc8...
# 176  {'destination': '0x40219bbda953ca811d2d0168dc8...
#
#     Tokemak-Wrapped Ether-Balancer rsETH-WETH Stable Pool  \
# 0    {'destination': '0x676b34c2c2294ef070c1e9e0fcd...
# 1    {'destination': '0x676b34c2c2294ef070c1e9e0fcd...
# 2    {'destination': '0x676b34c2c2294ef070c1e9e0fcd...
# 3    {'destination': '0x676b34c2c2294ef070c1e9e0fcd...
# 4    {'destination': '0x4e12227b350e8f8feec41a58d36...
# ..                                                 ...
# 172  {'destination': '0x4e12227b350e8f8feec41a58d36...
# 173  {'destination': '0x4e12227b350e8f8feec41a58d36...
# 174  {'destination': '0x4e12227b350e8f8feec41a58d36...
# 175  {'destination': '0x4e12227b350e8f8feec41a58d36...
# 176  {'destination': '0x4e12227b350e8f8feec41a58d36...
#
#            Tokemak-Wrapped Ether-Balancer rsETH / ETHx
# 0    {'destination': '0xb6d68122428dc1141467cb96791...
# 1    {'destination': '0xb6d68122428dc1141467cb96791...
# 2    {'destination': '0xb6d68122428dc1141467cb96791...
# 3    {'destination': '0xb6d68122428dc1141467cb96791...
# 4    {'destination': '0x2f7e096a400ded5d02762120b39...
# ..                                                 ...
# 172  {'destination': '0x2f7e096a400ded5d02762120b39...
# 173  {'destination': '0x2f7e096a400ded5d02762120b39...
# 174  {'destination': '0x2f7e096a400ded5d02762120b39...
# 175  {'destination': '0x2f7e096a400ded5d02762120b39...
# 176  {'destination': '0x2f7e096a400ded5d02762120b39...
#
# [177 rows x 6 columns]

# %%
col1 = "0x4e12227b350e8f8feec41a58d36ce2fb2e2d4575"
col2 = "0x676b34c2c2294ef070c1e9e0fcd4091dd06393fe"
import numpy as np

limited_df = clean_df[[col1, col2]].copy()
limited_df["0x676b34c2c2294ef070c1e9e0fcd4091dd06393fe"].iloc[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 4
#       2 col2 = '0x676b34c2c2294ef070c1e9e0fcd4091dd06393fe'
#       3 import numpy as np
# ----> 4 limited_df = clean_df[[col1, col2]].copy()
#       5 limited_df['0x676b34c2c2294ef070c1e9e0fcd4091dd06393fe'].iloc[0]
#
# File ~/Documents/Tokemak/v2-rebalance-dashboard/.venv/lib/python3.10/site-packages/pandas/core/frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File ~/Documents/Tokemak/v2-rebalance-dashboard/.venv/lib/python3.10/site-packages/pandas/core/indexes/base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File ~/Documents/Tokemak/v2-rebalance-dashboard/.venv/lib/python3.10/site-packages/pandas/core/indexes/base.py:6249, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6247 if nmissing:
#    6248     if nmissing == len(indexer):
# -> 6249         raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251     not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6252     raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['0x4e12227b350e8f8feec41a58d36ce2fb2e2d4575', '0x676b34c2c2294ef070c1e9e0fcd4091dd06393fe'], dtype='object')] are in the [columns]"

# %%
col1 = "0x4e12227b350e8f8feec41a58d36ce2fb2e2d4575"
col2 = "0x676b34c2c2294ef070c1e9e0fcd4091dd06393fe"
import numpy as np

limited_df = clean_df[[col1, col2]].copy()
limited_df
np.all(limited_df.isna().sum(axis=1) == 1)
# one option is to inlude a is shutdown call on each of the destinations

# %%
# [[0x2f2CC1bf461413014741dD68481dB4a3686DAC3D]
# [0x40219bBda953ca811d2D0168Dc806a96b84791d9]
# [0xC9b5D82652a1C8214b0971A004983d0EEeDD751C]
# [0x4E12227b350E8f8fEEc41A58D36cE2fB2e2d4575]
# [0x2F7e096a400ded5D02762120b39A3aA4ABA072a4]
# [0x5c6aeb9ef0d5BbA4E6691f381003503FD0D45126]]

# I need to know when in conflict, which reponse to use from  proxyGetDestinationSummaryStats

# I want a (autopool, block) -> list of current destinations

# %%
limited_df

# %%
dest = destination_details[5]
print(dest)

# %%
break

# %%
build_proxyGetDestinationSummaryStats_call(
    "destination_details",
)

# %%
c = build_proxyGetDestinationSummaryStats_call()

# %%
print(destination_details[4])

# %%
# /// @param destination The address / lp token of the destination vault
# /// @param baseApr Base Apr is the yield generated by staking rewards
# /// @param feeApr Yield for pool trading fees
# /// @param incentiveApr Incentives for LP
# /// @param safeTotalSupply Safe supply for LP tokens
# /// @param priceReturn Return from price movement to & away from peg
# /// @param maxDiscount Max discount to peg
# /// @param maxPremium Max premium to peg
# /// @param ownedShares Shares owned for this destination
# /// @param compositeReturn Total return combined from the individual yield components
# /// @param pricePerShare Price per share
# struct SummaryStats {
#     address destination;
#     uint256 baseApr;
#     uint256 feeApr;
#     uint256 incentiveApr;
#     uint256 safeTotalSupply;
#     int256 priceReturn;
#     int256 maxDiscount;
#     int256 maxPremium;
#     uint256 ownedShares;
#     int256 compositeReturn;
#     uint256 pricePerShare;
# }

# /// @dev Returns a destinations summary stats. Can revert and there can be abi decode errors temporarily
# /// @param autopoolStrategy Strategy to query
# /// @param destinationAddress Address of the destination to query stats for
# /// @param direction Direction to calculate the stats for
# /// @param amount Amount to use when looking at dilution effects
# /// @return stats The Destinations summary stats from the Strategy
# function proxyGetDestinationSummaryStats(
#     IAutopoolStrategy autopoolStrategy,
#     address destinationAddress,
#     IAutopoolStrategy.RebalanceDirection direction,
#     uint256 amount
# ) public returns (IStrategy.SummaryStats memory) {
#     return autopoolStrategy.getDestinationSummaryStats(destinationAddress, direction, amount);
# }

# %%
calls = []
for autopool in ALL_AUTOPOOLS:
    for dest in destination_details:
        if autopool.autopool_eth_addr == dest.autopool_vault_address:
            print(dest)

# %%
_build_summary_stats_call()

# %%
import pandas as pd
from mainnet_launch.constants import (
    CACHE_TIME,
    eth_client,
    ALL_AUTOPOOLS,
    BAL_ETH,
    AUTO_ETH,
    AUTO_LRT,
    AutopoolConstants,
)
from mainnet_launch.abis.abis import AUTOPOOL_VAULT_ABI
from mainnet_launch.data_fetching.get_events import get_each_event_in_contract


vault_contract = eth_client.eth.contract(AUTO_ETH.autopool_eth_addr, abi=AUTOPOOL_VAULT_ABI)

events = get_each_event_in_contract(vault_contract)
for e, df in events.items():
    print(e, df.shape)

# %%
# def _clean_summary_stats_info(success, summary_stats):
#     if success is True:
#         summary = {
#             "destination": summary_stats[0],
#             "baseApr": summary_stats[1] / 1e18,
#             "feeApr": summary_stats[2] / 1e18,
#             "incentiveApr": summary_stats[3] / 1e18,
#             "safeTotalSupply": summary_stats[4] / 1e18,
#             "priceReturn": summary_stats[5] / 1e18,
#             "maxDiscount": summary_stats[6] / 1e18,
#             "maxPremium": summary_stats[7] / 1e18,
#             "ownedShares": summary_stats[8] / 1e18,
#             "compositeReturn": summary_stats[9] / 1e18,
#             "pricePerShare": summary_stats[10] / 1e18,
#             # ignoring slashings costs, no longer part of model
#         }
#         return summary
#     else:
#         return None

# def build_proxyGetDestinationSummaryStats_call(
#         name:str, autopool_strategy_address :str, destination_address: str, direction:str, amount:int) -> Call:
#     if direction == "in":
#         direction_enum = 0
#     elif direction == "out":
#         direction_enum = 1
#     return_types = "(address,uint256,uint256,uint256,uint256,int256,int256,int256,uint256,int256,uint256)"

#     # cleaning_function = build_summary_stats_cleaning_function(autopool)
#     return Call(
#         LENS_CONTRACT,
#         [
#             f"proxyGetDestinationSummaryStats(address,address,uint8,uint256)({return_types})",
#             autopool_strategy_address,
#             destination_address,
#             direction_enum,
#             amount,
#         ],
#         [(name, _clean_summary_stats_info)],
#     )

# %%
s = events["Withdraw"]

s.sort_values("shares").tail(2).value_counts()

# %%
deposits = events["Deposit"]
deposits.tail(5).value_counts()

# %%
# https://dashboard.tenderly.co/tx/mainnet/0x030ca18bd0d52298ff9c49b76b100d0b2150cc9327392e720bc9f742ab1f6186
# deposit and stake .007 ETH, through the front end multicall. slightly more if you are using ETH instead of WETH.

# 281k Gas for a deposit, and stake of ETH

# 189k for Withdrawal, when fully in idle.

# about 400k gas when depositing to and from idle
# 0xf0a909c99aa33d45890d4f908d12301678ec3c1d78c52fc30d063961a4952d66
# at current prices is $21 round trip. Note this matches what I experienced, it cost ~$20 when I did it at the start
# https://www.cryptoneur.xyz/en/gas-fees-calculator?usedGas=400000&txnType=Custom

# our target user is entering and exit only from idle, so

# 400k Gas to enter and exit from idle, at 20 gwei and ETH at $2400, a round trip is $20.
# Curve add liqudity, 180k gas https://etherscan.io/tx/0x941010536a0c32db51275784e7a7e5f65e578867abcc87e0fe0c1f01af0490da
# Curve withdrawal liqudity 178,725 https://etherscan.io/tx/0x941010536a0c32db51275784e7a7e5f65e578867abcc87e0fe0c1f01af0490da

# curve depoist to gauge 445,888 gas https://etherscan.io/tx/0xabdf03ee23049df07cfb161db7bcba555e022822f397f5744e3b9f8c3e223c09
# Curve withdrawal from gauge 390,108 gas https://etherscan.io/tx/0x7dfcdcd40962a2b71251de0021c13602583cc99a9e2016b13c60f9891b96cefd

# convex stake https://etherscan.io/tx/0x3538805f314ccb033668aff57fcd85c21109cc5d57268500a7b79b79f133e334
# 600,278 gas
# convex unstake https://dashboard.tenderly.co/tx/mainnet/0xba77cb7da59cfd50635a32f2b32cac5b3608cf1993a3e9b278cf91818d56b250
# 520k gas


# total gas 1194K gas for add liqudity, stake on convex, unstake on convex, remove liqudity
# then they need to pay gas to claim rewards,

# 180 + 178 + 600 + 520

# lets looks look at some typical paths

# user added liqudity on curve, stakes it on convex,

# claims rewards once, having a hard time finding this transaction

# unstake on convex,  remove liqudity

# swap back to ETH

# %%
352 + 105 + 345 + 241 + 188

# %%
180 + 178 + 600 + 520

# %%
import pandas as pd
from mainnet_launch.constants import (
    CACHE_TIME,
    eth_client,
    ALL_AUTOPOOLS,
    BAL_ETH,
    AUTO_ETH,
    AUTO_LRT,
    AutopoolConstants,
)
from mainnet_launch.solver_diagnostics.solver_diagnostics import _load_solver_df


solver_df = _load_solver_df(AUTO_ETH)
sod = None
destination_added_to = None


def _get_rank_of_add(row: dict):
    sod = row["sod"]
    destination_added_to = row["destinationIn"]
    return


solver_df.apply(lambda row: _get_rank_of_add(row), axis=1)
destination_added_to

# %%
states = pd.DataFrame.from_records(solver_df["sod"].values[0]["destStates"])
states["name"]

# %%
solver_df.columns

# %%
states.columns

# %%
solver_df.head(1).T

# %%
solver_df.columns

# %%
states["pool"]

# %%
solver_df.columns

# %%
solver_df.head(1)[["destinationOut"]]

# %%
solver_df.head(1)[["destinationIn"]]

# %%
states[["name", "totalAprIn", "pool"]]

# %%
states.columns

# %%
all_steps = solver_df["steps"].values
dex_steps = []
for steps in all_steps:
    for step in steps:
        if "dex" in step:
            dex_steps.append(step)
pd.DataFrame.from_records(dex_steps)["dex"].value_counts()

# %%
def compute_number_of_add_rank_def(row: dict):
    addRank = row["addRank"]


solver_df

# %%
solver_df["addRank"].values[0]
# 1st no. should be the predicted ETH gain net of swap costs, 2nd no. is the swap costs. the results are highly dependent on the swap path that aggregators find

# %%
solver_df["moveName"][0]

# %%
# Ensure that the 'date' column is in datetime format
solver_df["date"] = pd.to_datetime(solver_df["date"])

# Group by date and check if there is at least one row for each day
days_with_data = solver_df.groupby(solver_df["date"].dt.date).size() > 0

# Convert it to a DataFrame or Series to display the result
days_with_data_df = pd.DataFrame(days_with_data, columns=["Solver Ran At Least"])
days_with_data_df

# %%
import plotly.express as px

# %%
solver_df["date"]

# %%
contract = eth_client.eth.contract(BAL_ETH.autopool_eth_addr, abi=ERC_20_ABI)
events = get_each_event_in_contract(contract)

# %%
transfers = events["Transfer"]
transfers

# %%
transfers = transfers.sort_values("block", ascending=False)

# %%
def build_wallet_balance_at_the_end_of_each_block(token_address: str) -> pd.DataFrame:
    # returns a dataframe of the balance of each token at the end of each block
    # breaks if a token_address is rebasing, or if balances can change while not emitting a transfer event

    contract = eth_client.eth.contract(token_address, abi=ERC_20_ABI)
    transfers = fetch_events(contract.events.Transfer)
    all_wallets = set(transfers["to"].unique())
    blocks = transfers["block"].unique().astype(int)
    block_and_timestamp_df = get_raw_state_by_blocks([], blocks, include_block_number=True).reset_index()

    def build_state_change(row: dict):
        amount = float(int(row["value"]) / 1e18)
        changes = {
            row["to"]: amount,
            row["from"]: -amount,
            "block": row["block"],
        }

        for w in all_wallets:
            if w not in changes:
                changes[w] = 0.0
        return changes

    rolling_wallet_erc20_balance_by_block = pd.DataFrame.from_records(
        transfers.sort_values("block", ascending=False).apply(build_state_change, axis=1)
    )
    rolling_wallet_erc20_balance_by_block = (
        rolling_wallet_erc20_balance_by_block.groupby("block").sum().cumsum().reset_index()
    )
    rolling_wallet_erc20_balance_by_block = pd.merge(
        rolling_wallet_erc20_balance_by_block, block_and_timestamp_df, on="block", how="left"
    )
    rolling_wallet_erc20_balance_by_block.set_index("timestamp", inplace=True)
    return rolling_wallet_erc20_balance_by_block


rolling_wallet_erc20_balance_by_block = build_wallet_balance_at_the_end_of_each_block(AUTO_LRT.autopool_eth_addr)
rolling_wallet_erc20_balance_by_block

# %%
addresses_to_exclude = [
    "0x0000000000000000000000000000000000000000",
    *[a.autopool_eth_addr for a in ALL_AUTOPOOLS],
    "0x000000000000000000000000000000000000dEaD",
    "0x9597C17f323160D8462c194D72FAAcF7b4CBCd2b",  # main rewarder
    "0xC45e939ca8C43822A2A233404Ecf420712084c30",  # router
]

cols = [c for c in rolling_wallet_erc20_balance_by_block.columns if c not in ["block", *addresses_to_exclude]]

# %%
def _daily_balance_over_zero(group):

    for value in group:
        if value > 0.0:
            return True

    return False


balance_lists = rolling_wallet_erc20_balance_by_block[cols].resample("1D").apply(list).map(_daily_balance_over_zero)

balance_lists.sum(axis=1)

# %%
rolling_wallet_erc20_balance_by_block.resample("1D").apply(list)

# %%
# had some balance within the last d ay

# %%
rolling_wallet_erc20_balance_by_block.columns.sort_values()

# %%
def get_count_of_balance_above_zero(row:dict):
    print(row.keys())

    
    addresses
    for addr in row:
        if addr not in :
            pass
            
    
    return   

rolling_wallet_erc20_balance_by_block.apply(get_count_of_balance_above_zero, axis=1)

# %%
dfs = [_fetch_raw_deposit_and_withdrawal_dfs(a) for a in ALL_AUTOPOOLS]
dfs

# %%
d, w = dfs[0]
d["sender"].value_counts()

# %%
d["owner"].value_counts()
