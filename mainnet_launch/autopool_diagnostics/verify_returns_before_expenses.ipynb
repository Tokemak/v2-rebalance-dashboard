# %%
import pandas as pd
import plotly.express as px
from mainnet_launch.autopool_diagnostics.returns_before_expenses import _fetch_implied_nav_diff_from_price_return
from mainnet_launch.constants import AUTO_LRT, BASE_ETH

uwcr_df, allocation_df, compositeReturn_out_df, total_nav_series, summary_stats_df, priceReturn_df = (
    _fetch_implied_nav_diff_from_price_return(AUTO_LRT)
)
# Out:
# 2024-12-02 13:50:27.798 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-02 13:50:27.820
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /home/parker/Documents/Tokemak/v2-rebalance-dashboard/.venv/lib/python3.10/site-packages/ipykernel_launcher.py [ARGUMENTS]
# 2024-12-02 13:50:27.820 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-02 13:50:27.821 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-02 13:50:27.821 No runtime found, using MemoryCacheStorageManager
# 2024-12-02 13:50:28.024 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-02 13:50:28.025 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-02 13:50:28.025 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-02 13:50:28.026 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-02 13:50:28.026 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-02 13:50:28.027 No runtime found, using MemoryCacheStorageManager
# 2024-12-02 13:50:28.031 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-02 13:50:28.031 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-02 13:50:28.032 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-02 13:50:28.032 No runtime found, using MemoryCacheStorageManager
# 2024-12-02 13:50:28.036 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-02 13:50:28.036 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-02 13:50:28.037 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-02 13:50:28.038 No runtime found, using MemoryCacheStorageManager
# 2024-12-02 13:50:28.528 Thread 'Thread-5': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-02 13:50:28.530 Thread 'Thread-5': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-02 13:50:28.532 Thread 'Thread-6': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-02 13:50:28.539 Thread 'Thread-7': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-02 13:50:28.540 Thread 'Thread-6': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-02 13:50:28.544 Thread 'Thread-7': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-02 13:50:36.104 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-02 13:50:36.104 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-02 13:50:37.430 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-02 13:50:37.430 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-02 13:50:45.800 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-02 13:50:45.801 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-02 13:50:45.801 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-02 13:50:45.863 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-02 13:50:45.863 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# /home/parker/Documents/Tokemak/v2-rebalance-dashboard/mainnet_launch/destination_diagnostics/fetch_destination_summary_stats.py:111: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   merged_destination_df = pd.DataFrame.from_records(summary_stats_df.apply(_combine_to_destination_name, axis=1))
# 2024-12-02 13:50:54.129 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-02 13:50:54.130 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
implied_extra_nav_if_price_return_is_zero.name = "additional_nav_if_price_return_was_0"

# %%
import plotly.express as px

px.line(implied_extra_nav_if_price_return_is_zero)

# %%
priceReturn_df
# Out:
#                            weETH/rETH (balancer)  rsETH / WETH (balancer)  \
# timestamp
# 2024-09-15 02:04:47+00:00              -0.000265                 0.000598
# 2024-09-15 08:06:23+00:00              -0.000254                 0.000879
# 2024-09-15 14:07:35+00:00              -0.000296                 0.000556
# 2024-09-15 20:08:35+00:00              -0.000289                 0.000555
# 2024-09-16 02:09:35+00:00              -0.000268                 0.000564
# ...                                          ...                      ...
# 2024-12-01 17:19:11+00:00               0.004697                 0.000421
# 2024-12-01 23:20:47+00:00               0.004559                 0.000428
# 2024-12-02 05:22:47+00:00               0.004525                 0.000453
# 2024-12-02 11:24:35+00:00               0.003438                 0.000463
# 2024-12-02 17:27:23+00:00               0.003357                 0.000477
#
#                            ezETH-WETH-BPT (balancer)  \
# timestamp
# 2024-09-15 02:04:47+00:00                   0.000738
# 2024-09-15 08:06:23+00:00                   0.000746
# 2024-09-15 14:07:35+00:00                   0.000734
# 2024-09-15 20:08:35+00:00                   0.000727
# 2024-09-16 02:09:35+00:00                   0.000729
# ...                                              ...
# 2024-12-01 17:19:11+00:00                        NaN
# 2024-12-01 23:20:47+00:00                        NaN
# 2024-12-02 05:22:47+00:00                        NaN
# 2024-12-02 11:24:35+00:00                        NaN
# 2024-12-02 17:27:23+00:00                        NaN
#
#                            weETH/ezETH/rswETH (balancer)  weeth-ng (curve)  \
# timestamp
# 2024-09-15 02:04:47+00:00                       0.000797          0.000172
# 2024-09-15 08:06:23+00:00                       0.000801          0.000170
# 2024-09-15 14:07:35+00:00                       0.000782          0.000115
# 2024-09-15 20:08:35+00:00                       0.000781          0.000121
# 2024-09-16 02:09:35+00:00                       0.000782          0.000120
# ...                                                  ...               ...
# 2024-12-01 17:19:11+00:00                       0.001931          0.000108
# 2024-12-01 23:20:47+00:00                       0.001929          0.000110
# 2024-12-02 05:22:47+00:00                       0.001983          0.000121
# 2024-12-02 11:24:35+00:00                       0.001634          0.000100
# 2024-12-02 17:27:23+00:00                       0.001702          0.000115
#
#                            autoLRT (tokemak)  rsETH / ETHx (balancer)
# timestamp
# 2024-09-15 02:04:47+00:00                0.0                 0.001220
# 2024-09-15 08:06:23+00:00                0.0                 0.001078
# 2024-09-15 14:07:35+00:00                0.0                 0.000855
# 2024-09-15 20:08:35+00:00                0.0                 0.000886
# 2024-09-16 02:09:35+00:00                0.0                 0.000886
# ...                                      ...                      ...
# 2024-12-01 17:19:11+00:00                0.0                      NaN
# 2024-12-01 23:20:47+00:00                0.0                      NaN
# 2024-12-02 05:22:47+00:00                0.0                      NaN
# 2024-12-02 11:24:35+00:00                0.0                      NaN
# 2024-12-02 17:27:23+00:00                0.0                      NaN
#
# [314 rows x 7 columns]
