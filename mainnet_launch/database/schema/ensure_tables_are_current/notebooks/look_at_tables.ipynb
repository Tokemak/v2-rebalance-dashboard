# %%
import plotly.express as px
import pandas as pd

from mainnet_launch.constants import *
from mainnet_launch.database.schema.full import *
from mainnet_launch.database.schema.postgres_operations import *
from mainnet_launch.database.schema.views import *


def get_readable_plan_table() -> pd.DataFrame:
    df = merge_tables_as_df(
        selectors=[
            TableSelector(RebalancePlans),
            TableSelector(
                Autopools,
                select_fields=[Autopools.symbol],
                join_on=Autopools.autopool_vault_address == RebalancePlans.autopool_vault_address,
            ),
        ]
    )
    return df


event_df = get_readable_rebalance_events_by_autopool(SILO_USD)
df = get_readable_plan_table()
df
# Out:
#                                                file_name  \
# 0      rebalance_plan_1753671656_0x0A2b94F6871c1D7A32...
# 1      rebalance_plan_1751856345_0x0A2b94F6871c1D7A32...
# 2      rebalance_plan_1736548221_0x0A2b94F6871c1D7A32...
# 3      rebalance_plan_1742585421_0x0A2b94F6871c1D7A32...
# 4      rebalance_plan_1731483021_0x0A2b94F6871c1D7A32...
# ...                                                  ...
# 13287  rebalance_plan_1756110156_0x52F0D57Fb5D4780a37...
# 13288  rebalance_plan_1756088556_0x52F0D57Fb5D4780a37...
# 13289  rebalance_plan_1756101155_0x52F0D57Fb5D4780a37...
# 13290  rebalance_plan_1756119155_0x52F0D57Fb5D4780a37...
# 13291  rebalance_plan_1756099355_0x52F0D57Fb5D4780a37...
#
#              datetime_generated                      autopool_vault_address  \
# 0     2025-07-28 03:00:56+00:00  0x0A2b94F6871c1D7A32Fe58E1ab5e6deA2f114E56
# 1     2025-07-07 02:45:45+00:00  0x0A2b94F6871c1D7A32Fe58E1ab5e6deA2f114E56
# 2     2025-01-10 22:30:21+00:00  0x0A2b94F6871c1D7A32Fe58E1ab5e6deA2f114E56
# 3     2025-03-21 19:30:21+00:00  0x0A2b94F6871c1D7A32Fe58E1ab5e6deA2f114E56
# 4     2024-11-13 07:30:21+00:00  0x0A2b94F6871c1D7A32Fe58E1ab5e6deA2f114E56
# ...                         ...                                         ...
# 13287 2025-08-25 08:22:36+00:00  0x52F0D57Fb5D4780a37164f918746f9BD51c684a3
# 13288 2025-08-25 02:22:36+00:00  0x52F0D57Fb5D4780a37164f918746f9BD51c684a3
# 13289 2025-08-25 05:52:35+00:00  0x52F0D57Fb5D4780a37164f918746f9BD51c684a3
# 13290 2025-08-25 10:52:35+00:00  0x52F0D57Fb5D4780a37164f918746f9BD51c684a3
# 13291 2025-08-25 05:22:35+00:00  0x52F0D57Fb5D4780a37164f918746f9BD51c684a3
#
#        chain_id                              solver_address rebalance_type  \
# 0             1  0x952D7a7eB2e0804d37d9244BE8e47341356d2f5D       FromIdle
# 1             1                                        None           None
# 2             1  0x952D7a7eB2e0804d37d9244BE8e47341356d2f5D       FromIdle
# 3             1                                        None           None
# 4             1  0x952D7a7eB2e0804d37d9244BE8e47341356d2f5D       FromIdle
# ...         ...                                         ...            ...
# 13287         1                                        None           None
# 13288         1                                        None           None
# 13289         1                                        None           None
# 13290         1                                        None           None
# 13291         1                                        None           None
#
#                                   destination_out  \
# 0      0x0A2b94F6871c1D7A32Fe58E1ab5e6deA2f114E56
# 1                                            None
# 2      0x0A2b94F6871c1D7A32Fe58E1ab5e6deA2f114E56
# 3                                            None
# 4      0x0A2b94F6871c1D7A32Fe58E1ab5e6deA2f114E56
# ...                                           ...
# 13287                                        None
# 13288                                        None
# 13289                                        None
# 13290                                        None
# 13291                                        None
#
#                                         token_out  \
# 0      0xC02aaA39b223FE8D0A0e5C4F27eAD9083C756Cc2
# 1                                            None
# 2      0xC02aaA39b223FE8D0A0e5C4F27eAD9083C756Cc2
# 3                                            None
# 4      0xC02aaA39b223FE8D0A0e5C4F27eAD9083C756Cc2
# ...                                           ...
# 13287                                        None
# 13288                                        None
# 13289                                        None
# 13290                                        None
# 13291                                        None
#
#                                    destination_in  \
# 0      0x9b163e15121816BE53F8d5c85fbefD6e6D9bebCd
# 1                                            None
# 2      0xc4Eb861e7b66f593482a3D7E8adc314f6eEDA30B
# 3                                            None
# 4      0xc4Eb861e7b66f593482a3D7E8adc314f6eEDA30B
# ...                                           ...
# 13287                                        None
# 13288                                        None
# 13289                                        None
# 13290                                        None
# 13291                                        None
#
#                                          token_in  ... in_dest_adj_apr  \
# 0      0x6b31a94029fd7840d780191B6D63Fa0D269bd883  ...        0.117924
# 1                                            None  ...             NaN
# 2      0x88794C65550DeB6b4087B7552eCf295113794410  ...        0.089252
# 3                                            None  ...             NaN
# 4      0x88794C65550DeB6b4087B7552eCf295113794410  ...        0.070416
# ...                                           ...  ...             ...
# 13287                                        None  ...             NaN
# 13288                                        None  ...             NaN
# 13289                                        None  ...             NaN
# 13290                                        None  ...             NaN
# 13291                                        None  ...             NaN
#
#        apr_delta  swap_offset_period  num_candidate_destinations  \
# 0       0.117924                26.0                         5.0
# 1            NaN                 NaN                         NaN
# 2       0.089252                46.0                         5.0
# 3            NaN                 NaN                         NaN
# 4       0.070416                48.0                         7.0
# ...          ...                 ...                         ...
# 13287        NaN                 NaN                         NaN
# 13288        NaN                 NaN                         NaN
# 13289        NaN                 NaN                         NaN
# 13290        NaN                 NaN                         NaN
# 13291        NaN                 NaN                         NaN
#
#        candidate_destinations_rank projected_swap_cost  projected_net_gain  \
# 0                              0.0            0.005530            0.266996
# 1                              NaN                 NaN                 NaN
# 2                              0.0            0.078233            1.903875
# 3                              NaN                 NaN                 NaN
# 4                              0.0            0.009908            0.406662
# ...                            ...                 ...                 ...
# 13287                          NaN                 NaN                 NaN
# 13288                          NaN                 NaN                 NaN
# 13289                          NaN                 NaN                 NaN
# 13290                          NaN                 NaN                 NaN
# 13291                          NaN                 NaN                 NaN
#
#       projected_gross_gain  projected_slippage   symbol
# 0                 0.272525            0.016309  autoETH
# 1                      NaN                 NaN  autoETH
# 2                 1.982107            0.042596  autoETH
# 3                      NaN                 NaN  autoETH
# 4                 0.416570            0.021364  autoETH
# ...                    ...                 ...      ...
# 13287                  NaN                 NaN  siloETH
# 13288                  NaN                 NaN  siloETH
# 13289                  NaN                 NaN  siloETH
# 13290                  NaN                 NaN  siloETH
# 13291                  NaN                 NaN  siloETH
#
# [13292 rows x 29 columns]

# %%
this_destinations = list(set([*event_df["destination_out"].values, *event_df["destination_in"].values]))

# %%
destinations_df = get_full_table_as_df(
    DestinationStates, where_clause=DestinationStates.destination_vault_address.in_(this_destinations)
)
destinations_df
# Out:
# Empty DataFrame
# Columns: [destination_vault_address, block, chain_id, incentive_apr, fee_apr, base_apr, points_apr, fee_plus_base_apr, total_apr_in, total_apr_out, underlying_token_total_supply, safe_total_supply, lp_token_spot_price, lp_token_safe_price, from_rebalance_plan, rebalance_plan_timestamp, rebalance_plan_key]
# Index: []

# %%
autopool_destinations = get_full_table_as_df(
    AutopoolDestinationStates
)  # , where_clause=AutopoolDestinationStates.destination_vault_address.in_(this_destinations))
autopool_destinations
# Out:
#                          destination_vault_address  \
# 0       0x903F21CBC0cFd49817dB219Cd216325fD4132034
# 1       0xfB6f99FdF12E37Bfe3c4Cf81067faB10c465fb24
# 2       0x0A2b94F6871c1D7A32Fe58E1ab5e6deA2f114E56
# 3       0x25cb41919d6B88e0D48108A4F5fe8FBb3744aFE1
# 4       0xc4Eb861e7b66f593482a3D7E8adc314f6eEDA30B
# ...                                            ...
# 142925  0x2fE75AEd0E1EFA62e47CE356814D16D9eb6450d1
# 142926  0x3D35b1E0Fe434848490427CE4DE13b6839365Bd2
# 142927  0x4827788F01D7533710cbfa7C0b5991E8b99E277F
# 142928  0x2Af19422D9f81A4c71306a409A540fC63d7f623B
# 142929  0xCb119265AA1195ea363D7A243aD56c73EA42Eb59
#
#                             autopool_vault_address     block  chain_id  \
# 0       0x0A2b94F6871c1D7A32Fe58E1ab5e6deA2f114E56  21712129         1
# 1       0x0A2b94F6871c1D7A32Fe58E1ab5e6deA2f114E56  22184669         1
# 2       0x0A2b94F6871c1D7A32Fe58E1ab5e6deA2f114E56  21511571         1
# 3       0x0A2b94F6871c1D7A32Fe58E1ab5e6deA2f114E56  22342307         1
# 4       0x0A2b94F6871c1D7A32Fe58E1ab5e6deA2f114E56  22506180         1
# ...                                            ...       ...       ...
# 142925  0xCb119265AA1195ea363D7A243aD56c73EA42Eb59  44428026       146
# 142926  0xCb119265AA1195ea363D7A243aD56c73EA42Eb59  44428026       146
# 142927  0xCb119265AA1195ea363D7A243aD56c73EA42Eb59  44439597       146
# 142928  0xCb119265AA1195ea363D7A243aD56c73EA42Eb59  44451155       146
# 142929  0xCb119265AA1195ea363D7A243aD56c73EA42Eb59  44428026       146
#
#          owned_shares
# 0            0.000000
# 1            0.000000
# 2          162.727288
# 3            0.000000
# 4          373.662845
# ...               ...
# 142925       0.000000
# 142926       0.000000
# 142927  421858.307028
# 142928       0.000000
# 142929     189.461276
#
# [142930 rows x 5 columns]
