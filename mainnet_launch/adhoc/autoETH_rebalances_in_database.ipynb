# %%
import pandas as pd

from mainnet_launch.database.postgres_operations import get_full_table_as_df_with_tx_hash, get_full_table_as_df
from mainnet_launch.database.schema.full import RebalanceEvents, RebalancePlans
from mainnet_launch.constants import AUTO_ETH


event_df = get_full_table_as_df_with_tx_hash(RebalanceEvents, where_clause=RebalanceEvents.autopool_vault_address == AUTO_ETH.autopool_eth_addr)
# we have the rebalance events themselves but not the plans

plan_df = get_full_table_as_df(RebalancePlans, where_clause=RebalancePlans.autopool_vault_address == AUTO_ETH.autopool_eth_addr)
plan_df
# Out:
#                                               file_name  ... projected_slippage
# 0     rebalance_plan_1745976638_0x0A2b94F6871c1D7A32...  ...           0.037974
# 1     rebalance_plan_1753412455_0x0A2b94F6871c1D7A32...  ...          -0.079327
# 2     rebalance_plan_1742088621_0x0A2b94F6871c1D7A32...  ...           0.027565
# 3     rebalance_plan_1747402224_0x0A2b94F6871c1D7A32...  ...           0.020310
# 4     rebalance_plan_1753282856_0x0A2b94F6871c1D7A32...  ...           0.271219
# ...                                                 ...  ...                ...
# 1447  rebalance_plan_1762379965_0x0A2b94F6871c1D7A32...  ...           0.003852
# 1448  rebalance_plan_1762381253_0x0A2b94F6871c1D7A32...  ...           0.008250
# 1449  rebalance_plan_1762380680_0x0A2b94F6871c1D7A32...  ...          -0.134924
# 1450  rebalance_plan_1762382051_0x0A2b94F6871c1D7A32...  ...           0.005524
# 1451  rebalance_plan_1767450785_0x0A2b94F6871c1D7A32...  ...                NaN
#
# [1452 rows x 28 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# CustomPostgresOperationException          Traceback (most recent call last)
# Cell In[2], line 3
#       1 # we have the rebalance events themselves but not the plans
# ----> 3 plan_df = get_full_table_as_df_with_tx_hash(RebalancePlans, where_clause=RebalancePlans.autopool_vault_address == AUTO_ETH.autopool_eth_addr)
#       4 plan_df
#
# File ~/Documents/Github/Tokemak/v2-rebalance-dashboard/mainnet_launch/database/postgres_operations.py:343, in get_full_table_as_df_with_tx_hash(table, where_clause)
#     338 """Fetch the full contents of a table (that has transaction hashes) along with the associated transaction datetime.
#     339
#     340 Optionally filter with a SQLAlchemy where_clause.
#     341 """
#     342 if "tx_hash" not in [a.name for a in table.__table__.columns]:
# --> 343     raise CustomPostgresOperationException(f"Table {table.__tablename__} must have a 'tx_hash' column")
#     345 with Session.begin() as session:
#     346     where_sql = _where_clause_to_string(where_clause, session)
#
# CustomPostgresOperationException: Table rebalance_plans must have a 'tx_hash' column
