# %%
import pandas as pd

from mainnet_launch.database.postgres_operations import get_full_table_as_df_with_tx_hash, get_full_table_as_df
from mainnet_launch.database.schema.full import RebalanceEvents, RebalancePlans
from mainnet_launch.constants import AUTO_ETH


event_df = get_full_table_as_df_with_tx_hash(
    RebalanceEvents, where_clause=RebalanceEvents.autopool_vault_address == AUTO_ETH.autopool_eth_addr
)

# we have the rebalance events themselves but not the plans
# bug found on jan 9 2026
# this misses the several plans on Jan 2, 2026
# plan_df = get_full_table_as_df(RebalancePlans, where_clause=RebalancePlans.autopool_vault_address == AUTO_ETH.autopool_eth_addr)

event_df.sort_index(ascending=False)
# Out:
# /Users/pb/Library/Caches/pypoetry/virtualenvs/mainnet-launch-FtycU18g-py3.10/lib/python3.10/site-packages/web3/__init__.py:4: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
#                                                                      tx_hash  \
# datetime
# 2026-01-09 12:31:11+00:00  0xe8c2bb555e694266d35abd1cb9c7e1e836001cf510bb...
# 2026-01-07 04:30:59+00:00  0x5efea4fea819da653357d89c9bd340ecfd3c9975707c...
# 2026-01-06 20:14:59+00:00  0x21931ee66d14ce29006d9475271e171aeb22575ef5fa...
# 2026-01-06 02:31:11+00:00  0x694cef2caa131c6a38a2ca75cd90c339f9819a2dd3e8...
# 2026-01-05 16:30:59+00:00  0x13a8cc43f28e0c975d4cbdfd864766e3b2decc3d568f...
# ...                                                                      ...
# ...

# %%
event_df = get_full_table_as_df_with_tx_hash(RebalanceEvents, where_clause=RebalanceEvents.rebalance_file_path == None)
event_df
# Out:
#                                                                      tx_hash  \
# datetime
# 2026-01-09 12:31:11+00:00  0xe8c2bb555e694266d35abd1cb9c7e1e836001cf510bb...
# 2026-01-07 04:30:59+00:00  0x5efea4fea819da653357d89c9bd340ecfd3c9975707c...
# 2026-01-06 20:14:59+00:00  0x21931ee66d14ce29006d9475271e171aeb22575ef5fa...
# 2026-01-06 02:31:11+00:00  0x694cef2caa131c6a38a2ca75cd90c339f9819a2dd3e8...
# 2026-01-05 16:30:59+00:00  0x13a8cc43f28e0c975d4cbdfd864766e3b2decc3d568f...
# 2026-01-04 15:51:11+00:00  0x29d2df0034b66ea11d7674d08d42801b4dd1ea1f6a7e...
# 2026-01-03 14:49:59+00:00  0x9eda9849d371427311da59946cc52eb51ad3272124b9...
# 2026-01-02 21:59:23+00:00  0x9588b05af1235c99b63a3c5ca75c94b383e676de5329...
# 2025-11-20 17:27:00+00:00  0x54797d17441b06622213987bfd2ce4be6f1b578ed431...
# 2025-11-17 16:58:21+00:00  0x267ea64172080d0e37bee4c7a61e08315c9d62edb628...
# 2025-11-17 14:58:17+00:00  0x84555b4f042b97729239cfec01ece83e8604d08bb91a...
# ...
