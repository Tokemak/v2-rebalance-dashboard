# %% [markdown]
# # VP Function Verification
#
# Reads `vp_function_mapping.csv` and calls each VP function at the latest block to verify the mapping is correct.

# %%
import pandas as pd
from pathlib import Path
from multicall import Call

from mainnet_launch.data_fetching.get_state_by_block import (
    get_state_by_one_block,
    safe_normalize_with_bool_success,
    build_blocks_to_use, get_raw_state_by_blocks
)
from mainnet_launch.constants import ETH_CHAIN, BASE_CHAIN

mapping = pd.read_csv(
    Path(__file__).parent / "vp_function_mapping.csv" if "__file__" in dir() else "vp_function_mapping.csv"
)
mapping
# Out:
# /Users/pb/Library/Caches/pypoetry/virtualenvs/mainnet-launch-FtycU18g-py3.10/lib/python3.10/site-packages/eth_abi/__init__.py:4: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
#    autopool                   destination_vault_address  \
# 0   autoETH  0x0A2b94F6871c1D7A32Fe58E1ab5e6deA2f114E56
# 1   autoETH  0x1Ea622fa030e4a78F4CC2f305dd3c08DA3F08573
# 2   autoETH  0xC001f23397dB71B17602Ce7D90a983Edc38DB0d1
# 3   autoETH  0x3772973f8F399D74488D5cF3276C032E0afC8A6f
# 4   autoETH  0x28109255F49f0A02BB31358B3e0b5cb7512EB4eC
# 5   autoETH  0x2C7120dCCF1c14A37A26A4955475d45d34a3d7E7
# 6   autoETH  0xd100c932801390fdeBcE11F26f611D4898b44236
# 7   autoETH  0x3F55eedDe51504E6Ed0ec30E8289b4Da11EdB7F9
# 8   autoETH  0x896eCc16Ab4AFfF6cE0765A5B924BaECd7Fa455a
# 9   autoETH  0xe4433D00Cf48BFE0C672d9949F2cd2c008bffC04
# 10  autoETH  0x2E0E2AB6505A1182367DFB1e3c66648bF3EEA020
# 11  autoETH  0xd96E943098B2AE81155e98D7DC8BeaB34C539f01
# 12  autoETH  0x43D99d04985ef2231f7d9b5D9111D2189d9FD971
# 13  autoETH  0xbA1462f43c6f60ebD1C62735c94E428aD073E01A
# 14  autoETH  0xE382BBd32C4E202185762eA433278f4ED9E6151E
# 15  autoETH  0xc4Eb861e7b66f593482a3D7E8adc314f6eEDA30B
# 16  autoETH  0x8cA2201BC34780f14Bca452913ecAc8e9928d4cA
# 17  autoETH  0xdfE3fA7027E84f59b266459C567278C79fe86f0C
# 18  autoETH  0xfB6f99FdF12E37Bfe3c4Cf81067faB10c465fb24
# 19  autoETH  0x9b163e15121816BE53F8d5c85fbefD6e6D9bebCd
# 20  autoETH  0x87E25fFe5C3A2720Cd43F5Eb8ec41Ac0CE699D07
# 21  autoETH  0x4142e3a17391676C66DDf1285E43889F168EE237
# 22  autoETH  0x40219bBda953ca811d2D0168Dc806a96b84791d9
# 23  autoETH  0x2B08137BeABd2454AD3631DEB754F97C5c93eB78
# 24  autoETH  0x6a8C6ff78082a2ae494EB9291DdC7254117298Ff
# 25  autoETH  0x5c6aeb9ef0d5BbA4E6691f381003503FD0D45126
# 26  autoETH  0x5b39015f01A7b68093889678ee4e566959872A4A
# 27  baseETH  0xAADf01DD90aE0A6Bb9Eb908294658037096E0404
# 28  baseETH  0xa6EFB95B7393cB419B48A933273F49b6bb48dd5D
# 29  baseETH  0xC3337192143EB496eed206C8c4249F7Cdee19078
# 30  baseETH  0xBd137c56f3116E5c36753037a784FF844F84F59c
# 31  baseETH  0x945a4f719018edBa445ca67bDa43663C815835Ad
# 32  baseETH  0x97c98De076cc8d3880c932DdaD4E4748eF8212c9
#
#                               destination_name  \
# 0                               autoETH (Idle)
# 1              Curve.fi Factory Pool: ETHx-ETH
# 2        Curve.fi Factory Pool: ETHx-ETH (old)
# 3                  Curve.fi Factory Pool: OETH
# 4                                    OETH/WETH
# 5                             Instadapp ETH v2
# 6                             wstETH (Holding)
# 7                             osETH/rETH (new)
# 8                             osETH/rETH (old)
# 9                           pxETH/stETH (main)
# 10                           pxETH/stETH (alt)
# 11                           pxETH/stETH (old)
# 12                             pxETH/wETH (v2)
# 13                           pxETH/wETH (main)
# 14                            pxETH/wETH (old)
# 15       Balancer pxETH/wETH StablePool (main)
# 16        Balancer pxETH/wETH StablePool (old)
# 17                 Balancer ETHx/wstETH (main)
# 18                  Balancer ETHx/wstETH (old)
# 19            Balancer Surge Fluid wstETH-wETH
# 20                Balancer osETH-waWETH (main)
# 21                 Balancer osETH-waWETH (alt)
# 22              Balancer weETH/rETH StablePool
# 23                            wETH/rETH (main)
# 24                             wETH/rETH (old)
# 25                               weETH/WETH-ng
# 26                     wstETH-rETH-sfrxETH-BPT
# 27                              baseETH (Idle)
# 28              Balancer rETH-WETH Stable Pool
# 29                     Balancer rETH-Aave wETH
# 30                 Gyroscope ECLP cbETH/wstETH
# 31  Volatile AMM - weETH.base/WETH (Aerodrome)
# 32            Balancer Surge Aave wstETH-fWETH
#
#                                   pool_address    exchange  \
# 0   0x0A2b94F6871c1D7A32Fe58E1ab5e6deA2f114E56     tokemak
# 1   0x59Ab5a5b5d617E478a2479B0cAD80DA7e2831492       curve
# 2   0x59Ab5a5b5d617E478a2479B0cAD80DA7e2831492       curve
# 3   0x94B17476A93b3262d87B9a326965D1E91f9c13E7       curve
# 4   0xcc7d5785AD5755B6164e21495E07aDb0Ff11C2A8       curve
# 5   0xA0D3707c569ff8C87FA923d3823eC5D81c98Be78       fluid
# 6   0x7f39C581F595B53c5cb19bD0b3f8dA6c935E2Ca0        lido
# 7   0xe080027Bd47353b5D1639772b4a75E9Ed3658A0d       curve
# 8   0xe080027Bd47353b5D1639772b4a75E9Ed3658A0d       curve
# 9   0x6951bDC4734b9f7F3E1B74afeBC670c736A0EDB6       curve
# 10  0x6951bDC4734b9f7F3E1B74afeBC670c736A0EDB6       curve
# 11  0x6951bDC4734b9f7F3E1B74afeBC670c736A0EDB6       curve
# 12  0xC8Eb2Cf2f792F77AF0Cd9e203305a585E588179D       curve
# 13  0xC8Eb2Cf2f792F77AF0Cd9e203305a585E588179D       curve
# 14  0xC8Eb2Cf2f792F77AF0Cd9e203305a585E588179D       curve
# 15  0x88794C65550DeB6b4087B7552eCf295113794410    balancer
# 16  0x88794C65550DeB6b4087B7552eCf295113794410    balancer
# 17  0xB91159aa527D4769CB9FAf3e4ADB760c7E8C8Ea7    balancer
# 18  0xB91159aa527D4769CB9FAf3e4ADB760c7E8C8Ea7    balancer
# 19  0x6b31a94029fd7840d780191B6D63Fa0D269bd883  balancerV3
# 20  0x57c23c58B1D8C3292c15BEcF07c62C5c52457A42  balancerV3
# 21  0x57c23c58B1D8C3292c15BEcF07c62C5c52457A42  balancerV3
# 22  0x05ff47AFADa98a98982113758878F9A8B9FddA0a    balancer
# 23  0x9EfE1A1Cbd6Ca51Ee8319AFc4573d253C3B732af       curve
# 24  0x9EfE1A1Cbd6Ca51Ee8319AFc4573d253C3B732af       curve
# 25  0xDB74dfDD3BB46bE8Ce6C33dC9D82777BCFc3dEd5       curve
# 26  0x42ED016F826165C2e5976fe5bC3df540C5aD0Af7    balancer
# 27  0xAADf01DD90aE0A6Bb9Eb908294658037096E0404     tokemak
# 28  0xC771c1a5905420DAEc317b154EB13e4198BA97D0    balancer
# 29  0xB7B8B3AfC010169779C5C2385ec0eB0477FE3347  balancerV3
# 30  0x54D86E177cdC664B5F9B17eB5fd6A76Fa529e466    balancer
# 31  0x91F0f34916Ca4E2cCe120116774b0e4fA0cdcaA8   aerodrome
# 32  0x9972c4f21b5Ae6062233031314aDbBddA7513Ed2  balancerV3
#
#                        vp_function vp_status  \
# 0                 N/A - always 1.0        OK
# 1     get_virtual_price()(uint256)        OK
# 2     get_virtual_price()(uint256)   SUSPECT
# 3     get_virtual_price()(uint256)   SUSPECT
# 4     get_virtual_price()(uint256)   SUSPECT
# 5         exchangePrice()(uint256)        OK
# 6         stEthPerToken()(uint256)        OK
# 7     get_virtual_price()(uint256)        OK
# 8     get_virtual_price()(uint256)     WRONG
# 9     get_virtual_price()(uint256)        OK
# 10    get_virtual_price()(uint256)        OK
# 11    get_virtual_price()(uint256)     WRONG
# 12    get_virtual_price()(uint256)  MARGINAL
# 13    get_virtual_price()(uint256)        OK
# 14    get_virtual_price()(uint256)   SUSPECT
# 15              getRate()(uint256)        OK
# 16              getRate()(uint256)   SUSPECT
# 17              getRate()(uint256)        OK
# 18              getRate()(uint256)     WRONG
# 19              getRate()(uint256)        OK
# 20              getRate()(uint256)        OK
# 21              getRate()(uint256)        OK
# 22              getRate()(uint256)        OK
# 23    get_virtual_price()(uint256)        OK
# 24    get_virtual_price()(uint256)        OK
# 25    get_virtual_price()(uint256)        OK
# 26              getRate()(uint256)     WRONG
# 27                N/A - always 1.0        OK
# 28              getRate()(uint256)        OK
# 29              getRate()(uint256)   SUSPECT
# 30              getRate()(uint256)     WRONG
# 31  getK()/totalSupply() [SPECIAL]     WRONG
# 32              getRate()(uint256)        OK
#
#                                                 notes
# 0                  autopool itself - VP is always 1.0
# 1                VP ~1.036-1.045 reasonable for Curve
# 2   VP ~1.0025 - same pool as 0x1Ea6 but VP way lo...
# 3   VP ~1.0023 - hardcoded override in augment_pla...
# 4   VP ~1.0002 - only 2 events; very low VP sugges...
# 5   VP ~1.17-1.20 reasonable; hardcoded override i...
# 6   VP ~1.21 reasonable for wstETH; hardcoded over...
# 7           VP ~1.028-1.048 reasonable for Curve pool
# 8   VP ~1.0025 - SHOULD use same pool as 0x3F55 bu...
# 9   VP ~1.01-1.02 reasonable; hardcoded override i...
# 10          VP ~1.022 reasonable; same pool as 0xe443
# 11  VP ~1.0025 - same pool as 0xe443 but VP way lo...
# 12  VP ~1.004 - same pool as 0xbA14 and 0xE382; VP...
# 13  VP ~1.001-1.003; low but consistent with low-f...
# 14  VP ~1.0025 - old DV; may resolve to wrong pool...
# 15  VP ~1.003-1.004; hardcoded override in augment...
# 16  VP ~1.0025 - same pool as 0xc4Eb but VP lower;...
# 17            VP ~1.015-1.025 reasonable for Balancer
# 18  VP ~1.0025 - same pool as 0xdfE3 but VP way lo...
# 19          VP ~1.008-1.014 reasonable for BalancerV3
# 20                         VP ~1.011-1.012 reasonable
# 21                            VP ~1.011; only 1 event
# 22                         VP ~1.031-1.033 reasonable
# 23                               VP ~1.012 reasonable
# 24                           VP ~1.011; only 2 events
# 25                         VP ~1.045-1.055 reasonable
# 26  VP starts 0.000088 drops to 0.000003 giving -1...
# 27                 autopool itself - VP is always 1.0
# 28                               VP ~1.024 reasonable
# 29  VP ~1.004 - low for a yield-bearing pool; may ...
# 30  VP ~0.003 - getRate() returns near-zero; Gyros...
# 31  VP ~1.7e21 raw K not normalized; also augment_...
# 32  VP ~1.005; only 4 events but reasonable for ne...

# %%
blocks = build_blocks_to_use(ETH_CHAIN)
surge_pool = "0x6b31a94029fd7840d780191B6D63Fa0D269bd883"
surge_call = Call(
    surge_pool,
    "getRate()(uint256)",
    [("rate", safe_normalize_with_bool_success)],
)
df = get_raw_state_by_blocks([surge_call], blocks, ETH_CHAIN)
df
# Out:
#                                rate
# timestamp
# 2024-09-10 23:59:11+00:00       NaN
# 2024-09-11 23:57:11+00:00       NaN
# 2024-09-12 22:57:35+00:00       NaN
# 2024-09-13 23:58:11+00:00       NaN
# 2024-09-14 23:59:47+00:00       NaN
# ...                             ...
# 2026-02-22 23:59:47+00:00  1.023298
# 2026-02-23 23:59:47+00:00  1.023377
# 2026-02-24 23:59:47+00:00  1.023476
# 2026-02-25 23:59:47+00:00  1.023544
# 2026-02-26 23:59:47+00:00  1.023610
#
# [535 rows x 1 columns]

# %%
import plotly.express as px

px.line(df, title='wstETH-wETH Surge Fluid VP Over Time')

# %%
# vp unsually spike on aug 1 and 2, see where the errors cluster

# %%
def get_chain(autopool_name: str):
    if autopool_name == "baseETH":
        return BASE_CHAIN
    return ETH_CHAIN


CALLABLE_SIGNATURES = {
    "get_virtual_price()(uint256)",
    "getRate()(uint256)",
    "stEthPerToken()(uint256)",
    "exchangePrice()(uint256)",
    "getInvariantDivActualSupply()(uint256)",
}

results = []

for _, row in mapping.iterrows():
    vp_function = row["vp_function"]
    pool_address = row["pool_address"]
    dv = row["destination_vault_address"]
    chain = get_chain(row["autopool"])
    latest_block = chain.get_block_near_top()

    if vp_function not in CALLABLE_SIGNATURES:
        results.append(
            {
                "autopool": row["autopool"],
                "destination_name": row["destination_name"],
                "dv": dv,
                "pool": pool_address,
                "vp_function": vp_function,
                "vp_value": "N/A (special)",
                "block": latest_block,
            }
        )
        continue

    call = Call(
        pool_address,
        vp_function,
        [("vp", safe_normalize_with_bool_success)],
    )
    try:
        state = get_state_by_one_block([call], latest_block, chain)
        vp_value = state["vp"]
    except Exception as e:
        vp_value = f"ERROR: {e}"

    results.append(
        {
            "autopool": row["autopool"],
            "destination_name": row["destination_name"],
            "dv": dv,
            "pool": pool_address,
            "vp_function": vp_function,
            "vp_value": vp_value,
            "block": latest_block,
        }
    )
# aerodrome has 0 fee and base apr?
results_df = pd.DataFrame(results)
results_df
# Out:
#    autopool                            destination_name  \
# 0   autoETH                              autoETH (Idle)
# 1   autoETH             Curve.fi Factory Pool: ETHx-ETH
# 2   autoETH       Curve.fi Factory Pool: ETHx-ETH (old)
# 3   autoETH                 Curve.fi Factory Pool: OETH
# 4   autoETH                                   OETH/WETH
# 5   autoETH                            Instadapp ETH v2
# 6   autoETH                            wstETH (Holding)
# 7   autoETH                            osETH/rETH (new)
# 8   autoETH                            osETH/rETH (old)
# 9   autoETH                          pxETH/stETH (main)
# 10  autoETH                           pxETH/stETH (alt)
# 11  autoETH                           pxETH/stETH (old)
# 12  autoETH                             pxETH/wETH (v2)
# 13  autoETH                           pxETH/wETH (main)
# 14  autoETH                            pxETH/wETH (old)
# 15  autoETH       Balancer pxETH/wETH StablePool (main)
# 16  autoETH        Balancer pxETH/wETH StablePool (old)
# 17  autoETH                 Balancer ETHx/wstETH (main)
# 18  autoETH                  Balancer ETHx/wstETH (old)
# 19  autoETH            Balancer Surge Fluid wstETH-wETH
# 20  autoETH                Balancer osETH-waWETH (main)
# 21  autoETH                 Balancer osETH-waWETH (alt)
# 22  autoETH              Balancer weETH/rETH StablePool
# 23  autoETH                            wETH/rETH (main)
# 24  autoETH                             wETH/rETH (old)
# 25  autoETH                               weETH/WETH-ng
# 26  autoETH                     wstETH-rETH-sfrxETH-BPT
# 27  baseETH                              baseETH (Idle)
# 28  baseETH              Balancer rETH-WETH Stable Pool
# 29  baseETH                     Balancer rETH-Aave wETH
# 30  baseETH                 Gyroscope ECLP cbETH/wstETH
# 31  baseETH  Volatile AMM - weETH.base/WETH (Aerodrome)
# 32  baseETH            Balancer Surge Aave wstETH-fWETH
#
#                                             dv  \
# 0   0x0A2b94F6871c1D7A32Fe58E1ab5e6deA2f114E56
# 1   0x1Ea622fa030e4a78F4CC2f305dd3c08DA3F08573
# 2   0xC001f23397dB71B17602Ce7D90a983Edc38DB0d1
# 3   0x3772973f8F399D74488D5cF3276C032E0afC8A6f
# 4   0x28109255F49f0A02BB31358B3e0b5cb7512EB4eC
# 5   0x2C7120dCCF1c14A37A26A4955475d45d34a3d7E7
# 6   0xd100c932801390fdeBcE11F26f611D4898b44236
# 7   0x3F55eedDe51504E6Ed0ec30E8289b4Da11EdB7F9
# 8   0x896eCc16Ab4AFfF6cE0765A5B924BaECd7Fa455a
# 9   0xe4433D00Cf48BFE0C672d9949F2cd2c008bffC04
# 10  0x2E0E2AB6505A1182367DFB1e3c66648bF3EEA020
# 11  0xd96E943098B2AE81155e98D7DC8BeaB34C539f01
# 12  0x43D99d04985ef2231f7d9b5D9111D2189d9FD971
# 13  0xbA1462f43c6f60ebD1C62735c94E428aD073E01A
# 14  0xE382BBd32C4E202185762eA433278f4ED9E6151E
# 15  0xc4Eb861e7b66f593482a3D7E8adc314f6eEDA30B
# 16  0x8cA2201BC34780f14Bca452913ecAc8e9928d4cA
# 17  0xdfE3fA7027E84f59b266459C567278C79fe86f0C
# 18  0xfB6f99FdF12E37Bfe3c4Cf81067faB10c465fb24
# 19  0x9b163e15121816BE53F8d5c85fbefD6e6D9bebCd
# 20  0x87E25fFe5C3A2720Cd43F5Eb8ec41Ac0CE699D07
# 21  0x4142e3a17391676C66DDf1285E43889F168EE237
# 22  0x40219bBda953ca811d2D0168Dc806a96b84791d9
# 23  0x2B08137BeABd2454AD3631DEB754F97C5c93eB78
# 24  0x6a8C6ff78082a2ae494EB9291DdC7254117298Ff
# 25  0x5c6aeb9ef0d5BbA4E6691f381003503FD0D45126
# 26  0x5b39015f01A7b68093889678ee4e566959872A4A
# 27  0xAADf01DD90aE0A6Bb9Eb908294658037096E0404
# 28  0xa6EFB95B7393cB419B48A933273F49b6bb48dd5D
# 29  0xC3337192143EB496eed206C8c4249F7Cdee19078
# 30  0xBd137c56f3116E5c36753037a784FF844F84F59c
# 31  0x945a4f719018edBa445ca67bDa43663C815835Ad
# 32  0x97c98De076cc8d3880c932DdaD4E4748eF8212c9
#
#                                           pool  \
# 0   0x0A2b94F6871c1D7A32Fe58E1ab5e6deA2f114E56
# 1   0x59Ab5a5b5d617E478a2479B0cAD80DA7e2831492
# 2   0x59Ab5a5b5d617E478a2479B0cAD80DA7e2831492
# 3   0x94B17476A93b3262d87B9a326965D1E91f9c13E7
# 4   0xcc7d5785AD5755B6164e21495E07aDb0Ff11C2A8
# 5   0xA0D3707c569ff8C87FA923d3823eC5D81c98Be78
# 6   0x7f39C581F595B53c5cb19bD0b3f8dA6c935E2Ca0
# 7   0xe080027Bd47353b5D1639772b4a75E9Ed3658A0d
# 8   0xe080027Bd47353b5D1639772b4a75E9Ed3658A0d
# 9   0x6951bDC4734b9f7F3E1B74afeBC670c736A0EDB6
# 10  0x6951bDC4734b9f7F3E1B74afeBC670c736A0EDB6
# 11  0x6951bDC4734b9f7F3E1B74afeBC670c736A0EDB6
# 12  0xC8Eb2Cf2f792F77AF0Cd9e203305a585E588179D
# 13  0xC8Eb2Cf2f792F77AF0Cd9e203305a585E588179D
# 14  0xC8Eb2Cf2f792F77AF0Cd9e203305a585E588179D
# 15  0x88794C65550DeB6b4087B7552eCf295113794410
# 16  0x88794C65550DeB6b4087B7552eCf295113794410
# 17  0xB91159aa527D4769CB9FAf3e4ADB760c7E8C8Ea7
# 18  0xB91159aa527D4769CB9FAf3e4ADB760c7E8C8Ea7
# 19  0x6b31a94029fd7840d780191B6D63Fa0D269bd883
# 20  0x57c23c58B1D8C3292c15BEcF07c62C5c52457A42
# 21  0x57c23c58B1D8C3292c15BEcF07c62C5c52457A42
# 22  0x05ff47AFADa98a98982113758878F9A8B9FddA0a
# 23  0x9EfE1A1Cbd6Ca51Ee8319AFc4573d253C3B732af
# 24  0x9EfE1A1Cbd6Ca51Ee8319AFc4573d253C3B732af
# 25  0xDB74dfDD3BB46bE8Ce6C33dC9D82777BCFc3dEd5
# 26  0x42ED016F826165C2e5976fe5bC3df540C5aD0Af7
# 27  0xAADf01DD90aE0A6Bb9Eb908294658037096E0404
# 28  0xC771c1a5905420DAEc317b154EB13e4198BA97D0
# 29  0xB7B8B3AfC010169779C5C2385ec0eB0477FE3347
# 30  0x54D86E177cdC664B5F9B17eB5fd6A76Fa529e466
# 31  0x91F0f34916Ca4E2cCe120116774b0e4fA0cdcaA8
# 32  0x9972c4f21b5Ae6062233031314aDbBddA7513Ed2
#
#                        vp_function       vp_value     block
# 0                 N/A - always 1.0  N/A (special)  24549872
# 1     get_virtual_price()(uint256)       1.056589  24549872
# 2     get_virtual_price()(uint256)       1.056589  24549872
# 3     get_virtual_price()(uint256)       1.002824  24549872
# 4     get_virtual_price()(uint256)       1.001344  24549872
# 5         exchangePrice()(uint256)       1.202138  24549872
# 6         stEthPerToken()(uint256)       1.228044  24549872
# 7     get_virtual_price()(uint256)       1.066379  24549872
# 8     get_virtual_price()(uint256)       1.066379  24549872
# 9     get_virtual_price()(uint256)       1.026724  24549872
# 10    get_virtual_price()(uint256)       1.026724  24549872
# 11    get_virtual_price()(uint256)       1.026724  24549872
# 12    get_virtual_price()(uint256)       1.004588  24549872
# 13    get_virtual_price()(uint256)       1.004588  24549872
# 14    get_virtual_price()(uint256)       1.004588  24549872
# 15              getRate()(uint256)       1.005884  24549872
# 16              getRate()(uint256)       1.005884  24549872
# 17              getRate()(uint256)            0.0  24549872
# 18              getRate()(uint256)            0.0  24549872
# 19              getRate()(uint256)       1.023671  24549872
# 20              getRate()(uint256)       1.026175  24549872
# 21              getRate()(uint256)       1.026175  24549872
# 22              getRate()(uint256)            0.0  24549872
# 23    get_virtual_price()(uint256)        1.03937  24549872
# 24    get_virtual_price()(uint256)        1.03937  24549872
# 25    get_virtual_price()(uint256)       1.067771  24549872
# 26              getRate()(uint256)       0.000003  24549872
# 27                N/A - always 1.0  N/A (special)  42712661
# 28              getRate()(uint256)            0.0  42712661
# 29              getRate()(uint256)       1.020137  42712661
# 30              getRate()(uint256)       0.003521  42712661
# 31  getK()/totalSupply() [SPECIAL]  N/A (special)  42712661
# 32              getRate()(uint256)       1.020263  42712661

# %%
suspect_destination_vault_address = '0x5c6aeb9ef0d5BbA4E6691f381003503FD0D45126'
results_df[results_df['dv'] == suspect_destination_vault_address].T

# need the calculator of 0x5c6aeb9ef0d5BbA4E6691f381003503FD0D45126
# Out:
#                                                           25
# autopool                                             autoETH
# destination_name                               weETH/WETH-ng
# dv                0x5c6aeb9ef0d5BbA4E6691f381003503FD0D45126
# pool              0xDB74dfDD3BB46bE8Ce6C33dC9D82777BCFc3dEd5
# vp_function                     get_virtual_price()(uint256)
# vp_value                                            1.067583
# block                                               24530166

# %%
# Aerodrome special case: getK() / totalSupply()
from mainnet_launch.adhoc.fee_and_base_apr_checks.augment_plans import compute_aerodome_vp

aero_dv = "0x945a4f719018edBa445ca67bDa43663C815835Ad"
aero_block = BASE_CHAIN.get_block_near_top()
aero_vp = compute_aerodome_vp(aero_dv, aero_block, BASE_CHAIN)
print(f"Aerodrome weETH/WETH VP (K/totalSupply) at block {aero_block}: {aero_vp:.6e}")
# Out:
# Aerodrome weETH/WETH VP (K/totalSupply) at block 42593907: 2.219218e+20

# %%
# Flag suspicious values
numeric_results = results_df[results_df["vp_value"].apply(lambda x: isinstance(x, (int, float)))].copy()
numeric_results["vp_value"] = numeric_results["vp_value"].astype(float)

suspicious = numeric_results[(numeric_results["vp_value"] < 0.01) | (numeric_results["vp_value"] > 100)]

if len(suspicious) > 0:
    print(f"Found {len(suspicious)} suspicious VP values (< 0.01 or > 100):")
    print(suspicious[["autopool", "destination_name", "vp_function", "vp_value"]].to_string(index=False))
else:
    print("All VP values look reasonable.")

print(f"\nSummary: {len(numeric_results)} callable, {len(results_df) - len(numeric_results)} special/error")
# Out:
# Found 6 suspicious VP values (< 0.01 or > 100):
# autopool               destination_name        vp_function     vp_value
#  autoETH    Balancer ETHx/wstETH (main) getRate()(uint256) 5.568482e-08
#  autoETH     Balancer ETHx/wstETH (old) getRate()(uint256) 5.568482e-08
#  autoETH Balancer weETH/rETH StablePool getRate()(uint256) 0.000000e+00
#  autoETH        wstETH-rETH-sfrxETH-BPT getRate()(uint256) 2.860760e-06
#  baseETH Balancer rETH-WETH Stable Pool getRate()(uint256) 0.000000e+00
#  baseETH    Gyroscope ECLP cbETH/wstETH getRate()(uint256) 3.520157e-03
#
# Summary: 30 callable, 3 special/error
