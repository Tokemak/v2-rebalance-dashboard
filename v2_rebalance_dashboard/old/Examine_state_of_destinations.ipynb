# %%
import pandas as pd
import plotly.express as px
import json
from glob import glob

a = None


def get_state_of_destination(json_path: str) -> pd.DataFrame:
    try:
        with open(json_path, "r") as fin:
            data = json.load(fin)
        state_of_destinations = data["sod"]["destStates"]
        # name starts august 5th,
        raw_df = pd.DataFrame.from_records(state_of_destinations)
        raw_df["Date"] = pd.to_datetime(data["sod"]["currentTimestamp"], unit="s")
        raw_df["autopool_address"] = data["poolAddress"]
        raw_df["json_name"] = json_path

        return raw_df
    except Exception as e:

        print(json_path, e)
        return pd.DataFrame()


paths = glob("../fetched_data/*")
raw_df = pd.concat([get_state_of_destination(p) for p in paths])
raw_df["autopool_address"].value_counts()
# Out:
# ../fetched_data/rebalance_records.json Expecting value: line 1 column 1 (char 0)
# ../fetched_data/rebalance_plan.json 'sod'
# ../fetched_data/rebalance_plan (18).json 'sod'
# autopool_address
#                                               4375
# 0x49C4719EaCc746b87703F964F09C22751F397BA0    3342
# 0x72cf6d7C85FfD73F18a83989E7BA8C1c30211b73     112
# Name: count, dtype: int64

# %%
#  'sodOnly': True, -> No proposed rebalance
# 'sodOnly': True, -> Yes proposed rebalance

# %%
with open("../fetched_data/rebalance_plan_1723339958_0x72cf6d7C85FfD73F18a83989E7BA8C1c30211b73.json", "r") as fin:
    data = json.load(fin)
    # pool address can be empty is there is no destination plan
data["date"]
# Out:
# {'timestamp': 1723339958,
#  'sodOnly': True,
#  'chainId': '1',
#  'solverAddress': '0x2C26808b567BA224652f4eB20D45df4bccC29470',
#  'poolAddress': '',
#  'destinationOut': '',
#  'tokenOut': '',
#  'amountOut': '',
#  'amountOutETH': '',
#  'destinationIn': '',
#  'tokenIn': '',
#  'minAmountIn': '',
#  'minAmountInETH': '',
#  'steps': [],
#  'sod': {'currentTimestamp': 1723339958,
#   'destStates': [{'snapshotTimestamp': 0,
#     'name': 'Tokemak-Wrapped Ether-Balancer stETH Stable Pool',
#     'address': '0x38e73E98d2038FafdC847F13dd9100732383B6F2',
#     'poolType': 'balMetaStable',
#     'pool': '0x32296969Ef14EB0c6d29669C550D4a0449130230',
#     'underlying': '0x32296969Ef14EB0c6d29669C550D4a0449130230',
#     'underlyingTokens': ['0x7f39C581F595B53c5cb19bD0b3f8dA6c935E2Ca0',
#      '0xC02aaA39b223FE8D0A0e5C4F27eAD9083C756Cc2'],
#     'underlyingTokenAmounts': [268498489174720994753, 308698409307532091857],
#     'underlyingReserves': [315538836082128422734, 308698409307532091857],
#     'totalAprIn': 0.02895215156282984,
#     'totalAprOut': 0.029064386124290388,
#     'incentiveAPR': 0.0,
#     'destLPValue': 0,
#     'discountViolationAddFlag': [False, False],
#     'discountViolationTrim1Flag': [False, False],
#     'discountViolationTrim2Flag': [False, False],
#     'ownedShares': 0,
#     'totSupply': 0,
#     'safePrice': 1.0496247250538846,
#     'spotPrice': 1.0496230584511217,
#     'tokenSpotPrice': [1.1750337406875042, 1.0],
#     'tokenSafePrice': [1.1751978085686607, 1.0],
#     'flipFlag': False},
#    {'snapshotTimestamp': 0,
#     'name': 'Tokemak-Wrapped Ether-Balancer rETH Stable Pool',
#     'address': '0xfb1f48a461cCC70081226d8353e45CfBd410dD8F',
#     'poolType': 'balMetaStable',
#     'pool': '0x1E19CF2D73a72Ef1332C882F20534B6519Be0276',
#     'underlying': '0x1E19CF2D73a72Ef1332C882F20534B6519Be0276',
#     'underlyingTokens': ['0xae78736Cd615f374D3085123A210448E74Fc6393',
#      '0xC02aaA39b223FE8D0A0e5C4F27eAD9083C756Cc2'],
#     'underlyingTokenAmounts': [6358764908050425771782, 7717460143210603869384],
#     'underlyingReserves': [7088082883763722175747, 7717460143210603869384],
#     'totalAprIn': 0.04074227787951201,
#     'totalAprOut': 0.0516411189871174,
#     'incentiveAPR': 0.0358011909073977,
#     'destLPValue': 1.3817476880166763e+22,
#     'discountViolationAddFlag': [False, False],
#     'discountViolationTrim1Flag': [False, False],
#     'discountViolationTrim2Flag': [False, False],
#     'ownedShares': 0,
#     'totSupply': 0,
#     'safePrice': 1.0355632248089768,
#     'spotPrice': 1.035538184060264,
#     'tokenSpotPrice': [1.115333389600493, 1.0],
#     'tokenSafePrice': [1.1146949110809166, 1.0],
#     'flipFlag': False},
#    {'snapshotTimestamp': 0,
#     'name': 'Tokemak-Wrapped Ether-Balancer rsETH / ETHx',
#     'address': '0x37e565f997c2b16d2542E906672E9c6281e77954',
#     'poolType': 'balCompStable',
#     'pool': '0x7761b6E0Daa04E70637D81f1Da7d186C205C2aDE',
#     'underlying': '0x7761b6E0Daa04E70637D81f1Da7d186C205C2aDE',
#     'underlyingTokens': ['0xA1290d69c65A6Fe4DF752f95823fae25cB99e5A7',
#      '0xA35b1B31Ce002FBF2058D22F30f95D405200A15b'],
#     'underlyingTokenAmounts': [1098676149156536972030, 294640346993539354357],
#     'underlyingReserves': [1117216935418958552659, 305263598811584475907],
#     'totalAprIn': 0.03635301301186341,
#     'totalAprOut': 0.09343378245743575,
#     'incentiveAPR': 0.012054157651074033,
#     'destLPValue': 3.204533257427394e+20,
#     'discountViolationAddFlag': [False, False],
#     'discountViolationTrim1Flag': [False, False],
#     'discountViolationTrim2Flag': [False, False],
#     'ownedShares': 0,
#     'totSupply': 0,
#     'safePrice': 1.0125943252500336,
#     'spotPrice': 1.0124914320471936,
#     'tokenSpotPrice': [1.0166945417793325, 1.0362394361828815],
#     'tokenSafePrice': [1.01687557, 1.03605498],
#     'flipFlag': False},
#    {'snapshotTimestamp': 0,
#     'name': 'Tokemak-Wrapped Ether-Gyroscope ECLP wstETH/cbETH',
#     'address': '0x8C598Be7D29ca09d847275356E1184F166B96931',
#     'poolType': 'balGyro',
#     'pool': '0xF7A826D47c8E02835D94fb0Aa40F0cC9505cb134',
#     'underlying': '0xF7A826D47c8E02835D94fb0Aa40F0cC9505cb134',
#     'underlyingTokens': ['0x7f39C581F595B53c5cb19bD0b3f8dA6c935E2Ca0',
#      '0xBe9895146f7AF43049ca1c1AE358B0541Ea49704'],
#     'underlyingTokenAmounts': [26476737868312161089, 366949383255257952545],
#     'underlyingReserves': [99461800056981180885, 326607094471045968549],
#     'totalAprIn': 0.03341136691802343,
#     'totalAprOut': 0.07698763878650862,
#     'incentiveAPR': 0.003946368099175654,
#     'destLPValue': 4.226734638345287e+20,
#     'discountViolationAddFlag': [False, False],
#     'discountViolationTrim1Flag': [False, False],
#     'discountViolationTrim2Flag': [False, False],
#     'ownedShares': 0,
#     'totSupply': 418646358902968658448,
#     'safePrice': 1.0177596530498878,
#     'spotPrice': 1.0184750669846239,
#     'tokenSpotPrice': [1.1742313020874204, 1.0772359406568652],
#     'tokenSafePrice': [1.1751978085686607, 1.07635],
#     'flipFlag': False},
#    {'snapshotTimestamp': 0,
#     'name': 'Tokemak-Wrapped Ether-Balancer osETH/wETH StablePool',
#     'address': '0xA6B62bFdc664Af24DDdfF335A167b867f1d590aF',
#     'poolType': 'balCompStable',
#     'pool': '0xDACf5Fa19b1f720111609043ac67A9818262850c',
#     'underlying': '0xDACf5Fa19b1f720111609043ac67A9818262850c',
#     'underlyingTokens': ['0xC02aaA39b223FE8D0A0e5C4F27eAD9083C756Cc2',
#      '0xf1C9acDc66974dFB6dEcB12aA385b9cD01190E38'],
#     'underlyingTokenAmounts': [11070187952949934210548,
#      7991148996714831917079],
#     'underlyingReserves': [11070187952949934210548, 8192756016611661101400],
#     'totalAprIn': 0.034801271629550816,
#     'totalAprOut': 0.034801271629550816,
#     'incentiveAPR': 0.024314091076293138,
#     'destLPValue': 6.129253524640446e+21,
#     'discountViolationAddFlag': [False, False],
#     'discountViolationTrim1Flag': [False, False],
#     'discountViolationTrim2Flag': [False, False],
#     'ownedShares': 0,
#     'totSupply': 0,
#     'safePrice': 1.0108516249585728,
#     'spotPrice': 1.0108416791212458,
#     'tokenSpotPrice': [1.0, 1.025296331709128],
#     'tokenSafePrice': [1.0, 1.02522879],
#     'flipFlag': False},
#    {'snapshotTimestamp': 0,
#     'name': 'Tokemak-Wrapped Ether-Balancer wstETH-WETH Stable Pool',
#     'address': '0xF35fbb601e7de870029691f1872D67A8fC866B15',
#     'poolType': 'balCompStable',
#     'pool': '0x93d199263632a4EF4Bb438F1feB99e57b4b5f0BD',
#     'underlying': '0x93d199263632a4EF4Bb438F1feB99e57b4b5f0BD',
#     'underlyingTokens': ['0x7f39C581F595B53c5cb19bD0b3f8dA6c935E2Ca0',
#      '0xC02aaA39b223FE8D0A0e5C4F27eAD9083C756Cc2'],
#     'underlyingTokenAmounts': [3089845572991561468136, 1234355504621897664184],
#     'underlyingReserves': [3631179746195261268295, 1234355504621897664184],
#     'totalAprIn': 0.04769484032222082,
#     'totalAprOut': 0.05156156170628854,
#     'incentiveAPR': 0.017325454419426855,
#     'destLPValue': 3.970851472963747e+21,
#     'discountViolationAddFlag': [False, False],
#     'discountViolationTrim1Flag': [False, False],
#     'discountViolationTrim2Flag': [False, False],
#     'ownedShares': 0,
#     'totSupply': 0,
#     'safePrice': 1.027716043067346,
#     'spotPrice': 1.0276920036253452,
#     'tokenSpotPrice': [1.175142004750465, 1.0],
#     'tokenSafePrice': [1.1751978085686607, 1.0],
#     'flipFlag': False},
#    {'snapshotTimestamp': 0,
#     'name': 'Tokemak-Wrapped Ether-Balancer ETHx/wstETH',
#     'address': '0xa3956D49106288E5c04E6FBbBad5b68593f0bE3b',
#     'poolType': 'balCompStable',
#     'pool': '0xB91159aa527D4769CB9FAf3e4ADB760c7E8C8Ea7',
#     'underlying': '0xB91159aa527D4769CB9FAf3e4ADB760c7E8C8Ea7',
#     'underlyingTokens': ['0x7f39C581F595B53c5cb19bD0b3f8dA6c935E2Ca0',
#      '0xA35b1B31Ce002FBF2058D22F30f95D405200A15b'],
#     'underlyingTokenAmounts': [86512004851474932363, 134669605410390468511],
#     'underlyingReserves': [101668718516334696813, 139525115340069988645],
#     'totalAprIn': 0.052267446226034776,
#     'totalAprOut': 0.12048955749240002,
#     'incentiveAPR': 0.029099617488646288,
#     'destLPValue': 1.68946702845197e+20,
#     'discountViolationAddFlag': [False, False],
#     'discountViolationTrim1Flag': [False, False],
#     'discountViolationTrim2Flag': [False, False],
#     'ownedShares': 0,
#     'totSupply': 0,
#     'safePrice': 1.0085069634959969,
#     'spotPrice': 1.008559165449702,
#     'tokenSpotPrice': [1.1748105295296474, 1.0363964740543938],
#     'tokenSafePrice': [1.1751978085686607, 1.03605498],
#     'flipFlag': False},
#    {'snapshotTimestamp': 0,
#     'name': 'Tokemak-Wrapped Ether-Balancer swETH-WETH Stable Pool',
#     'address': '0xE9D758002676EecCfAc6106c1E31fE04e419c01D',
#     'poolType': 'balCompStable',
#     'pool': '0xE7e2c68d3b13d905BBb636709cF4DfD21076b9D2',
#     'underlying': '0xE7e2c68d3b13d905BBb636709cF4DfD21076b9D2',
#     'underlyingTokens': ['0xC02aaA39b223FE8D0A0e5C4F27eAD9083C756Cc2',
#      '0xf951E335afb289353dc249e82926178EaC7DEd78'],
#     'underlyingTokenAmounts': [23611265695174008817, 79675132358502748058],
#     'underlyingReserves': [23611265695174008817, 84785275444611804850],
#     'totalAprIn': 0.023562023391401114,
#     'totalAprOut': 0.025416976373905033,
#     'incentiveAPR': 0.0,
#     'destLPValue': 0,
#     'discountViolationAddFlag': [False, False],
#     'discountViolationTrim1Flag': [False, False],
#     'discountViolationTrim2Flag': [False, False],
#     'ownedShares': 0,
#     'totSupply': 0,
#     'safePrice': 1.0210435122578232,
#     'spotPrice': 1.0219326688575687,
#     'tokenSpotPrice': [1.0, 1.0657783554887579],
#     'tokenSafePrice': [1.0, 1.06413724],
#     'flipFlag': False},
#    {'snapshotTimestamp': 0,
#     'name': 'Tokemak-Wrapped Ether-Balancer weETH/rETH StablePool',
#     'address': '0x0D883F9600857a28CfBccb16b10095EAcF8055af',
#     'poolType': 'balCompStable',
#     'pool': '0x05ff47AFADa98a98982113758878F9A8B9FddA0a',
#     'underlying': '0x05ff47AFADa98a98982113758878F9A8B9FddA0a',
#     'underlyingTokens': ['0xae78736Cd615f374D3085123A210448E74Fc6393',
#      '0xCd5fE23C85820F7B72D0926FC9b05b43E359b7ee'],
#     'underlyingTokenAmounts': [795811819302869424563, 1860009650850435126545],
#     'underlyingReserves': [887087385154954501915, 1943143154197125494612],
#     'totalAprIn': 0.05836661288457039,
#     'totalAprOut': 0.05859383611651293,
#     'incentiveAPR': 0.03735086537671015,
#     'destLPValue': 2.2737618056108625e+21,
#     'discountViolationAddFlag': [False, False],
#     'discountViolationTrim1Flag': [False, False],
#     'discountViolationTrim2Flag': [False, False],
#     'ownedShares': 0,
#     'totSupply': 0,
#     'safePrice': 1.0175867098477431,
#     'spotPrice': 1.0175429029295868,
#     'tokenSpotPrice': [1.1148235331187768, 1.0445746630796966],
#     'tokenSafePrice': [1.1146949110809166, 1.0446952],
#     'flipFlag': False},
#    {'snapshotTimestamp': 0,
#     'name': 'Tokemak-Wrapped Ether-Balancer weETH-WETH Stable Pool',
#     'address': '0x5817Cc19A51F92a1fc2806C0228b323fa5be72a0',
#     'poolType': 'balCompStable',
#     'pool': '0xb9dEbDDF1d894c79D2B2d09f819FF9B856FCa552',
#     'underlying': '0xb9dEbDDF1d894c79D2B2d09f819FF9B856FCa552',
#     'underlyingTokens': ['0xC02aaA39b223FE8D0A0e5C4F27eAD9083C756Cc2',
#      '0xCd5fE23C85820F7B72D0926FC9b05b43E359b7ee'],
#     'underlyingTokenAmounts': [54132742799742719199, 60230649314992363396],
#     'underlyingReserves': [54132742799742719199, 62922670232255810076],
#     'totalAprIn': 0.05380295328668078,
#     'totalAprOut': 0.05398085715500426,
#     'incentiveAPR': 0.0,
#     'destLPValue': 0,
#     'discountViolationAddFlag': [False, False],
#     'discountViolationTrim1Flag': [False, False],
#     'discountViolationTrim2Flag': [False, False],
#     'ownedShares': 0,
#     'totSupply': 0,
#     'safePrice': 1.0669994027415277,
#     'spotPrice': 1.0670144439654965,
#     'tokenSpotPrice': [1.0, 1.0448914763830872],
#     'tokenSafePrice': [1.0, 1.0446952],
#     'flipFlag': False},
#    {'snapshotTimestamp': 0,
#     'name': 'Tokemak-Wrapped Ether-Balancer ezETH-WETH Stable Pool',
#     'address': '0x1E02da6E4DFc4875E372104E5e79d54632F52cB3',
#     'poolType': 'balCompStable',
#     'pool': '0x596192bB6e41802428Ac943D2f1476C1Af25CC0E',
#     'underlying': '0x596192bB6e41802428Ac943D2f1476C1Af25CC0E',
#     'underlyingTokens': ['0xbf5495Efe5DB9ce00f80364C8B423567e58d2110',
#      '0xC02aaA39b223FE8D0A0e5C4F27eAD9083C756Cc2'],
#     'underlyingTokenAmounts': [8267901087588828945561, 2154894852948554931794],
#     'underlyingReserves': [8376034981617142218021, 2154894852948554931794],
#     'totalAprIn': 0.04472816688811193,
#     'totalAprOut': 0.050635024124510326,
#     'incentiveAPR': 0.019935837391900687,
#     'destLPValue': 8.053112208871595e+21,
#     'discountViolationAddFlag': [False, False],
#     'discountViolationTrim1Flag': [False, False],
#     'discountViolationTrim2Flag': [False, False],
#     'ownedShares': 0,
#     'totSupply': 0,
#     'safePrice': 1.0111636894478542,
#     'spotPrice': 1.011443330581091,
#     'tokenSpotPrice': [1.0135529474667446, 1.0],
#     'tokenSafePrice': [1.01307876, 1.0],
#     'flipFlag': False},
#    {'snapshotTimestamp': 0,
#     'name': 'Tokemak-Wrapped Ether-Balancer weETH/ezETH/rswETH',
#     'address': '0x8A580F95bF9478C9EC9166E70F5bf2d489C15d8f',
#     'poolType': 'balCompStable',
#     'pool': '0x848a5564158d84b8A8fb68ab5D004Fae11619A54',
#     'underlying': '0x848a5564158d84b8A8fb68ab5D004Fae11619A54',
#     'underlyingTokens': ['0xbf5495Efe5DB9ce00f80364C8B423567e58d2110',
#      '0xCd5fE23C85820F7B72D0926FC9b05b43E359b7ee',
#      '0xFAe103DC9cf190eD75350761e95403b7b8aFa6c0'],
#     'underlyingTokenAmounts': [1153695534124996106629,
#      670575461881158950670,
#      945599184430903126157],
#     'underlyingReserves': [1168784441128888740708,
#      700546966265029726201,
#      959085452383142486868],
#     'totalAprIn': 0.0583298873015146,
#     'totalAprOut': 0.06865147483467528,
#     'incentiveAPR': 0.018432454988110688,
#     'destLPValue': 1.611721519150382e+21,
#     'discountViolationAddFlag': [False, False, False],
#     'discountViolationTrim1Flag': [False, False, False],
#     'discountViolationTrim2Flag': [False, False, False],
#     'ownedShares': 0,
#     'totSupply': 0,
#     'safePrice': 1.0137961502413961,
#     'spotPrice': 1.013900628466024,
#     'tokenSpotPrice': [1.0134194578430697,
#      1.0451061756865019,
#      1.0138632762766921],
#     'tokenSafePrice': [1.01307876, 1.0446952, 1.01426214],
#     'flipFlag': False},
#    {'snapshotTimestamp': 0,
#     'name': 'Tokemak-Wrapped Ether-Gyroscope ECLP wstETH/wETH',
#     'address': '0x9CA9B5dB35e5a48f2B147DaBB8e9848475094669',
#     'poolType': 'balGyro',
#     'pool': '0xf01b0684C98CD7aDA480BFDF6e43876422fa1Fc1',
#     'underlying': '0xf01b0684C98CD7aDA480BFDF6e43876422fa1Fc1',
#     'underlyingTokens': ['0x7f39C581F595B53c5cb19bD0b3f8dA6c935E2Ca0',
#      '0xC02aaA39b223FE8D0A0e5C4F27eAD9083C756Cc2'],
#     'underlyingTokenAmounts': [396061378694477695939, 43594251258155366143],
#     'underlyingReserves': [460624504528372398179, 47567148041457587801],
#     'totalAprIn': 0.022697565468406143,
#     'totalAprOut': 0.0764329225793592,
#     'incentiveAPR': 0.0,
#     'destLPValue': 5.0697581191556864e+20,
#     'discountViolationAddFlag': [False, False],
#     'discountViolationTrim1Flag': [False, False],
#     'discountViolationTrim2Flag': [False, False],
#     'ownedShares': 0,
#     'totSupply': 498834549187491342280,
#     'safePrice': 1.020468041733932,
#     'spotPrice': 1.0204270211365174,
#     'tokenSpotPrice': [1.1751408043225675, 1.0],
#     'tokenSafePrice': [1.1751978085686607, 1.0],
#     'flipFlag': False},
#    {'snapshotTimestamp': 0,
#     'name': 'Tokemak-Wrapped Ether-Balancer rsETH-WETH Stable Pool',
#     'address': '0x2B7612998d9c979b125d3A4F4Bb2aF88a80f0C0f',
#     'poolType': 'balCompStable',
#     'pool': '0x58AAdFB1Afac0ad7fca1148f3cdE6aEDF5236B6D',
#     'underlying': '0x58AAdFB1Afac0ad7fca1148f3cdE6aEDF5236B6D',
#     'underlyingTokens': ['0xA1290d69c65A6Fe4DF752f95823fae25cB99e5A7',
#      '0xC02aaA39b223FE8D0A0e5C4F27eAD9083C756Cc2'],
#     'underlyingTokenAmounts': [5031909018897875503148, 1139535950641381363101],
#     'underlyingReserves': [5116825351779917924052, 1139535950641381363101],
#     'totalAprIn': 0.028431035055344056,
#     'totalAprOut': 0.1564032073787037,
#     'incentiveAPR': 0.0,
#     'destLPValue': 1.636673218389447e+20,
#     'discountViolationAddFlag': [False, False],
#     'discountViolationTrim1Flag': [False, False],
#     'discountViolationTrim2Flag': [False, False],
#     'ownedShares': 79643301731919770984,
#     'totSupply': 0,
#     'safePrice': 1.00902560000711,
#     'spotPrice': 1.009046744297686,
#     'tokenSpotPrice': [1.0169090908268537, 1.0],
#     'tokenSafePrice': [1.01687557, 1.0],
#     'flipFlag': False}]},
#  'rebalanceTest': {'currentTimestamp': 1723339958,
#   'type': 'Pool2Pool',
#   'outDest': 'Tokemak-Wrapped Ether-Balancer rsETH-WETH Stable Pool',
#   'outSafeETH': 8.031476888133322e+19,
#   'outDestApr': 0.1564032073787037,
#   'inDest': 'Tokemak-Wrapped Ether-Balancer weETH/rETH StablePool',
#   'inSafeETH': 8.031476888133322e+19,
#   'inDestApr': 0.05836661288457039,
#   'inDestAdjApr': 0.05721973281385483,
#   'swapOffsetPeriod': 60}}

# %%
raw_df[raw_df["autopool_address"] == ""]["json_name"].values
# Out:
# array(['../fetched_data/rebalance_plan_1723339958_0x72cf6d7C85FfD73F18a83989E7BA8C1c30211b73.json',
#        '../fetched_data/rebalance_plan_1723339958_0x72cf6d7C85FfD73F18a83989E7BA8C1c30211b73.json',
#        '../fetched_data/rebalance_plan_1723339958_0x72cf6d7C85FfD73F18a83989E7BA8C1c30211b73.json',
#        ...,
#        '../fetched_data/rebalance_plan_1723987959_0x72cf6d7C85FfD73F18a83989E7BA8C1c30211b73.json',
#        '../fetched_data/rebalance_plan_1723987959_0x72cf6d7C85FfD73F18a83989E7BA8C1c30211b73.json',
#        '../fetched_data/rebalance_plan_1723987959_0x72cf6d7C85FfD73F18a83989E7BA8C1c30211b73.json'],
#       dtype=object)

# %%
raw_df[raw_df["autopool_address"] != ""]["Date"].min()
# Out:
# Timestamp('2024-06-28 05:43:42')

# %%
raw_df[raw_df["autopool_address"] != ""]["Date"].max()
# Out:
# Timestamp('2024-08-17 01:32:38')

# %%
paths[-1]
# Out:
# '../fetched_data/rebalance_plan_1722287299.json'

# %%
with open(paths[-1], "r") as fin:
    data = json.load(fin)

data.keys()
# Out:
# dict_keys(['timestamp', 'sodOnly', 'chainId', 'solverAddress', 'poolAddress', 'destinationOut', 'tokenOut', 'amountOut', 'amountOutETH', 'destinationIn', 'tokenIn', 'minAmountIn', 'minAmountInETH', 'steps', 'sod'])

# %%
data["poolAddress"]  # poolAddress is the autopool
# Out:
# '0x49C4719EaCc746b87703F964F09C22751F397BA0'

# %%
raw_df

# %%
# poolAddresses = raw_df.pivot_table(
#     columns="name", index="Date", values="poolAddress"
# ).sort_index()

# poolAddresses
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 poolAddresses = raw_df.pivot_table(
#       2     columns="name", index="Date", values="poolAddress"
#       3 ).sort_index()
#       5 poolAddresses
#
# File ~/Documents/Tokemak/v2-rebalance-dashboard/.venv/lib/python3.12/site-packages/pandas/core/frame.py:9509, in DataFrame.pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#    9492 @Substitution("")
#    9493 @Appender(_shared_docs["pivot_table"])
#    9494 def pivot_table(
#    (...)
#    9505     sort: bool = True,
#    9506 ) -> DataFrame:
#    9507     from pandas.core.reshape.pivot import pivot_table
# -> 9509     return pivot_table(
#    9510         self,
#    9511         values=values,
#    9512         index=index,
#    9513         columns=columns,
#    9514         aggfunc=aggfunc,
#    9515         fill_value=fill_value,
#    9516         margins=margins,
#    9517         dropna=dropna,
#    9518         margins_name=margins_name,
#    9519         observed=observed,
#    9520         sort=sort,
#    9521     )
#
# File ~/Documents/Tokemak/v2-rebalance-dashboard/.venv/lib/python3.12/site-packages/pandas/core/reshape/pivot.py:102, in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#      99     table = concat(pieces, keys=keys, axis=1)
#     100     return table.__finalize__(data, method="pivot_table")
# --> 102 table = __internal_pivot_table(
#     103     data,
#     104     values,
#     105     index,
#     106     columns,
#     107     aggfunc,
#     108     fill_value,
#     109     margins,
#     110     dropna,
#     111     margins_name,
#     112     observed,
#     113     sort,
#     114 )
#     115 return table.__finalize__(data, method="pivot_table")
#
# File ~/Documents/Tokemak/v2-rebalance-dashboard/.venv/lib/python3.12/site-packages/pandas/core/reshape/pivot.py:148, in __internal_pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#     146 for i in values:
#     147     if i not in data:
# --> 148         raise KeyError(i)
#     150 to_filter = []
#     151 for x in keys + values:
#
# KeyError: 'poolAddress'

# %%
# n aug5th forward

# %%
latest_sod = raw_df[raw_df["Date"] == raw_df["Date"].max()].copy()
latest_sod.columns
# Out:
# Index(['snapshotTimestamp', 'name', 'address', 'poolType', 'pool',
#        'underlying', 'underlyingTokens', 'underlyingTokenAmounts',
#        'underlyingReserves', 'totalAprIn', 'totalAprOut', 'incentiveAPR',
#        'destLPValue', 'discountViolationAddFlag', 'discountViolationTrim1Flag',
#        'discountViolationTrim2Flag', 'ownedShares', 'totSupply', 'safePrice',
#        'spotPrice', 'tokenSpotPrice', 'tokenSafePrice', 'flipFlag', 'Date'],
#       dtype='object')

# %%
# underlyingReserves in Eth terms, in each token, eth value in pool itself.

# %%
latest_sod[["name", "totalAprIn", "totalAprOut"]]  # total apr in and out, no dilution.
# Out:
#                                                  name  totalAprIn  totalAprOut
# 0            Tokemak-Wrapped Ether-Curve.fi ETH/stETH    0.019498     0.019553
# 1   Tokemak-Wrapped Ether-Curve.fi Factory Pool: s...    0.022861     0.024399
# 2   Tokemak-Wrapped Ether-Curve.fi Factory Crypto ...    0.027714     0.028424
# 3                    Tokemak-Wrapped Ether-osETH/rETH    0.054583     0.054583
# 4   Tokemak-Wrapped Ether-Curve.fi Factory Plain P...    0.026942     0.026964
# 5    Tokemak-Wrapped Ether-Balancer stETH Stable Pool    0.016534     0.016586
# 6     Tokemak-Wrapped Ether-Balancer rETH Stable Pool    0.035483     0.050077
# 7   Tokemak-Wrapped Ether-Curve.fi Factory Pool: E...    0.087771     0.088301
# 8                 Tokemak-Wrapped Ether-weETH/WETH-ng    0.044976     0.045505
# 9         Tokemak-Wrapped Ether-Balancer rsETH / ETHx    0.030731     0.073158
# 10                    Tokemak-Wrapped Ether-wETH/rETH    0.076394     0.076394
# 11  Tokemak-Wrapped Ether-Balancer osETH/wETH Stab...    0.012069     0.037353
# 12  Tokemak-Wrapped Ether-Balancer wstETH-WETH Sta...    0.045573     0.055340
# 13         Tokemak-Wrapped Ether-Balancer ETHx/wstETH    0.023045     0.112737
# 14  Tokemak-Wrapped Ether-Balancer swETH-WETH Stab...    0.032791     0.034062
# 15  Tokemak-Wrapped Ether-Curve.fi Factory Crypto ...    0.032824     0.033233
# 16  Tokemak-Wrapped Ether-Balancer rsETH-WETH Stab...    0.027807     0.029134

# %%
latest_sod[
    [
        "name",
        "ownedShares",
        "totSupply",
        "underlyingTokenAmounts",
        "underlyingReserves",
        "incentiveAPR",
        "totalAprOut",
        "totalAprIn",
        "Date",
        "destLPValue",
    ]
]
# Out:
#                                                  name           ownedShares  \
# 0            Tokemak-Wrapped Ether-Curve.fi ETH/stETH                     0
# 1   Tokemak-Wrapped Ether-Curve.fi Factory Pool: s...                     0
# 2   Tokemak-Wrapped Ether-Curve.fi Factory Crypto ...                     0
# 3                    Tokemak-Wrapped Ether-osETH/rETH                     0
# 4   Tokemak-Wrapped Ether-Curve.fi Factory Plain P...                     0
# 5    Tokemak-Wrapped Ether-Balancer stETH Stable Pool                     0
# 6     Tokemak-Wrapped Ether-Balancer rETH Stable Pool                     0
# 7   Tokemak-Wrapped Ether-Curve.fi Factory Pool: E...                     0
# 8                 Tokemak-Wrapped Ether-weETH/WETH-ng                     0
# 9         Tokemak-Wrapped Ether-Balancer rsETH / ETHx                     0
# 10                    Tokemak-Wrapped Ether-wETH/rETH                     0
# 11  Tokemak-Wrapped Ether-Balancer osETH/wETH Stab...                     0
# 12  Tokemak-Wrapped Ether-Balancer wstETH-WETH Sta...                     0
# 13         Tokemak-Wrapped Ether-Balancer ETHx/wstETH  35360324227703601889
# 14  Tokemak-Wrapped Ether-Balancer swETH-WETH Stab...                     0
# 15  Tokemak-Wrapped Ether-Curve.fi Factory Crypto ...                     0
# 16  Tokemak-Wrapped Ether-Balancer rsETH-WETH Stab...                     0
#
#    totSupply                             underlyingTokenAmounts  \
# 0          0                                             [0, 0]
# 1          0                                             [0, 0]
# 2          0                                             [0, 0]
# 3          0                                             [0, 0]
# 4          0                                             [0, 0]
# 5          0     [263658154016371617831, 306775182341078337872]
# 6          0   [6398433704475764983107, 7690691375998310174547]
# 7          0                                             [0, 0]
# 8          0                                             [0, 0]
# 9          0    [1071100727801546816877, 387892866136055375252]
# 10         0                                             [0, 0]
# 11         0  [10993832624539408073550, 8072153475977746564191]
# 12         0    [2831304470254406848940, 831359561372495073489]
# 13         0      [97473179019984478228, 133921648282425784616]
# 14         0       [21557665452829884691, 81727178203795748670]
# 15         0                                             [0, 0]
# 16         0   [4802327224131551320143, 1548651172976811454408]
#
#                                    underlyingReserves  incentiveAPR  \
# 0   [32053017709056097416229, 36054978452860982156...  0.000000e+00
# 1   [8442437875449715352039, 14393539477280800838762]  0.000000e+00
# 2      [192136005169069194451, 210973693433123288742]  0.000000e+00
# 3    [2648765041029220131216, 2732659635691775301376]  0.000000e+00
# 4       [224406246608804822635, 60875711825788444781]  0.000000e+00
# 5      [310143702954353407752, 306775182341078337872]  0.000000e+00
# 6    [7139479440856630202282, 7690691375998310174547]  3.100955e-02
# 7     [728743301652670014069, 1457159213143158678685]  4.755062e-02
# 8     [728743301652670014069, 1457159213143158678685]  0.000000e+00
# 9     [1091598746603732470837, 402278377337436965715]  9.225449e-03
# 10       [43880133906260680382, 34889238933921616445]  5.733957e-02
# 11  [10993832624539408073550, 8282006783601900477392]  0.000000e+00
# 12    [3330491544522420333571, 831359561372495073489]  2.047298e-02
# 13     [114658667746393425530, 138888306707122311992]  0.000000e+00
# 14       [21557665452829884691, 87126910847699738619]  0.000000e+00
# 15     [859310503765655579943, 680087082106718560573]  0.000000e+00
# 16   [4894230993011013022484, 1548651172976811454408]  2.585088e-07
#
#     totalAprOut  totalAprIn                Date   destLPValue
# 0      0.019553    0.019498 2024-08-20 21:45:33  4.070127e+22
# 1      0.024399    0.022861 2024-08-20 21:45:33  2.168196e+22
# 2      0.028424    0.027714 2024-08-20 21:45:33  3.983268e+20
# 3      0.054583    0.054583 2024-08-20 21:45:33  0.000000e+00
# 4      0.026964    0.026942 2024-08-20 21:45:33  8.278779e+19
# 5      0.016586    0.016534 2024-08-20 21:45:33  0.000000e+00
# 6      0.050077    0.035483 2024-08-20 21:45:33  1.384626e+22
# 7      0.088301    0.087771 2024-08-20 21:45:33  1.058117e+21
# 8      0.045505    0.044976 2024-08-20 21:45:33  5.740130e+19
# 9      0.073158    0.030731 2024-08-20 21:45:33  4.014347e+20
# 10     0.076394    0.076394 2024-08-20 21:45:33  1.065852e+20
# 11     0.037353    0.012069 2024-08-20 21:45:33  6.132133e+21
# 12     0.055340    0.045573 2024-08-20 21:45:33  3.222657e+21
# 13     0.112737    0.023045 2024-08-20 21:45:33  1.872206e+20
# 14     0.034062    0.032791 2024-08-20 21:45:33  0.000000e+00
# 15     0.033233    0.032824 2024-08-20 21:45:33  0.000000e+00
# 16     0.029134    0.027807 2024-08-20 21:45:33  6.981129e+19

# %%
totalAprOut = raw_df.pivot_table(columns="name", index="Date", values="totalAprOut").sort_index()
px.line(totalAprOut)

# %%
raw_df

# %%
totalAprOut = raw_df.pivot_table(columns="name", index="Date", values="totalAprIn").sort_index()
px.scatter(totalAprOut)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# This is the expected cadence
#
# solver uptime, calculator keeper uptime()
#
# If a json existed

# %%
px.scatter(totalAprOut.resample("1D").first())

# %%
# destLPValue (ETH value staked at the aura / convex contract)

# %%
# underlyingTokenAmounts, quanity of each token in the pool

# %%
97473179019984478228 / 114658667746393425530
# Out:
# 0.850116096199369

# %%
133921648282425784616 / 138888306707122311992
# Out:
# 0.9642399094463017

# %% [markdown]
# What is up with underlying token amounts
#
# what is "flipFlag" in state of destinations
#
# Can you include Idle as a destination as well in the state of the destinations
#
# Can you inclue autopool address as a field, in the rebalance plan
#
# could you add the lpToken.totalSupply() for each of the pools
#
# check if these exist first

# %%
raw_df.columns
# Out:
# Index(['snapshotTimestamp', 'name', 'address', 'poolType', 'pool',
#        'underlying', 'underlyingTokens', 'underlyingReserves', 'totalAprIn',
#        'totalAprOut', 'incentiveAPR', 'destLPValue',
#        'discountViolationAddFlag', 'discountViolationTrim1Flag',
#        'discountViolationTrim2Flag', 'ownedShares', 'totSupply', 'safePrice',
#        'spotPrice', 'tokenSpotPrice', 'tokenSafePrice', 'Date', 'flipFlag'],
#       dtype='object')

# %%
def build_lp_composition_over_time_df(raw_df: pd.DataFrame) -> pd.DataFrame:
    lp_composition_over_time_df = raw_df[["name", "Date"]].copy()
    lp_composition_over_time_df["eth_value_in_destination"] = raw_df.apply(_add_eth_value_in_destination, axis=1)
    return lp_composition_over_time_df


def _add_eth_value_in_destination(row: dict):
    return (int(row["ownedShares"]) / 1e18) * row["safePrice"]


def make_autopool_LP_composition_over_time_chart(raw_df: list[pd.DataFrame]):
    lp_composition_over_time_df = build_lp_composition_over_time_df(raw_df)
    eth_in_destination_df = lp_composition_over_time_df.pivot_table(
        columns="name", index="Date", values="eth_value_in_destination"
    ).sort_index()
    # only look at destinatios we have touched,
    # eg where at least one of the values in eth_value_in_destination is not 0
    # this is just to make the legend cleaner
    eth_in_destination_df = eth_in_destination_df.loc[:, (eth_in_destination_df != 0).any(axis=0)]
    fig = px.bar(
        eth_in_destination_df.resample("1D").ffill(),
        title="LP Composition Over Time In ETH",
        labels={"value": "ETH"},
    )
    return fig


lp_composition_over_time_fig = make_autopool_LP_composition_over_time_chart(raw_df)  # These are the weights
lp_composition_over_time_fig.show()

# %% [markdown]
# Does this make sense

# %%
def build_asset_composition_over_time_df(raw_df: pd.DataFrame) -> pd.DataFrame:
    name_time_df = raw_df[["name", "Date"]].copy()

    date_assets_owned_records = raw_df.apply(_add_eth_value_in_each_asset, axis=1)
    assets_owned_df = pd.DataFrame.from_records(date_assets_owned_records)

    return pd.concat([name_time_df, assets_owned_df], axis=0)


def _add_eth_value_in_each_asset(row: dict):
    shares_owned = int(row["ownedShares"]) / 1e18
    # this will work if we have total supply, can be backed out using destination eth value but
    # using total supply is clearer
    portion_of_pool_owned = shares_owned / (int(row["totSupply"]) / 1e18)
    portion_of_tokens_owned = {"Date": row["Date"]}

    for token, underlyingReserve, tokenSafePrice in zip(
        row["underlyingTokens"], row["underlyingReserves"], row["tokenSafePrice"]
    ):
        portion_of_tokens_owned[token] = portion_of_pool_owned * (int(underlyingReserve) / 1e18) * tokenSafePrice

    return portion_of_tokens_owned  # dict[token: eth value of this token ]


a = build_asset_composition_over_time_df(raw_df)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[15], line 24
#      20         portion_of_tokens_owned[token] = portion_of_pool_owned * (int(underlyingReserve) / 1e18) * tokenSafePrice
#      22     return portion_of_tokens_owned # dict[token: eth value of this token ]
# ---> 24 a = build_asset_composition_over_time_df(raw_df)
#
# Cell In[15], line 4, in build_asset_composition_over_time_df(raw_df)
#       1 def build_asset_composition_over_time_df(raw_df: pd.DataFrame) -> pd.DataFrame:
#       2     name_time_df = raw_df[["name", "Date"]].copy()
# ----> 4     date_assets_owned_records = raw_df.apply(
#       5         _add_eth_value_in_each_asset, axis=1
#       6     )
#       7     assets_owned_df = pd.DataFrame.from_records(date_assets_owned_records)
#       9     return pd.concat([name_time_df, assets_owned_df], axis=0)
#
# File ~/.cache/pypoetry/virtualenvs/v2-rebalance-dashboard-Tgz_6KTZ-py3.12/lib/python3.12/site-packages/pandas/core/frame.py:10374, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10360 from pandas.core.apply import frame_apply
#   10362 op = frame_apply(
#   10363     self,
#   10364     func=func,
#    (...)
#   10372     kwargs=kwargs,
#   10373 )
# > 10374 return op.apply().__finalize__(self, method="apply")
#
# File ~/.cache/pypoetry/virtualenvs/v2-rebalance-dashboard-Tgz_6KTZ-py3.12/lib/python3.12/site-packages/pandas/core/apply.py:916, in FrameApply.apply(self)
#     913 elif self.raw:
#     914     return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
# --> 916 return self.apply_standard()
#
# File ~/.cache/pypoetry/virtualenvs/v2-rebalance-dashboard-Tgz_6KTZ-py3.12/lib/python3.12/site-packages/pandas/core/apply.py:1063, in FrameApply.apply_standard(self)
#    1061 def apply_standard(self):
#    1062     if self.engine == "python":
# -> 1063         results, res_index = self.apply_series_generator()
#    1064     else:
#    1065         results, res_index = self.apply_series_numba()
#
# File ~/.cache/pypoetry/virtualenvs/v2-rebalance-dashboard-Tgz_6KTZ-py3.12/lib/python3.12/site-packages/pandas/core/apply.py:1081, in FrameApply.apply_series_generator(self)
#    1078 with option_context("mode.chained_assignment", None):
#    1079     for i, v in enumerate(series_gen):
#    1080         # ignore SettingWithCopy here in case the user mutates
# -> 1081         results[i] = self.func(v, *self.args, **self.kwargs)
#    1082         if isinstance(results[i], ABCSeries):
#    1083             # If we have a view on v, we need to make a copy because
#    1084             #  series_generator will swap out the underlying data
#    1085             results[i] = results[i].copy(deep=False)
#
# Cell In[15], line 16, in _add_eth_value_in_each_asset(row)
#      13 shares_owned = int(row["ownedShares"]) / 1e18
#      14 # this will work if we have total supply, can be backed out using destination eth value but
#      15 # using total supply is clearer
# ---> 16 portion_of_pool_owned = shares_owned / (int(row["totSupply"]) / 1e18)
#      17 portion_of_tokens_owned = {'Date': row['Date']}
#      19 for token, underlyingReserve, tokenSafePrice in zip(row["underlyingTokens"], row["underlyingReserves"], row["tokenSafePrice"]):
#
# ZeroDivisionError: float division by zero
