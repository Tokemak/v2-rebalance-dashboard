# %% [markdown]
# # sketch the parts of the dashboard

# %% [markdown]
# # Autopool LP composition over time.
#
# - stacked bar plot overtime, ETH terms, not asset terms.
#
# - In state of destinations

# %% [markdown]
# # Autopool Asset Composition Over time.
#
# - stacked bar plot overtime. In ETH terms, not asset terms.
# - use LP quanity + pool balances, can be used by state of destination

# %% [markdown]
# # NAV Per share over time
#
# - onchain calls
#
# - `nav_per_share = vault_contract.functions.convertToAssets(int(1e18)).call(block_identifier=block) / 1e18`
#
# - scatter plot, annualized performance since init, since prior 30 days, local min, local max,

# %% [markdown]
# # NAV over time
# - sum idle, and debt, onchain calls

# %% [markdown]
# # Pool composite APR over time by self, (maybe other autopools)

# %% [markdown]
# # Pool composite APR over time, Xs of APR and lines for composite APR out of the other destinations.
#
# Include lines of timestamp with rebalance
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # solver is just plans, does not say it is executed or not.
#
# Was a plan proposed, or not
#
# Precurser to an execution.
#
#
# get rebalance events,
#
#
# later connect the solver execution plan to the on chain event

# %% [markdown]
# (lp Token value at start and lp token value at end, eth value at the end of reward tokens accumlated)
#
#
# ignore gas costs for now. swap costs, slippage, timeing, competence, routing, all of that jazz
#
#
# 1 ETH in DestinationA between July 1 and Aug 31 would have turned into 1.005 ETH
# 1 ETH in DestinationB between July 1 and Aug 31 would have turned into 1.002 ETH
# ...
# 1 ETH in balETH between July 1 and Aug 31 would have turned into 1.008 ETH
