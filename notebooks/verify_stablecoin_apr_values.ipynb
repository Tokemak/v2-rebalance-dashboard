# %%
from dataclasses import dataclass
from typing import List, Any

@dataclass
class destinationStats:
    snapshotTimestamp: int
    name: str
    address: str
    underlyingReserves: List[Any]
    totalAprIn: float
    totalAprOut: float
    incentiveAPR: float
    destLPValue: float
    discountViolationAddFlag: List[bool]
    discountViolationTrim1Flag: List[bool]
    discountViolationTrim2Flag: List[bool]
    totSupply: int


all_stats = [
destinationStats(snapshotTimestamp=1743037712, name='Tokemak-USD Coin-Staked USDe', address='0xb6E89d23d1E33537D383622B1955EbDa135c0b5A', underlyingReserves=[], totalAprIn=0.03728419964151889, totalAprOut=0.03728419964151889, incentiveAPR=0, destLPValue=0, discountViolationAddFlag=[False], discountViolationTrim1Flag=[False], discountViolationTrim2Flag=[False], totSupply=0),
destinationStats(snapshotTimestamp=1743037712, name='Tokemak-USD Coin-Savings Dai', address='0x77fa99c62e746C98a7c24d0EFA2120F4eee9a993', underlyingReserves=[], totalAprIn=0.05023748464136718, totalAprOut=0.05023748464136718, incentiveAPR=0, destLPValue=0, discountViolationAddFlag=[False], discountViolationTrim1Flag=[False], discountViolationTrim2Flag=[False], totSupply=0),
destinationStats(snapshotTimestamp=1743037712, name='Tokemak-USD Coin-Savings USDS', address='0xa767F35BF1d51f4ab7432188DfE6324934c9CCbD', underlyingReserves=[], totalAprIn=0.05972327753138192, totalAprOut=0.05972327753138192, incentiveAPR=0, destLPValue=0, discountViolationAddFlag=[False], discountViolationTrim1Flag=[False], discountViolationTrim2Flag=[False], totSupply=0),
destinationStats(snapshotTimestamp=1743037712, name='Tokemak-USD Coin-Savings crvUSD', address='0xc46806911906248117Bbe87aC6e2814436Ad9fbe', underlyingReserves=[], totalAprIn=0.014112274003788275, totalAprOut=0.014112274003788275, incentiveAPR=0, destLPValue=0, discountViolationAddFlag=[False], discountViolationTrim1Flag=[False], discountViolationTrim2Flag=[False], totSupply=0),
destinationStats(snapshotTimestamp=1743037712, name='Tokemak-USD Coin-Staked FRAX', address='0x4686CEe2B3b1Da28a1db926443d5DDd674462b29', underlyingReserves=[], totalAprIn=0.04866143639055304, totalAprOut=0.04866143639055304, incentiveAPR=0, destLPValue=0, discountViolationAddFlag=[False], discountViolationTrim1Flag=[False], discountViolationTrim2Flag=[False], totSupply=0),
destinationStats(snapshotTimestamp=1743037712, name='Tokemak-USD Coin-sDAI/sUSDe', address='0x04ee6c666a01018a070925040ea2aF6554d051e4', underlyingReserves=[0, 0], totalAprIn=0.043526615369215205, totalAprOut=0.043526615369215205, incentiveAPR=0.0, destLPValue=2.4045419116656984e+24, discountViolationAddFlag=[False, False], discountViolationTrim1Flag=[False, False], discountViolationTrim2Flag=[False, False], totSupply=2109663671922702890717780),
destinationStats(snapshotTimestamp=1743037712, name='Tokemak-USD Coin-Curve.fi Factory Plain Pool: crvUSD/USDC', address='0x5996333aDf54e3aC8C0Fc3De0fe51de0B75BC00d', underlyingReserves=[0, 0], totalAprIn=0.10533784135325752, totalAprOut=0.10533784135325752, incentiveAPR=0.10893427239070812, destLPValue=1.0338288462053879e+25, discountViolationAddFlag=[False, False], discountViolationTrim1Flag=[False, False], discountViolationTrim2Flag=[False, False], totSupply=10159102217147824718869031),
destinationStats(snapshotTimestamp=1743037712, name='Tokemak-USD Coin-Curve.fi Factory Plain Pool: crvUSD/USDT', address='0x6F628dcCD275feA4277722D177265741031E09d7', underlyingReserves=[0, 0], totalAprIn=0.11382188738851555, totalAprOut=0.11382188738851555, incentiveAPR=0.12168227280949627, destLPValue=6.378964763596449e+24, discountViolationAddFlag=[False, False], discountViolationTrim1Flag=[False, False], discountViolationTrim2Flag=[False, False], totSupply=6272168549700695640407284),
destinationStats(snapshotTimestamp=1743037712, name='Tokemak-USD Coin-GHO/crvUSD', address='0xB580f62dd031c63F083CBdC4f9e5C5653036cb1B', underlyingReserves=[0, 0], totalAprIn=0.025118343866591106, totalAprOut=0.025118343866591106, incentiveAPR=0.022437558232437867, destLPValue=2.0599713681593708e+24, discountViolationAddFlag=[False, False], discountViolationTrim1Flag=[False, False], discountViolationTrim2Flag=[False, False], totSupply=2049359783201951384853308),
destinationStats(snapshotTimestamp=1743037712, name='Tokemak-USD Coin-Curve.fi Factory Plain Pool: crvUSD/Frax', address='0xEeEE628a00B0EDa99D1bc78a72Fa2F2Df4AdE2F4', underlyingReserves=[0, 0], totalAprIn=0.07481588460723836, totalAprOut=0.07481588460723836, incentiveAPR=0.08121928775713075, destLPValue=1.3879550923594564e+24, discountViolationAddFlag=[False, False], discountViolationTrim1Flag=[False, False], discountViolationTrim2Flag=[False, False], totSupply=1378476686661968483569876),
destinationStats(snapshotTimestamp=1743037712, name='Tokemak-USD Coin-sUSDe/crvUSD', address='0x4a712BBFD80480eaEd9999DA8971B78DB2E12230', underlyingReserves=[0, 0], totalAprIn=0.08981816250693844, totalAprOut=0.08981816250693844, incentiveAPR=0.06172167245515278, destLPValue=1.5108529935992016e+24, discountViolationAddFlag=[False, False], discountViolationTrim1Flag=[False, False], discountViolationTrim2Flag=[False, False], totSupply=1415696924798847011197709),
destinationStats(snapshotTimestamp=1743037712, name='Tokemak-USD Coin-LlamaThena', address='0x833813b306a5bD8f372F877713D5dB5186559b3d', underlyingReserves=[0, 0], totalAprIn=0.06435697437626166, totalAprOut=0.06435697437626166, incentiveAPR=0.03216169415151663, destLPValue=3.0801249594762284e+24, discountViolationAddFlag=[False, False], discountViolationTrim1Flag=[False, False], discountViolationTrim2Flag=[False, False], totSupply=2960127318249048877421351),
destinationStats(snapshotTimestamp=1743037712, name='Tokemak-USD Coin-Curve.fi Strategic USD Reserves', address='0x41A8DFc857554aE23A4b31188a3109EA4e2377D3', underlyingReserves=[0, 0], totalAprIn=0.12862996273280913, totalAprOut=0.12862996273280913, incentiveAPR=0.10341444203630219, destLPValue=2.88393351509838e+24, discountViolationAddFlag=[False, False], discountViolationTrim1Flag=[False, False], discountViolationTrim2Flag=[False, False], totSupply=2867086514737780930621190),
destinationStats(snapshotTimestamp=1743037712, name='Tokemak-USD Coin-Curvykin Skysaver', address='0x66122E834Fa0E4cC1fA98D1C47F653561F7FBB04', underlyingReserves=[0, 0], totalAprIn=0.09324624141090736, totalAprOut=0.09324624141090736, incentiveAPR=0.06000701613859533, destLPValue=2.6037619396834447e+24, discountViolationAddFlag=[False, False], discountViolationTrim1Flag=[False, False], discountViolationTrim2Flag=[False, False], totSupply=2526724632367201093865938),
destinationStats(snapshotTimestamp=1743037712, name='Tokemak-USD Coin-sUSDe/sUSDS', address='0xE0649C82BBfF3C8F5FE000CdA5062c55c051B2EE', underlyingReserves=[0, 0], totalAprIn=0.04600358718666763, totalAprOut=0.04600358718666763, incentiveAPR=0.0, destLPValue=1.5614666890679107e+21, discountViolationAddFlag=[False, False], discountViolationTrim1Flag=[False, False], discountViolationTrim2Flag=[False, False], totSupply=1554078599406333212880),
destinationStats(snapshotTimestamp=1743037712, name='Tokemak-USD Coin-Balancer Aave GHO/USDT/USDC', address='0xC064A47894349f3cc75D5edb69A2E91c0A049d4A', underlyingReserves=[0, 0], totalAprIn=0.1286364550412168, totalAprOut=0.1286364550412168, incentiveAPR=0.1133376579570482, destLPValue=2.5876648873552805e+25, discountViolationAddFlag=[False, False, False], discountViolationTrim1Flag=[False, False, False], discountViolationTrim2Flag=[False, False, False], totSupply=25689424348898037754047061),
destinationStats(snapshotTimestamp=1743037712, name='Tokemak-USD Coin-Balancer sUSDe/USDC', address='0xe6b267103A33f01bbcBbb5C247261fB3c040B387', underlyingReserves=[0, 0], totalAprIn=0.08483640502791978, totalAprOut=0.08483640502791978, incentiveAPR=0.062215780529664914, destLPValue=1.7878963505038518e+24, discountViolationAddFlag=[False, False], discountViolationTrim1Flag=[False, False], discountViolationTrim2Flag=[False, False], totSupply=1646640906942680639595331),

]

for stat in all_stats:
    print(stat.name, round(stat.totalAprIn * 100,2))
# Out:
# Tokemak-USD Coin-Staked USDe 3.73
# Tokemak-USD Coin-Savings Dai 5.02
# Tokemak-USD Coin-Savings USDS 5.97
# Tokemak-USD Coin-Savings crvUSD 1.41
# Tokemak-USD Coin-Staked FRAX 4.87
# Tokemak-USD Coin-sDAI/sUSDe 4.35
# Tokemak-USD Coin-Curve.fi Factory Plain Pool: crvUSD/USDC 10.53
# Tokemak-USD Coin-Curve.fi Factory Plain Pool: crvUSD/USDT 11.38
# Tokemak-USD Coin-GHO/crvUSD 2.51
# Tokemak-USD Coin-Curve.fi Factory Plain Pool: crvUSD/Frax 7.48
# Tokemak-USD Coin-sUSDe/crvUSD 8.98
# Tokemak-USD Coin-LlamaThena 6.44
# Tokemak-USD Coin-Curve.fi Strategic USD Reserves 12.86
# Tokemak-USD Coin-Curvykin Skysaver 9.32
# Tokemak-USD Coin-sUSDe/sUSDS 4.6
# Tokemak-USD Coin-Balancer Aave GHO/USDT/USDC 12.86
# Tokemak-USD Coin-Balancer sUSDe/USDC 8.48

# %% [markdown]
# ## Just hold base token
# ![image.png](attachment:image.png)
#
# I Naively trust Ethena's UI here, that the APR is higher by 3.5% than this method. There would need to be a good reason to have this be lower, and that seems odd
#
# the sDAI and sUSDs rates are decisions by maker DAO governance.
#
# ![image-2.png](attachment:image-2.png)
# right now sUSDs is at 4.5 + (points). I am confident that the sUSDs rate here is in correct.
#
#
#
# https://defillama.com/yields/pool/c8a24fee-ec00-4f38-86c0-9f6daebc4225
#
# ![image-3.png](attachment:image-3.png)
#
#
#
# ![image-4.png](attachment:image-4.png)
# https://curve.fi/crvusd/ethereum/scrvUSD/
#
#
# These look like step functions, so there might be an element of the Curve DAO making decisions here. Either way they are showing 2.88% and looking historically the rates are declining.
#
# I don't think 5% here is correct.
#
# ![image-5.png](attachment:image-5.png)
#
# Pendle has the APR closer to 5.4% over 90 days here instead of 6%.
#
# https://app.frax.finance/sfrax/stake
#
# frax estimates at 5%
#
# ![image-6.png](attachment:image-6.png)

# %% [markdown]
# # Pools

# %% [markdown]
# ![image-2.png](attachment:image-2.png)
#
# convex shows 12.83% so here. That diff might be because we are discounting incnetive APR by 10%
#
# ![image.png](attachment:image.png)
#
# The same here
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)
#
# The crvUSD-FRAX nubmers here seem like an overestimate just from looking at the UI
#
# ![image-5.png](attachment:image-5.png)
#
# Again a slight under estimate
#
# ![image-6.png](attachment:image-6.png)
#
# larger under estimate
#
# ![image-7.png](attachment:image-7.png)
#
# skysaver, slight underestimate
#
#
#
# ![image-8.png](attachment:image-8.png)
#
# down by 1%, there are no incentives but there are Ethena points.

# %% [markdown]
# ## balancer pools
#
# ![image.png](attachment:image.png)
#
# Balancer is showing is showing only 7.3%
#
# ![image-2.png](attachment:image-2.png)
#
# Aura finance shows that the GHO and Aura extra rewards are currently not renewed. This makes me think the APR here is an over estimate.
#
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)
#
#
# ![image-5.png](attachment:image-5.png)
#
# This puts the swap fees at very high,
#
# Not sure how they calculate it but it looks liek the fees have bene higher this week, than they were last week
# ![image-6.png](attachment:image-6.png)
#
#
# ![image-7.png](attachment:image-7.png)

# %%
100 * (3200*12) / 1_700_000
# my back of the napkin math puts the swap fees over the last month at 2.25% that seems more reasonable than their 6.5%
# Out:
# 2.2588235294117647

# %%
# all_stats = [

# destinationStats(snapshotTimestamp=1743037712, name='Tokemak-USD Coin-Staked USDe', address='0xb6E89d23d1E33537D383622B1955EbDa135c0b5A', underlyingReserves=[], totalAprIn=0.03728419964151889, totalAprOut=0.03728419964151889, incentiveAPR=0, destLPValue=0, discountViolationAddFlag=[False], discountViolationTrim1Flag=[False], discountViolationTrim2Flag=[False], totSupply=0),
# destinationStats(snapshotTimestamp=1743037712, name='Tokemak-USD Coin-Savings Dai', address='0x77fa99c62e746C98a7c24d0EFA2120F4eee9a993', underlyingReserves=[], totalAprIn=0.05023748464136718, totalAprOut=0.05023748464136718, totalAprOut=0, destLPValue=0, discountViolationAddFlag=[False], discountViolationTrim1Flag=[False], discountViolationTrim2Flag=[False], totSupply=0),
# destinationStats(snapshotTimestamp=1743037712, name='Tokemak-USD Coin-Savings USDS', address='0xa767F35BF1d51f4ab7432188DfE6324934c9CCbD', underlyingReserves=[], totalAprIn=0.05972327753138192, totalAprOut=0.05972327753138192, incentiveAPR=0, destLPValue=0, discountViolationAddFlag=[False], discountViolationTrim1Flag=[False], discountViolationTrim2Flag=[False], totSupply=0),
# destinationStats(snapshotTimestamp=1743037712, name='Tokemak-USD Coin-Savings crvUSD', address='0xc46806911906248117Bbe87aC6e2814436Ad9fbe', underlyingReserves=[], totalAprIn=0.014112274003788275, totalAprOut=0.014112274003788275, incentiveAPR=0, destLPValue=0, discountViolationAddFlag=[False], discountViolationTrim1Flag=[False], discountViolationTrim2Flag=[False], totSupply=0),
# destinationStats(snapshotTimestamp=1743037712, name='Tokemak-USD Coin-Staked FRAX', address='0x4686CEe2B3b1Da28a1db926443d5DDd674462b29', underlyingReserves=[], totalAprIn=0.04866143639055304, totalAprOut=0.04866143639055304, incentiveAPR=0, destLPValue=0, discountViolationAddFlag=[False], discountViolationTrim1Flag=[False], discountViolationTrim2Flag=[False], totSupply=0),
# destinationStats(snapshotTimestamp=1743037712, name='Tokemak-USD Coin-sDAI/sUSDe', address='0x04ee6c666a01018a070925040ea2aF6554d051e4', underlyingReserves=[0, 0], totalAprIn=0.043526615369215205, totalAprOut=0.043526615369215205, incentiveAPR=0.0, destLPValue=2.4045419116656984e+24, discountViolationAddFlag=[False, False], discountViolationTrim1Flag=[False, False], discountViolationTrim2Flag=[False, False], totSupply=2109663671922702890717780),
# destinationStats(snapshotTimestamp=1743037712, name='Tokemak-USD Coin-Curve.fi Factory Plain Pool: crvUSD/USDC', address='0x5996333aDf54e3aC8C0Fc3De0fe51de0B75BC00d', underlyingReserves=[0, 0], totalAprIn=0.10533784135325752, totalAprOut=0.10533784135325752, incentiveAPR=0.10893427239070812, destLPValue=1.0338288462053879e+25, discountViolationAddFlag=[False, False], discountViolationTrim1Flag=[False, False], discountViolationTrim2Flag=[False, False], totSupply=10159102217147824718869031),
# destinationStats(snapshotTimestamp=1743037712, name='Tokemak-USD Coin-Curve.fi Factory Plain Pool: crvUSD/USDT', address='0x6F628dcCD275feA4277722D177265741031E09d7', underlyingReserves=[0, 0], totalAprIn=0.11382188738851555, totalAprOut=0.11382188738851555, incentiveAPR=0.12168227280949627, destLPValue=6.378964763596449e+24, discountViolationAddFlag=[False, False], discountViolationTrim1Flag=[False, False], discountViolationTrim2Flag=[False, False], totSupply=6272168549700695640407284),
# destinationStats(snapshotTimestamp=1743037712, name='Tokemak-USD Coin-GHO/crvUSD', address='0xB580f62dd031c63F083CBdC4f9e5C5653036cb1B', underlyingReserves=[0, 0], totalAprIn=0.025118343866591106, totalAprOut=0.025118343866591106, incentiveAPR=0.022437558232437867, destLPValue=2.0599713681593708e+24, discountViolationAddFlag=[False, False], discountViolationTrim1Flag=[False, False], discountViolationTrim2Flag=[False, False], totSupply=2049359783201951384853308),
# destinationStats(snapshotTimestamp=1743037712, name='Tokemak-USD Coin-Curve.fi Factory Plain Pool: crvUSD/Frax', address='0xEeEE628a00B0EDa99D1bc78a72Fa2F2Df4AdE2F4', underlyingReserves=[0, 0], totalAprIn=0.07481588460723836, totalAprOut=0.07481588460723836, incentiveAPR=0.08121928775713075, destLPValue=1.3879550923594564e+24, discountViolationAddFlag=[False, False], discountViolationTrim1Flag=[False, False], discountViolationTrim2Flag=[False, False], totSupply=1378476686661968483569876),
# destinationStats(snapshotTimestamp=1743037712, name='Tokemak-USD Coin-sUSDe/crvUSD', address='0x4a712BBFD80480eaEd9999DA8971B78DB2E12230', underlyingReserves=[0, 0], totalAprIn=0.08981816250693844, totalAprOut=0.08981816250693844, incentiveAPR=0.06172167245515278, destLPValue=1.5108529935992016e+24, discountViolationAddFlag=[False, False], discountViolationTrim1Flag=[False, False], discountViolationTrim2Flag=[False, False], totSupply=1415696924798847011197709),
# destinationStats(snapshotTimestamp=1743037712, name='Tokemak-USD Coin-LlamaThena', address='0x833813b306a5bD8f372F877713D5dB5186559b3d', underlyingReserves=[0, 0], totalAprIn=0.06435697437626166, totalAprOut=0.06435697437626166, incentiveAPR=0.03216169415151663, destLPValue=3.0801249594762284e+24, discountViolationAddFlag=[False, False], discountViolationTrim1Flag=[False, False], discountViolationTrim2Flag=[False, False], totSupply=2960127318249048877421351),
# destinationStats(snapshotTimestamp=1743037712, name='Tokemak-USD Coin-Curve.fi Strategic USD Reserves', address='0x41A8DFc857554aE23A4b31188a3109EA4e2377D3', underlyingReserves=[0, 0], totalAprIn=0.12862996273280913, totalAprOut=0.12862996273280913, incentiveAPR=0.10341444203630219, destLPValue=2.88393351509838e+24, discountViolationAddFlag=[False, False], discountViolationTrim1Flag=[False, False], discountViolationTrim2Flag=[False, False], totSupply=2867086514737780930621190),
# destinationStats(snapshotTimestamp=1743037712, name='Tokemak-USD Coin-Curvykin Skysaver', address='0x66122E834Fa0E4cC1fA98D1C47F653561F7FBB04', underlyingReserves=[0, 0], totalAprIn=0.09324624141090736, totalAprOut=0.09324624141090736, incentiveAPR=0.06000701613859533, destLPValue=2.6037619396834447e+24, discountViolationAddFlag=[False, False], discountViolationTrim1Flag=[False, False], discountViolationTrim2Flag=[False, False], totSupply=2526724632367201093865938),
# destinationStats(snapshotTimestamp=1743037712, name='Tokemak-USD Coin-sUSDe/sUSDS', address='0xE0649C82BBfF3C8F5FE000CdA5062c55c051B2EE', underlyingReserves=[0, 0], totalAprIn=0.04600358718666763, totalAprOut=0.04600358718666763, incentiveAPR=0.0, destLPValue=1.5614666890679107e+21, discountViolationAddFlag=[False, False], discountViolationTrim1Flag=[False, False], discountViolationTrim2Flag=[False, False], totSupply=1554078599406333212880),
# destinationStats(snapshotTimestamp=1743037712, name='Tokemak-USD Coin-Balancer Aave GHO/USDT/USDC', address='0xC064A47894349f3cc75D5edb69A2E91c0A049d4A', underlyingReserves=[0, 0], totalAprIn=0.1286364550412168, totalAprOut=0.1286364550412168, incentiveAPR=0.1133376579570482, destLPValue=2.5876648873552805e+25, discountViolationAddFlag=[False, False, False], discountViolationTrim1Flag=[False, False, False], discountViolationTrim2Flag=[False, False, False], totSupply=25689424348898037754047061),
# destinationStats(snapshotTimestamp=1743037712, name='Tokemak-USD Coin-Balancer sUSDe/USDC', address='0xe6b267103A33f01bbcBbb5C247261fB3c040B387', underlyingReserves=[0, 0], totalAprIn=0.08483640502791978, totalAprOut=0.08483640502791978, incentiveAPR=0.062215780529664914, destLPValue=1.7878963505038518e+24, discountViolationAddFlag=[False, False], discountViolationTrim1Flag=[False, False], discountViolationTrim2Flag=[False, False], totSupply=1646640906942680639595331),

# ]

# what it was
